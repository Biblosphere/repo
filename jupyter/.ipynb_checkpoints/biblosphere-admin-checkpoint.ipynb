# %% [markdown]
# ***Admin functions for Biblosphere***
#
# - MySQL functions
# -- Delete ISBN record
# -- Query book by ISBN
#
# - API functions
# -- Add book with ISBN
# -- Recognize book shelf by photo
# -- Scan not found ISBN

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore
from firebase_admin import storage
from firebase_admin import auth
from math import pi, sin, cos, atan2, sqrt
import requests
import re
import geohash2
from geopy.geocoders import Nominatim
from google.cloud.firestore_v1 import Increment

import cv2
import pandas as pd
import json


#cred = credentials.Certificate("biblosphere-firebase-adminsdk.json")
#firebase_admin.initialize_app(cred)

class Book:
    def __init__(self, isbn, title, authors, image='', language=None):
        self.isbn = isbn
        self.title = title
        self.authors = authors
        self.image = image
        if language is not None:
            self.language = language
        self.keys = lexems(title + ' ' + authors + ' ' + isbn, full=True)

    @classmethod
    def from_json(cls, obj):
        return cls(obj['isbn'], obj['title'], obj['authors'], obj['image'])

    def catalog_title(self):
        return self.title + ' ' + self.authors
    
def lexems(s, full = False):
    if type(s) is str:
        return re.sub('[;()\",/&!?:.\-*·|+$\'«@•]',' ',s.lower()).split()
    elif type(s) is set:
        return [w.lower() for w in s]
    

class Block:
    def __init__(self, book=None, bookspine=None, outline=None):
        self.book = book
        self.bookspine = bookspine
        self.outline = outline


    @classmethod
    def from_json(cls, obj):
        return cls(book=obj['book'], bookspine=obj['bookspine'], outline=obj['outline'])


# Class to decode JSON to class objects
class JsonDecoder(json.JSONDecoder):
    def __init__(self, *args, **kwargs):
        json.JSONDecoder.__init__(self, object_hook=self.object_hook, *args, **kwargs)

    def object_hook(self, obj):
        if '_type' not in obj:
            return obj
        type = obj['_type']
        if type == 'Book':
            return Book.from_json(obj)
        elif type == 'Block':
            return Block.from_json(obj)
        
        
# Function to calculate distance between two geo-points
def distance_between(lat1, lon1, lat2, lon2):
    r = 6378.137 # Radius of earth in KM
    d_lat = lat2 * pi / 180 - lat1 * pi / 180
    d_lon = lon2 * pi / 180 - lon1 * pi / 180
    a = sin(d_lat/2) * sin(d_lat/2) + cos(lat1*pi/180) * cos(lat2*pi/180) * sin(d_lon/2) * sin(d_lon/2)
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = r * c

    return distance / 1000


def check_isbn_10(isbn):
    i, s, t = 0, 0, 0

    digits = [int(d) for d in isbn]
    
    for d in digits: 
        t += d
        s += t

    return s % 11


def calc_isbn_13(isbn):
    digits = [int(d) for d in isbn]
    
    check = 0
    for i, d in enumerate(digits[0:12]):
        #print(i, d)
        #print(d * (1 + 2 * (i % 2))
        check += d * (1 + 2 * (i % 2))
        
    return (10 - check % 10) % 10


# Test recognize:
# gcloud auth print-identity-token
headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjY1YjNmZWFhZDlkYjBmMzhiMWI0YWI5NDU1M2ZmMTdkZTRkZDRkNDkiLCJ0eXAiOiJKV1QifQ..oby53OATR_4VfLZpiXPWJSac0PDG_MS6a5FBxIrdZYucy4-_5vVoggx1xNOOhOd7WRhrJ_6awYdf_eIes_kbVdPjfUsTslJUQCOc6tjH8sy69dqilwrSNqub1WPttcMUlq_t8qxKRlyZRL6a5uw7RjmU3MBJrjTyaNEq-XM1KrcVY1bW1Gwt7nAGGE8yqvuPzfVSyz-EgZ9fJFkl9hXDYhoBoL2mPv_43Z1dXBjK9QOcZ_3p4sKJKjERmXrWHANY-mA4__qeaTnpA-eh9nVr-H6CGFdOEmhRKNrHecW0QBi5aZYgLK3Af1DBDFUhaq5Ot34f4XZ81P7S1u--JmDtCA"}

def get_book(isbn):
    try:
        endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/get?isbn=%s" % isbn

        res = requests.get(endpoint, headers=headers)

        if not res.ok:
            print('HTTP error:', res.status_code, res._content)
            return None
        
        res_json = json.loads(res._content)
        books = [Book.from_json(obj) for obj in res_json]

        if books is not None and len(books) > 0:
            return books[0]
        else:
            return None
    except Exception as e:
        print('Exception for book [%s]' % book['id'], e)
        traceback.print_exc()
        return None

    
def add_books(books):
    endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/add"

    body = {'books': [
        {"isbn": b.isbn, 
         "title": b.title, 
         "authors": b.authors,
         "image": b.image,
        } for b in books]
    }
    res = requests.post(endpoint, headers=headers, json=body)
    
    if res.ok:
        print('%d books added' % len(books))
    else:
        print('HTTP error:', res.status_code, res._content)
        
    return    
    

def recognize_image(uid, image, shelf, point):
    endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/add_user_books_from_image"
    body = {
              'uid': uid,
              'uri': 'images/%s/%s' % (uid, image),
              'shelf': shelf,
              'notification': False,
              'location': {
                  'lat': point.latitude,
                  'lon': point.longitude,
                  'geohash': geohash2.encode(point.latitude, point.longitude)[:9],
               }
            }
    
    #print('Input:', body)
    
    res = requests.post(endpoint, headers=headers, json=body)

    if res.ok:
        print(res._content)
        return True
    else:
        print('HTTP error:', res.status_code, res._content)
        return False

# %%
# Script to create data for Bilblosphere v3 
# - copy "bookrecords" to "books"
# - "users" with books to "bookplaces" (group books by location hash)
# - "shelves" to "photos"
# - copy wishlists from "bookrecords" to "users"
# CLEAN "photos", "books", "photos", "bookplaces" BEFORE RUN!!! 

db = firestore.client()

# Loop throug all users. Select for each user all shelves and bookrecords (wish and books).
#users = db.collection('users').limit(30).stream()
users = db.collection('users').stream()
users = [u for u in users]

for u in users:
    u_data = u.to_dict()

    # - Copy all wishes to "wishlist" property
    wishes = db.collection('bookrecords').where('ownerId', '==', u.id).where('wish', '==', True).stream()
    wishlist =  [w.to_dict()['isbn'] for w in wishes] 

    if len(wishlist) > 0:
        print('Wishlist updated', u.id)
        db.collection('users').document(u.id).update({'wishlist': wishlist})
            
    # - Group all books and shelves for the same geo-hash (first 7 positions). Create bookplace for each geo-hash.
    books = db.collection('bookrecords').where('ownerId', '==', u.id).where('wish', '==', False).order_by('location.geohash').stream()
    books_data = [b.to_dict() for b in books]

    # Only do for users with books
    if len(books_data) > 0:
        # Get user email 
        user_auth = auth.get_user(u.id)

        # - Create "photos" records for each "shelves" record. Link it to user.
        shelves = db.collection('shelves').where('userId', '==', u.id).stream()
        shelves_data = [s.to_dict() for s in shelves]
        photos = {}
        
        for s in shelves_data:
            if 'image' in s and s['image'] is not None:
                photo = {'photo': s['image'],
                         'reporter': s['userId']}
                
                if 'position' in s and s['position'] is not None:
                    photo['location'] =   {
                         'geopoint': s['position'],
                         'geohash': geohash2.encode(s['position'].latitude, s['position'].longitude)[:9],
                        }

                photo_ref = db.collection('photos').document()
                photo_ref.set(photo)
                photo['id'] = photo_ref.id

                photos[s['image']] = photo

        bookplaces = {}
        geohash = ''
        bookplace = {}

        for b in books_data:

            # If first book or book from another location -> create bookplace
            if b['location']['geohash'][0:7] != geohash:
                geohash = b['location']['geohash'][0:7]

                # Create bookplace record
                bookplace = {'users': [u.id], 'location': b['location']}
                
                if user_auth is not None:
                    bookplace['email'] = user_auth.email
                    bookplace['name'] = user_auth.display_name
            
                # Keep bookplace record in Firestore
                bookplace_ref = db.collection('bookplaces').document()
                bookplace_ref.set(bookplace)
                
                bookplace['id'] = bookplace_ref.id
                bookplaces[geohash] = bookplace

            # Create book record
            book = {'bookplace': bookplace['id'], 
                    'location': b['location'],
                    'owner_id': b['ownerId'],
                    'authors': b['authors'],
                    'title': b['title'],
                    'isbn': b['isbn'],
                    'cover': b['image'],
                   }
            
            # If book refer to shelf -> update shelf location and bookplace (if missing)
            if 'shelf_image' in b:
                book['photo'] = b['shelf_image']
                
                if b['shelf_image'] in photos: 
                    book['photo_id'] = photos[b['shelf_image']]['id']
                else:
                    print('DATA MISSING: shelf is missing:', b['shelf_image'])
                
                if b['shelf_image'] in photos and 'location' not in photos[b['shelf_image']]: 
                    photos[b['shelf_image']]['location'] = b['location']

                if b['shelf_image'] in photos and 'bookplace' not in photos[b['shelf_image']]: 
                    photos[b['shelf_image']]['bookplace'] = bookplace['id']


            if 'ownerName' in b:
                book['owner_name'] = b['ownerName']

            # Store book in Firestore
            db.collection('books').document().set(book)

        for key in photos:
            p = photos[key]
            
            if 'location' not in p:
                if 'location' in u_data:
                    p['location'] = u_data['location']
                else:
                    print('DATA MISSING: location missing:', u.id, p['photo'])

            # Update photo in Firestore
            if 'location' in p and 'bookplace' in p:
                db.collection('photos').document(p['id']).update({'location': p['location'], 'bookplace': p['bookplace']})
# Out:
# DATA MISSING: location missing: 15REj1o7M5aj528uHTswiG4i5nr1 images/15REj1o7M5aj528uHTswiG4i5nr1/1590558940200.jpg
# DATA MISSING: location missing: 15REj1o7M5aj528uHTswiG4i5nr1 images/15REj1o7M5aj528uHTswiG4i5nr1/1590558991094.jpg
# DATA MISSING: location missing: 15REj1o7M5aj528uHTswiG4i5nr1 images/15REj1o7M5aj528uHTswiG4i5nr1/1590559079080.jpg
# DATA MISSING: location missing: 1VHBTFgSb0ay5I3jZS3htp16KrT2 images/1VHBTFgSb0ay5I3jZS3htp16KrT2/1592265067919.jpg
# Wishlist updated 1b2o7YjIkChyVOJK4EfbzvGpP4M2
# DATA MISSING: location missing: 24bjZCnWLFQ5VrmR5E8HZKC12IE2 images/24bjZCnWLFQ5VrmR5E8HZKC12IE2/1600103869571.jpg
/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590265241529.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590324109192.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590324129308.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590324155442.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590922212979.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590922272311.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594152683298.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594153150239.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594153258331.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594153343007.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594154259676.jpg
# DATA MISSING: location missing: vDWiB1lV2yYAAd8t7J3PkeKhRpH2 images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1594154817518.jpg
# DATA MISSING: location missing: wzkLkyqWeWXYUyYfXGxZocaTHZD2 images/wzkLkyqWeWXYUyYfXGxZocaTHZD2/1591455820952.jpg
# Wishlist updated xDDC4YKaQUeKsr1CKgmioVz4nx02
# DATA MISSING: location missing: xem1khYLX0a3d7KuE2FTYa9QGcK2 images/xem1khYLX0a3d7KuE2FTYa9QGcK2/1590140670901.jpg
# Wishlist updated xrTVCEyCwfOtO8lDe5UKk2egF4c2
# Wishlist updated xwnPhfeRv5QFgeisoNSZer53oY12
# Wishlist updated yDqi9VsWfEYFhBLyK17eMhMzHND3
# Wishlist updated zEFXcNUi0sa3tw20pQfLdJ8TO303
# DATA MISSING: location missing: zMxvIhjkpeYhknY56EMu0ybrBEN2 images/zMxvIhjkpeYhknY56EMu0ybrBEN2/1593621385650.jpg
# Wishlist updated zY0Zg4bB7OY4zQcOKZjeixCuPQG3
# Wishlist updated zhqhgC2sr8SqREHBJAbkjUZxqvj1

# %%
# Admin script to build book clusters
# There are 4 levels of clusters:
# - At geo-hash length 7 (150 m)
# - At geo-hash length 5 (5 km)
# - At geo-hash length 3 (150 km)
# - At geo-hash length 2 (1200 km)

# DROP 'clusters' BEFORE RERUN!!!

# Function to update clusters on all 4 levels
def updateGeoHash(geohash, geopoint, count):

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:7])
    db.collection('clusters').document(geohash[:7]).set({'id': geohash[:7],  
                                                         'level': 7,
                                                         'hash5': geohash[:5],
                                                         'hash6': geohash[:6],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:5])
    db.collection('clusters').document(geohash[:5]).set({'id': geohash[:5],  
                                                         'level': 5,
                                                         'hash3': geohash[:3],
                                                         'hash4': geohash[:4],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:3])
    db.collection('clusters').document(geohash[:3]).set({'id': geohash[:3],  
                                                         'level': 3,
                                                         'hash2': geohash[:2],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:2])
    db.collection('clusters').document(geohash[:2]).set({'id': geohash[:2],  
                                                         'level': 2,
                                                         'hash1': geohash[:1],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)
    return


db = firestore.client()

#places = db.collection('bookplaces').limit(30).stream()
places = db.collection('bookplaces').stream()
places = [p for p in places]

count = 0
for p in places:
    # Calculate number of books for each bookplace
    books = db.collection('books').where('bookplace', '==', p.id).stream()
    books = [b for b in books]
    
    db.collection('bookplaces').document(p.id).update({'count': len(books), 'id': p.id})
    print('Bookplace %s updated: book count = %d' % (p.id, len(books)))

    # Update clusters for each bookplace
    place = p.to_dict()
    if 'location' not in place:
        print('************** ERROR: place %s does not have location' % p.id)
    else:
        updateGeoHash(place['location']['geohash'], place['location']['geopoint'], len(books))
# Out:
# Bookplace 07hGVZEQf8gI85OEsJJZ updated: book count = 5
# Bookplace 0DksB6iVdipN7XtRXjcC updated: book count = 4
# Bookplace 0dlGLZ9DnMQBpMYgWNk7 updated: book count = 1
# Bookplace 0j01ufqiI2vpNmnuAsDM updated: book count = 24
# Bookplace 0yhdjiFtP5hrhrT5kh2g updated: book count = 2
# Bookplace 1I2MC7LLA41WFxYpw0Vm updated: book count = 1
# Bookplace 1YDU71ndZ9UUMhtksikw updated: book count = 2
# Bookplace 1c867uI7EiRzJLxJY5lf updated: book count = 4
# Bookplace 1r1tFCczR1Jfz5BuoiQp updated: book count = 5
# Bookplace 2546YeewBJQf16k4Eb89 updated: book count = 1
# Bookplace 2GxAGyzEAa8wawXaThXN updated: book count = 14
# Bookplace 2V4MrQmey0VMvA06yXSo updated: book count = 1
# Bookplace 2b3py69Yk92PSOtIGOhU updated: book count = 2
# Bookplace 2i86MNp5RgzNgbNgKLqh updated: book count = 3
# Bookplace 2twNvz9VZ2zTHbIyZPT6 updated: book count = 28
# Bookplace 2y8nIpyRnlPbGRYU2MPq updated: book count = 5
# Bookplace 3HocMwO1E6iZLje0jVd4 updated: book count = 19
# Bookplace 3LKY1LVaF4wgPnmPSFsF updated: book count = 15
# Bookplace 3oJhbeVR2IYXVvs6nzSu updated: book count = 1
# Bookplace 3vCb2jrWkjz6deyFEsg3 updated: book count = 2
# Bookplace 4Nv2k4vNWFRS2R7T7eOP updated: book count = 20
# Bookplace 4oIe4cf7X0bOmCexWn8Q updated: book count = 1
# Bookplace 59fAxiKhgsqQF3HriSed updated: book count = 7
# Bookplace 5KMACRNlHLT0QKzGpDJ2 updated: book count = 2
# Bookplace 5YrqO0XscsA21WcDonC2 updated: book count = 4
# Bookplace 6JRyQOJfeB4cIC07gJGS updated: book count = 6
# Bookplace 6KopdGAsLYRUBEiwxuVm updated: book count = 25
# Bookplace 6PkRQaaO66gonX39OAMl updated: book count = 5
# Bookplace 6bUCIVED6kCha8cMLe2v updated: book count = 3
# Bookplace 6gC74R8KSlx9Kbtttj0e updated: book count = 14
# Bookplace 6qQUNoYHmIyDVRJCm0HP updated: book count = 4
# Bookplace 7DohZ7ab69jYgqeAz2vv updated: book count = 1
# Bookplace 85iQl09DIB5fN5BD6LNW updated: book count = 16
# Bookplace 8LzHYjptL0QFLjb4i3YQ updated: book count = 20
# Bookplace 8ZXhjP2OoRk67S1a24hU updated: book count = 1
# Bookplace 8bODms84ad5Qy2phpAmG updated: book count = 1
# Bookplace 8dHLJW6Bnxtq4uZKOpOu updated: book count = 14
# Bookplace 99fHXqkt7caWroJs0OJ4 updated: book count = 6
# Bookplace 9Q8TRENhRey2uVoDEL6Q updated: book count = 4
# Bookplace 9SRUPduZRk7NlBlVTYNx updated: book count = 2
# Bookplace 9kSzJdgzoioaubHjDcVL updated: book count = 1
# Bookplace 9vZd56ws5QpKqpSCVrGw updated: book count = 5
# Bookplace 9zPsL3EU9bQ4bWzhpzct updated: book count = 2
# Bookplace B1vkvIBXkfcbcQ0NDZBw updated: book count = 7
# Bookplace BIowW741IPusk9GhqkNG updated: book count = 2
# Bookplace Bg4Vaic9fePd1glO5nXy updated: book count = 80
# Bookplace BggpluwZodKbMT8qXgQP updated: book count = 16
# Bookplace BvKEAOIG8YiBufOTV2zx updated: book count = 5
# Bookplace Bxu2mk01jW7YJ9nkGF6Y updated: book count = 88
# Bookplace C0zTlAOr6EZz9Cosnyag updated: book count = 5
# Bookplace C888aLnQijOEbb1odmc7 updated: book count = 16
# Bookplace C9XGFER8noB0bgMqafZk updated: book count = 1
# Bookplace CNDYH7CNjwsdunUg6qoJ updated: book count = 4
# Bookplace CXzbN86zxBoKTmGQGbn0 updated: book count = 1
# Bookplace CpaMefCvXUxphD4k3OdX updated: book count = 17
# Bookplace DKK75rvwGD8JgOThr7Lx updated: book count = 1
# Bookplace E164EMpNgPI5BvfI1JJd updated: book count = 8
# Bookplace E4aRQlkJfV7XCnsD5eXH updated: book count = 8
# Bookplace EEqmW75AMP2tr4v29PeV updated: book count = 8
# Bookplace EGuSi7Yt7alVGSWwcgI7 updated: book count = 35
# Bookplace ELIkoQcE8kMfY7GUJf0e updated: book count = 6
# Bookplace F466JtuTt2P0pwwdLhXP updated: book count = 1
# Bookplace FECb0Y3r6u69Xhft41IA updated: book count = 2
# Bookplace FZzKQaX1SJH1GWpn7YUm updated: book count = 17
# Bookplace Fn1him3NBwoSVXDDN3wv updated: book count = 2
# Bookplace Fz1OvpkBQ1bi2Ygenvzu updated: book count = 8
# Bookplace G1zchilAiVLxxfpoakq9 updated: book count = 5
# Bookplace G9uHHWgMRXwmrWPMwJX6 updated: book count = 36
# Bookplace GDmDbFJZQjnCh0lQImRZ updated: book count = 2
# Bookplace GaUYvi61qxZfrmjHfpS9 updated: book count = 9
# Bookplace GplgpuKNUGJDz5W5skPQ updated: book count = 1
# Bookplace GqB20k8xJt4Nzhamj5KH updated: book count = 9
# Bookplace GyCY0Ad2HzO97KlDuRom updated: book count = 9
# Bookplace H4oIxlxHqrFI7S72OLZD updated: book count = 11
# Bookplace HLIaIhXBszYydJgKpHQS updated: book count = 1
# Bookplace HUhjMQZN0uDOJ3O5d6nc updated: book count = 1
# Bookplace Ha79NmookvMVTbmCia2u updated: book count = 5
# Bookplace Hay82EjjZQIEUT9PPIQ0 updated: book count = 17
# Bookplace Hl9wOutRB37GhLTNNQII updated: book count = 2
# Bookplace HnvHlnnK1gNwQBFKxsE5 updated: book count = 9
# Bookplace HopmbOWZ5KxTz21hH4BG updated: book count = 8
# Bookplace Hulj7ftN7ixmyNqVO5yR updated: book count = 2
# Bookplace I1WMJwx1DpRnaOCULQlB updated: book count = 11
# Bookplace IuaC6iNkYDNipxqXqaog updated: book count = 7
# Bookplace JIpdNggt7DHEr8Mrtv3t updated: book count = 13
# Bookplace JOKveXiPQRotRzS2MUGi updated: book count = 13
# Bookplace JVdZIyiet1xv2Bh2l4bk updated: book count = 1
# Bookplace JZwEk6k83fRnbF3t1xIw updated: book count = 2
# Bookplace K2Wbx524G1Zvx1S7Dq0O updated: book count = 6
# Bookplace KF0ngfVFn7Nq1vcFXlLQ updated: book count = 1
# Bookplace KOzFDTTkVGFXr0KIuRlP updated: book count = 3
# Bookplace KU433nHouE5T0fDgOHKu updated: book count = 17
# Bookplace KtMWdDi4w0X2x8bDFRHL updated: book count = 4
# Bookplace LkjMJdVwRZPDh2qEiY2Y updated: book count = 1
# Bookplace McjVkusEhukyNz817mEz updated: book count = 7
# Bookplace McmBamDQ0ZDKhHTHkj42 updated: book count = 21
# Bookplace N9Uk5wdOKeGljZpBZoWA updated: book count = 5
# Bookplace Ndwh6jYazPtmRMmEZyFi updated: book count = 1
# Bookplace NnuxIVrvQ7lp7S2UAHhK updated: book count = 19
# Bookplace ODgPdKTvxLRxbYEGfF0f updated: book count = 5
# Bookplace Ogf8Y32ZQAZrVDFmVUYQ updated: book count = 1
# Bookplace OinFcoAViWTTwVzLIsOY updated: book count = 10
# Bookplace Oq4lFsFmSDBTJjaKiUMB updated: book count = 6
# Bookplace PDhIxZsPAgcdah0uYefC updated: book count = 2
# Bookplace PdgSZnR6KdW8BTa4sFuR updated: book count = 22
# Bookplace PfHcJK89T1LnjY5bCWh9 updated: book count = 13
# Bookplace PoMPZYnCFHR9rTPg7LmU updated: book count = 28
# Bookplace PuxRypDAaaPhiJo6sZHB updated: book count = 4
# Bookplace Q0ERk9uY2O1ZqU7VVzo8 updated: book count = 2
# Bookplace QWZKDm1qquViOhfMSaI3 updated: book count = 24
# Bookplace QhfIE7d7p0PMWaMt2Osj updated: book count = 4
# Bookplace QzyeI94O2iQ9EJnGg4Qg updated: book count = 12
# Bookplace R2ge3XyVY50k9rgTgZ8u updated: book count = 2
# Bookplace RHm0Irm0B2xcvA9r0xow updated: book count = 1
# Bookplace RVFC9CRr8dj2XSPzdrcp updated: book count = 21
# Bookplace RjPdhg2y5R0yf6DmNcfj updated: book count = 3
# Bookplace Rr7xyWXNQC8xcslPjJFC updated: book count = 2
# Bookplace S8sUHAZeGtv53vAm9BL6 updated: book count = 1
# Bookplace SGg4GqwmnT8VFK9T9pBe updated: book count = 1
# Bookplace SkSTOpRJwv7Rs21zxHB6 updated: book count = 1
# Bookplace SmT3KppBrnRtDBouR1TB updated: book count = 17
# Bookplace SnZ1GZeuZVRXuE6CkShr updated: book count = 25
# Bookplace SzlfhDqy9YciQqYZbhh6 updated: book count = 12
# Bookplace TNKy58tCJ7XXES1SinoD updated: book count = 5
# Bookplace TZ2ILEO5ee9mFCMpr8gu updated: book count = 8
# Bookplace Thx4rlXdSZkJCZAW2VDM updated: book count = 1
# Bookplace TyG9pE2D24dFNE0sq0OB updated: book count = 9
# Bookplace UUo0CQ9S5L2PjOLOWfYY updated: book count = 3
# Bookplace UerVJ8hbyKml0Ft4iZXD updated: book count = 1
# Bookplace Ui5tBjn6cSCJuV4Y3R3v updated: book count = 9
# Bookplace VEuOYnK5Ge3eYJ00srlq updated: book count = 11
# Bookplace VRJHshlByOW4bl6LS8Ha updated: book count = 1
# Bookplace W5gWIw3Mp3ZAW4QWeAcw updated: book count = 1
# Bookplace WBLIjtFZI14PnfCJoQ8L updated: book count = 1
# Bookplace WFDx8bZ5jTOQgpSueZUC updated: book count = 3
# Bookplace WOTuQyTxsgO73C2VJk3y updated: book count = 28
# Bookplace WT8ZdbkgzzehqjtPUclC updated: book count = 1
# Bookplace WTmoSBvO1qDcQsXXsK3X updated: book count = 1
# Bookplace WXn0Zl9QFeoAsIu3oO5O updated: book count = 2
# Bookplace Wj5GpDwvyjEaItcGP4AZ updated: book count = 7
# Bookplace WoG6ioK4MJ27pCn68ctJ updated: book count = 3
# Bookplace WryDcbG3OX0wayde3VF3 updated: book count = 28
# Bookplace WujnqcdLksVGr9DHsSha updated: book count = 8
# Bookplace X2oJiZK3kRyL4EQMolD0 updated: book count = 7
# Bookplace X4M4gGU3APLOxrNbXTn2 updated: book count = 1
# Bookplace XNZYyz09AugssdFZlHp2 updated: book count = 1
# Bookplace XR6SvDK5XBPaniQuHvjX updated: book count = 4
# Bookplace XyC6NFpvQFLz5kqlpnxq updated: book count = 2
# Bookplace YQNZp984hMxwddvYdqFo updated: book count = 1
# Bookplace Ylgt6RjiKsFp3SCcPiGZ updated: book count = 1
# Bookplace YqzBf6cJfdsssHE73Jaw updated: book count = 1
# Bookplace Yy0nM7wsFPh3yEFnDY86 updated: book count = 8
# Bookplace ZACLa76ba3VfPs7mac58 updated: book count = 2
# Bookplace ZWsTUXJTF0wtLdiDTj1h updated: book count = 15
# Bookplace a5QSmNYGITfINbm7hSHI updated: book count = 3
# Bookplace aAVU5Pl0wPByfpSqTixr updated: book count = 8
# Bookplace aI2qxkPOdrRMzJBE2NRN updated: book count = 15
# Bookplace aRKj9wJZuRoDjTWGke6X updated: book count = 1
# Bookplace aeHSrbsbM6yOuSBkL4OQ updated: book count = 1
# Bookplace aqxazuZ2rbIT8wjhf8KW updated: book count = 1
# Bookplace b7dWyXB0MRIK9PNJsywQ updated: book count = 4
# Bookplace bC5FYCGJK9gWzAsukQ2U updated: book count = 6
# Bookplace bg2yzzBR3UjQSBlENF6V updated: book count = 2
# Bookplace bxIynuKaHVXX68By9ygW updated: book count = 7
# Bookplace c0XPbMy8ieQbxp1dwIZH updated: book count = 16
# Bookplace c3MzJCBnGA3XpLBWhGXO updated: book count = 24
# Bookplace cBanwCOoyL5f8VxYzRTz updated: book count = 35
# Bookplace cdMs6tVjtOpjrIsLmung updated: book count = 15
# Bookplace d1BaIHZCvwJVXJ2RRfJW updated: book count = 1
# Bookplace dOQ4dK1VpW6fJo8WN74Q updated: book count = 1
# Bookplace dQZ67OQzlruf5oWuEvRK updated: book count = 15
# Bookplace dTzRftnv1DQWBYdI2yeX updated: book count = 2
# Bookplace dtL3sKcCBCEMqg2qbskC updated: book count = 43
# Bookplace eBqqGd5mKwS15WhLWB9k updated: book count = 1
# Bookplace eE8irducFvn7efiwkFRG updated: book count = 1
# Bookplace eMyyDVqfCekxDI7SUw4D updated: book count = 4
# Bookplace eQue2V3nbP6P34taSPYq updated: book count = 2
# Bookplace eXfuwaKMnciF2HzsQPxb updated: book count = 16
# Bookplace ed6A9XpOyrtjLUMD5dws updated: book count = 31
# Bookplace eyh7Od8vBp6tRSogeTC7 updated: book count = 9
# Bookplace f0x6NDrAM1M38CWWNKSQ updated: book count = 3
# Bookplace fIaAIgqKoJfYNyYS7ZuV updated: book count = 1
# Bookplace fSGSMlgFI9f8SWQV7dwf updated: book count = 4
# Bookplace fZzVyBCPZWHtlpSbPhZF updated: book count = 8
# Bookplace gHa4NLU029dwXgJ5SY7w updated: book count = 30
# Bookplace gWnwXPXyYQHxd8QpUmQI updated: book count = 5
# Bookplace gmxdrBF3yUE94Nf0h3Yt updated: book count = 1
# Bookplace gsQl6USpMeD6son6K7tj updated: book count = 7
# Bookplace gvUBxsjEKDqobHlapkOP updated: book count = 1
# Bookplace hNtUJPhoO4HJ5769Hpo6 updated: book count = 7
# Bookplace hb8vJzx9tSp993ydhWGO updated: book count = 4
# Bookplace hbCOtyN5BBgiHJNg5n3q updated: book count = 5
# Bookplace iOJYNUIJM35n4OazwH1p updated: book count = 2
# Bookplace iPmhQ1LgTHfblmMYZAXl updated: book count = 3
# Bookplace iSDjpBByTPDnnCxjH2ys updated: book count = 2
# Bookplace ieyoN3VYQVGamRCnJNf0 updated: book count = 2
# Bookplace in86w00RxuFSBFCpjad8 updated: book count = 31
# Bookplace io491C5dRIjTBiktjqXQ updated: book count = 15
# Bookplace jGOOvqim0evq7oKwQklF updated: book count = 2
# Bookplace jI3H7WNI0DMtolltzoYv updated: book count = 4
# Bookplace jhXsBeP2PWTY6lgDFC4c updated: book count = 12
# Bookplace jktLRM7gCBExUHCyf7U3 updated: book count = 20
# Bookplace jy6eXdjwrm8Fq6skZiTo updated: book count = 1
# Bookplace k4BFKSw1xMDNf0CpQ4RI updated: book count = 2
# Bookplace kUNbjrohYxYdtMgPsrFb updated: book count = 3
# Bookplace kq8WCgRnPIkjxBlxsqa6 updated: book count = 5
# Bookplace lBVdhMQObS4QUjjD11UN updated: book count = 15
# Bookplace lixiljyObGp6AVIj2d8O updated: book count = 1
# Bookplace m4Aos0U24JagU083EHsV updated: book count = 7
# Bookplace mQgD2PUhtftdhff6xBnj updated: book count = 1
# Bookplace mROTuUyJyb0kaoG4dOqJ updated: book count = 24
# Bookplace mhQKRGBD6JnsTUpiQ57T updated: book count = 10
# Bookplace mmddLFUcXEcnyBj49A34 updated: book count = 2
# Bookplace mzqBMSJgQi0EIugANd4g updated: book count = 8
# Bookplace n0k3ePLqPnzYErEhEW1Z updated: book count = 1
# Bookplace n1czLAldOFKHuCVu9Gak updated: book count = 1
# Bookplace nGWxex2xACXVMscaJYZ0 updated: book count = 9
# Bookplace nmFZcC1X2Op8Lu7NLXiz updated: book count = 3
# Bookplace oFB1ZjktB99IIaMOHLWr updated: book count = 5
# Bookplace oPzuYHkCc675RjYKEtjC updated: book count = 5
# Bookplace oZm3Wqu9tXAKplFZpIot updated: book count = 16
# Bookplace obXzSTuV8wl4NjhYngbU updated: book count = 13
# Bookplace on2q7bQ4AwBQjGQgHazX updated: book count = 5
# Bookplace pFPTIMh8UtRX2dTyaW7u updated: book count = 31
# Bookplace pJE6nh3HnHHSUNIsXF3i updated: book count = 2
# Bookplace pk6irwaXMcVNgIi82hxC updated: book count = 3
# Bookplace poL7lF0CU2WzBiWS9UXA updated: book count = 3
# Bookplace ppdspB5zw9qns2qtT3x4 updated: book count = 4
# Bookplace pq2LlNvQZ9XCJVjn8j2n updated: book count = 23
# Bookplace pwtZWUAJcw3eRjq5FQb3 updated: book count = 3
# Bookplace q7toUcBtK7no4O333flj updated: book count = 9
# Bookplace qjQG9cznM63VGeQnLOYN updated: book count = 1
# Bookplace qqoRDuqzIQXzDWeESt5l updated: book count = 1
# Bookplace qvnRr7TNWXw9c7MGAqH0 updated: book count = 5
# Bookplace qzm7cpFTkqzz6NgmoGef updated: book count = 2
# Bookplace rF3Zq8kVhZFA6kgR5CUe updated: book count = 1
# Bookplace rR9j6sB5kwlhCcPxjR5d updated: book count = 2
# Bookplace rdcqx5Bhen3OWa6KyR6p updated: book count = 1
# Bookplace sEldcIoSUNxZL6cgHArV updated: book count = 1
# Bookplace sdFHC3zngk0KlF4jOsR5 updated: book count = 5
# Bookplace swkIXAtS29P99T9Fub1Y updated: book count = 2
# Bookplace swt76pRkQSJKYvPqW44M updated: book count = 6
# Bookplace t7SNiBXP2az1kYTuu2KT updated: book count = 21
# Bookplace tQ96kfvVdBnkyK2z3e59 updated: book count = 34
# Bookplace tUuk91GE3BTBbKPpHgrG updated: book count = 18
# Bookplace toEy0arcY56x0ODivhER updated: book count = 11
# Bookplace tsVWZF6QxtFpdb8NRQIO updated: book count = 14
# Bookplace twdmGPTCCOJMt0J3y0VQ updated: book count = 1
# Bookplace uXnsHge3I9wZIRlAhG0P updated: book count = 27
# Bookplace vEcMD4ML4oP2dH5K2DPp updated: book count = 1
# Bookplace vUm8GHv74fskDTb5hVSV updated: book count = 24
# Bookplace vXP2bhu23U7ZecvxiO6B updated: book count = 1
# Bookplace vgZD5dyrI7lCqmd2pM3p updated: book count = 1
# Bookplace w2ef3TEp3LTyYNDScOT8 updated: book count = 5
# Bookplace w6sqthMlEeMlhkkt5hPu updated: book count = 2
# Bookplace wDzsgsVactC6ULhJjHV0 updated: book count = 5
# Bookplace wTmOYie99KnIC5cmd9GW updated: book count = 36
# Bookplace wY0IvYekZldLqHhH2l8r updated: book count = 2
# Bookplace ww0rTEx5QBGycmORsDuJ updated: book count = 33
# Bookplace x7s9zs8iM6aADaVdzbU3 updated: book count = 3
# Bookplace xK9fkBcfYj0XouUoRVrA updated: book count = 3
# Bookplace xr1bRhGHGkTiHJRN8zzv updated: book count = 35
# Bookplace y61JIIBa33z6a863HAkV updated: book count = 1
# Bookplace yEXxBJNsiewTLAhepnQl updated: book count = 6
# Bookplace yRSFaTJWCd9odPe7QXRQ updated: book count = 1
# Bookplace yjZcTroaHa36Wk5BKUPr updated: book count = 29
# Bookplace z9gaNg8Wu53FwQdrGXGr updated: book count = 5
# Bookplace zBK48jG2j330sPkCXuFb updated: book count = 1
# Bookplace zFDcUvzvcs06VCYrBMWa updated: book count = 6
# Bookplace zQSbz9KgvJ51Au8pwHCq updated: book count = 2

# %%
# Script to assign language to the books

def has_cyrillic(text):
    return bool(re.search('[а-яА-Я]', text))

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

for b in books:
    data = b.to_dict()
    if has_cyrillic(data['title']):
        language = 'RUS'
    else:
        language = 'ENG'
 
    db.collection('books').document(b.id).update({'language': language})

# %%
# Script to add shelf image URL and outline coordinates

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

for b in books:
    data = b.to_dict()

    # Skip if book does not have photo or already converted
    if 'photo' not in data or data['photo'].startswith('https'):
        continue
     
    # Get URL for cloud storage path
    blob = bucket.blob(data['photo'])
    blob.make_public()
    
    # TODO: Get outline from json file

    # Store URL in firestore
    db.collection('books').document(b.id).update({'photo': blob.public_url})

# %%
# Script to add book outline coordinates

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#photos = db.collection('photos').limit(1).stream()
photos = db.collection('photos').stream()
photos = [p for p in photos]

for p in photos:
    data = p.to_dict()

    # Read JSON with recognition detailes
    json_file = data['photo'][:-3] + 'json'
    print('JSON file: ', json_file)
    
    blob = bucket.blob(json_file)
    
    if not blob.exists():
        print('BLOB does not exist', json_file)
        continue
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)
    
    recognized_blocks = results['recognized']
    #unrecognized_blocks = stored_results['unrecognized']

    for b in recognized_blocks:
        # Set the Firestore bookrecord
        #print('Book:', b.book.isbn, b.outline)

        # Find each book by ISBN and photo id
        docs = db.collection('books').where('photo_id', '==', p.id).where('isbn', '==', b.book.isbn).stream()
        docs = [d for d in docs]

        if len(docs) == 0:
            print('Book not found for %s, photo id %s, title %s' % (b.book.isbn, p.id, b.book.title))
        
        if len(docs) > 1:
            print('More than 1 book found for %s and photo id %s' % (b.book.isbn, p.id))

        # Update book with coordinates
        outline = [{'x': v[0], 'y': v[1]} for v in b.outline]
    
        for doc in docs:
            db.collection('books').document(doc.id).update({'outline': outline})
# Out:
# JSON file:  images/TysKYGb0XkbPjSpK9vI8G06fP4n1/1595233468425.json
# JSON file:  images/8t7W2VXfYVdLJiHLO4m1hp6JJG92/1549138655892.json
# JSON file:  images/24bjZCnWLFQ5VrmR5E8HZKC12IE2/1600103844627.json
# Book not found for 9789657454220, photo id 0HRgzb6AOCcE7fjNrwEV, title Isaiah 53, Explained, Mitch Glaser, Russian, ÐÑ Ñ Ñ ÐºÐ Ð
# Book not found for 9789657454220, photo id 0HRgzb6AOCcE7fjNrwEV, title Isaiah 53, Explained, Mitch Glaser, Russian, ÐÑ Ñ Ñ ÐºÐ Ð
# Book not found for 5867121348, photo id 0HRgzb6AOCcE7fjNrwEV, title Набоков о Набокове и прочем : Интервью. Рецензии. Эссе. / Ред.-сост. Николай Мельников. - Москва : Изд-во Независимая газ., 2002. - 700,
# Book not found for 9789657454220, photo id 0HRgzb6AOCcE7fjNrwEV, title Isaiah 53, Explained, Mitch Glaser, Russian, ÐÑ Ñ Ñ ÐºÐ Ð
# JSON file:  images/TcPOkClCeKTf2UDaFmGOWlcXxt23/1555826154473.json
# JSON file:  images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593018204373.json
# Book not found for 9785237014341, photo id 0SYzLN5iJpzVpgV7XQJ6, title ÐºÐ¾Ð½Ñ Ñ Ð¾Ð»Ñ  : Ñ Ð¾Ð¼Ð°Ð½
# JSON file:  images/vDWiB1lV2yYAAd8t7J3PkeKhRpH2/1590922212979.json
# Book not found for 9785733103037, photo id 0TpQuSgadZ4lycM6GV6q, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9785733103037, photo id 0TpQuSgadZ4lycM6GV6q, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9785733103037, photo id 0TpQuSgadZ4lycM6GV6q, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9785733103037, photo id 0TpQuSgadZ4lycM6GV6q, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9780898387117, photo id 0TpQuSgadZ4lycM6GV6q, title Animal Models in Cardiovascular Research
# Book not found for 9780970124548, photo id 0TpQuSgadZ4lycM6GV6q, title What To Do For Senior Health (English Edition) (What to Do for Health)
# Book not found for 9780373611959, photo id 0TpQuSgadZ4lycM6GV6q, title Select Fire (Executioner #195)
# JSON file:  images/mJzRVrG590cT0SxvnG503xqo6DB3/1552954621625.json
# JSON file:  images/24bjZCnWLFQ5VrmR5E8HZKC12IE2/1600103965236.json
# Book not found for 9780375502644, photo id 0eX4PP0z099MKwmZZe3w, title Moab Is My Washpot: An Autobiography
title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# JSON file:  images/noaN3PE4YRQcOa4dtTeaPl5d2zN2/1594216023639.json
# Book not found for 9785389176560, photo id AYAyh2pk43HRcItFpg6Y, title Приключения суперсыщика Калле Блумквиста
# JSON file:  images/zMxvIhjkpeYhknY56EMu0ybrBEN2/1593621281685.json
# JSON file:  images/odJ3ysUcgqRtaOWyYZq3BA5IZ892/1552464450502.json
# Book not found for 9785699031023, photo id B1tP6Q4MYPJqAjV1YVln, title Ð Ð¾Ð»Ñ Ñ Ð¾Ðµ Ð Ð»Ð¾ Ð Ð¼ÐµÐ»ÐºÐ Ðµ Ð¿Ð°ÐºÐ¾Ñ Ñ Ð [Bolshoje zlo i melkije pakosti]
# JSON file:  images/E99DVg4clPOnAJNEcfeRJvbJ7TL2/1553348673607.json
# JSON file:  images/4fO4yMFnf1UlHkW60JJswz8AHnU2/1548510815023.json
# JSON file:  images/8UJw0yj5ceVq2lDq5KQfLlB5UE52/1594656943413.json
# JSON file:  images/8UJw0yj5ceVq2lDq5KQfLlB5UE52/1594655153391.json
# JSON file:  images/1b2o7YjIkChyVOJK4EfbzvGpP4M2/1544380001928.json
# JSON file:  images/TysKYGb0XkbPjSpK9vI8G06fP4n1/1603375998616.json
# JSON file:  images/15REj1o7M5aj528uHTswiG4i5nr1/1590559079080.json
# Book not found for 9785457526587, photo id CBJmtGWS8AWuAC082Rlc, title От буквы и слога к иероглифу: системы письма в пространстве и времени
# Book not found for 9785001540540, photo id CBJmtGWS8AWuAC082Rlc, title Математика для дошкольников от А до Я : авторский курс подготовки к школе + пошаговая инструкция для взрослых :
# Book not found for 4680274042928, photo id CBJmtGWS8AWuAC082Rlc, title Учимся читать (Развивающие карточки. Готовимся к школе 5+)
# Book not found for 9785090582841, photo id CBJmtGWS8AWuAC082Rlc, title Адаптированная основная образовательная программа дошкольного образования для детей с тяжелыми нарушениями речи
# Book not found for 9780743261654, photo id CBJmtGWS8AWuAC082Rlc, title Шаг к успеху
# JSON file:  images/TBSx4AFS8cb6bGgh0zXgVfKAcgQ2/1547746875249.json
# JSON file:  images/noaN3PE4YRQcOa4dtTeaPl5d2zN2/1594216387353.json
# JSON file:  images/xem1khYLX0a3d7KuE2FTYa9QGcK2/1590140670901.json
# Book not found for 9780967576725, photo id CheWC5Jq2qrgZzIFKEWS, title J.D.'s Rustler
# Book not found for 9785733103037, photo id CheWC5Jq2qrgZzIFKEWS, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9780915658084, photo id CheWC5Jq2qrgZzIFKEWS, title The Taming of the C.A.N.D.Y. (Continuously Advertised, Nutritionally Deficient Yummies!) Monster
# Book not found for 9785733103037, photo id CheWC5Jq2qrgZzIFKEWS, title Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# Book not found for 9780153231520, photo id CheWC5Jq2qrgZzIFKEWS, title Pony Express to the Rescue Below Level Grade 3: Harcourt School Publishers Trophies (Trophies 03)
# Book not found for 9780970124548, photo id CheWC5Jq2qrgZzIFKEWS, title What To Do For Senior Health (English Edition) (What to Do for Health)
# Book not found for 9789562828420, photo id CheWC5Jq2qrgZzIFKEWS, title LIBERTAD Y RAZON. ROUSSEAU, HEGEL, MARX
# Book not found for 9785905155048, photo id CheWC5Jq2qrgZzIFKEWS, title Борис Ельцин. Новая Россия. Мир. Материалы 1 Всероссийского конкурса научных работ студентов, аспирантов и молодых ученых. Том 2
# JSON file:  images/8lLrYHjISUag3ZFHMvgR22dZgS92/1548770517400.json
# JSON file:  images/JotImqlat0ORS2fbGy10MU9sXXC2/1549225939800.json
# JSON file:  images/AZtM2Ncqj4TFaDE0GpeQE08qhZi2/1548659266503.json
# Book not found for 9785699128013, photo id ya0jRimqU2LSUFY93dsl, title Ð Ñ Ð Ð Ð½aÑ ÐµÐ Ð¾ Ñ Ð°Ñ Ñ
# JSON file:  images/noaN3PE4YRQcOa4dtTeaPl5d2zN2/1594214187454.json
# Book not found for 9785765443538, photo id yhO2obJioizGJinDK16r, title Ловушка для блондинов
# Book not found for 9785020252608, photo id yhO2obJioizGJinDK16r, title Словарь якутского языка : в 3 томах / Э. К. Пекарский ; Российская акад. наук. - 3-е изд., испр. и доп. - Санкт-Петербург : Наука, 2008-. - 25 см.
# Т. 3, вып. 10-13: Т. 3. Вып. 10-13. Та - Ычыңы. - Санкт-Петербург : Наука, 2008-.; ISBN 978-5-02-025260-8
# JSON file:  images/15REj1o7M5aj528uHTswiG4i5nr1/1590558940200.json
# Book not found for 9785171149543, photo id zLsGzpSMOq9tOtrLSeUB, title Алфавит с трафаретами. Учим буквы, учимся писать
# Book not found for 9785971050261, photo id zLsGzpSMOq9tOtrLSeUB, title Практическое руководство к художественному чтению. Практический курс для самообразования. С приложением образцовой хрестоматии
# Book not found for 9785001007609, photo id zLsGzpSMOq9tOtrLSeUB, title Как найти деньги для вашего бизнеса. Пошаговая инструкция по привлечению инвестиций
# Book not found for 9785994908617, photo id zLsGzpSMOq9tOtrLSeUB, title Академия солнечных зайчиков. 4-5 лет. УЧИМ ЦИФРЫ (Развивающие задания и игра). Соответствует ФГОС ДО
# Book not found for 9785457526587, photo id zLsGzpSMOq9tOtrLSeUB, title От буквы и слога к иероглифу: системы письма в пространстве и времени
# Book not found for 9785000264027, photo id zLsGzpSMOq9tOtrLSeUB, title Русский язык. ЕГЭ. Двадцать ступеней к успеху
# Book not found for 9785519505017, photo id zLsGzpSMOq9tOtrLSeUB, title Caesar and Cleopatra (Paperback)
# Book not found for 9785090582841, photo id zLsGzpSMOq9tOtrLSeUB, title Адаптированная основная образовательная программа дошкольного образования для детей с тяжелыми нарушениями речи
# JSON file:  images/vSXeuTQDMlNBsuwbc51BAKng5Hk2/1549468879485.json
# JSON file:  images/1VHBTFgSb0ay5I3jZS3htp16KrT2/1592265067919.json
# JSON file:  images/NW3sjiR8NQT6OwZyRFwCEmgbZ8j1/1549138813877.json
# JSON file:  images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593018213743.json
# Book not found for 9785237014341, photo id zcn83PJEFx4CMbTxIuhk, title ÐºÐ¾Ð½Ñ Ñ Ð¾Ð»Ñ  : Ñ Ð¾Ð¼Ð°Ð½
# JSON file:  images/0lCFhlFm4pUhMnaUfbB3bDjw1pW2/1558878716905.json

# %%
# Script to calculate book rectangle and place for the book cover

from shapely.geometry import Polygon

P = Polygon([[0, 0], [1, 0], [1, 1], [0.000001, 1], [0, 0.999999]])

print(P.centroid)
#POINT (0.5 0.5)


# For each book calculate min rectangle

# Store min rectangle in a form of x,y, h, w, alpha

# Calculate
# Out:
# POINT (0.50000000000025 0.49999999999975)

# %%
# Procedure to calculate best place for book cover image within the shelf photo

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Aspect ration of book cover (Width / Height)
ratio = 2.0 / 3.0 

def imread_blob(blob):
    img = cv2.imdecode(np.asarray(bytearray(blob.download_as_string()), dtype=np.uint8), cv2.IMREAD_COLOR)
    return img

# Function to fit biggest rectangle with given aspect ratio
def fit(ratio, contour):
    
    # TODO: Make it working for triangles and polygons
    # For each point of the contour draw two diagonals of the potential rectangle
    # Discard diagnals which are outside the angle of enclosing sides
    # Find intersection of diagonal with the rest of the sides
    # Calculate complimentary diagonal and check if corners are inside the photo
    # Choose biggest candidate, if several are biggest join them together
    
    width, height = abs(contour[2,0] - contour[0,0]), abs(contour[2,1] - contour[0,1])
    
    return min(width, height * ratio)


# Function to determine the biggest free part outside of book image
def cover(width, height, contour):
    min_x, max_x = min(contour[:, 0]), max(contour[:, 0])
    min_y, max_y = min(contour[:, 1]), max(contour[:, 1])
    
    if min_x > width - max_x:
        candidate1 = np.array([[0, 0], [0, height], [min_x, height], [min_x, 0]])
    else:
        candidate1 = np.array([[max_x, 0], [max_x, height], [width, height], [width, 0]])

    if min_y > height - max_y:
        candidate2 = np.array([[0, 0], [0, min_y], [width, min_y], [width, 0]])
    else: 
        candidate2 = np.array([[0, max_y], [0, height], [width, height], [width, max_y]])

    if fit(ratio, candidate1) > fit(ratio, candidate2):
        cover = candidate1
    else: 
        cover = candidate2
        
    return cover

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#photos = db.collection('photos').limit(5).stream()
photos = db.collection('photos').stream()
photos = [p for p in photos]

for p in photos:
    data = p.to_dict()

    # Read JSON with recognition detailes
    json_file = data['photo'][:-3] + 'json'
    print('JSON file: ', json_file)
    
    blob = bucket.blob(json_file)
    
    if not blob.exists():
        print('BLOB does not exist', json_file)
        continue
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)
    
    recognized_blocks = results['recognized']
    #unrecognized_blocks = stored_results['unrecognized']
    
    uri = results['uri']

    image_blob = bucket.blob(uri)
    img = imread_blob(image_blob)

    height, width = img.shape[0:2]
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)

    for b in recognized_blocks:
        # Update book with coordinates
        outline = np.array(b.outline)
        
        place_for_cover = cover(width, height, outline)
        
        spine = cv2.minAreaRect(outline)
        spine = np.int0(cv2.boxPoints(spine))

        #print('Cover:', place_for_cover)
        #print('Bookspine:', spine)
        #cv2.drawContours(img, np.array([outline]), 0, (0, 0, 255), 15)
        #cv2.drawContours(img, np.array([place_for_cover]), 0, (0, 255, 0), 15)
        #cv2.drawContours(img, np.array([spine]), 0, (255, 0, 0), 15)
        #plt.imshow(img)

        # Find each book by ISBN and photo id
        docs = db.collection('books').where('photo_id', '==', p.id).where('isbn', '==', b.book.isbn).stream()
        docs = [d for d in docs]

        if len(docs) == 0:
            print('Book not found for %s, photo id %s, title %s' % (b.book.isbn, p.id, b.book.title))
        
        if len(docs) > 1:
            print('More than 1 book found for %s and photo id %s' % (b.book.isbn, p.id))

        # Update book with coordinates
        spine = [{'x': v[0], 'y': v[1]} for v in spine.tolist()]
        place_for_cover = [{'x': v[0], 'y': v[1]} for v in place_for_cover.tolist()]
            
        #print('Cover:', place_for_cover)
        #print('Bookspine:', spine)

        for doc in docs:
            db.collection('books').document(doc.id).update({'spine': spine, 'place_for_cover': place_for_cover})
# Out:
# JSON file:  images/TcPOkClCeKTf2UDaFmGOWlcXxt23/1555826154473.json
# Cover: [{'x': 0, 'y': 0}, {'x': 0, 'y': 768}, {'x': 799, 'y': 768}, {'x': 799, 'y': 0}]
# Bookspine: [{'x': 853, 'y': 596}, {'x': 798, 'y': 594}, {'x': 808, 'y': 242}, {'x': 863, 'y': 244}]

# %%
# Script to count recognized books for a period

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('shelves').where('id', '>=', '1593006003543').stream()

count = 0
for i, b in enumerate(books):
    data = b.to_dict()
    if data['recognized'] is not None and data['recognized'] > 0:
        print('Recognized %d %s' % (data['recognized'], data['image']))
        count += data['recognized'] 

print('TOTAL RECOGNIZED:', count)
# Out:
# Recognized 8 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006003543.jpg
# Recognized 7 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006083473.jpg
# Recognized 6 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006110917.jpg
# Recognized 5 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006125181.jpg
# Recognized 13 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006137290.jpg
# Recognized 17 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593006145977.jpg
# Recognized 1 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593009273328.jpg
# Recognized 3 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593009413374.jpg
# Recognized 4 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593017157610.jpg
# Recognized 10 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593017363983.jpg
# Recognized 5 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593017975066.jpg
# Recognized 1 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593018196053.jpg
# Recognized 2 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593018204373.jpg
# Recognized 1 images/IEbwfDjHQcQkTm4uGDMCQfMsGuY2/1593018213743.jpg
# Recognized 7 images/ZN7Ux33RKWaaRT8ENjG0ToZvWzS2/1593278933780.jpg
# Recognized 1 images/ZN7Ux33RKWaaRT8ENjG0ToZvWzS2/1593362741530.jpg
# TOTAL RECOGNIZED: 91

# %%
emails = ['webdoedie@gmail.com',
'camilleguzman.10880@gmail.com',
'angiewelch.88990@gmail.com',
'samueldixon.34540@gmail.com',
'skaplichniy@gmail.com',
'sof5859@yandex.ru',
'gingeralina@mail.ru',
'kanhai.kcc@gmail.com',
'anbarbery@gmail.com',
'mchusick@gmail.com',
'thomashibbard89@gmail.com',
'kolbasa12393@mail.ru',
'bdinh14@gmail.com',
'ashima.odsharma@gmail.com',
'mart.a.o.3393@gmail.com',
'poleshchukolala@gmail.com',
'pelageya99@gmail.com',
'topoeva.n@yandex.ru',
'kamiomisuzu@yandex.ru',
'avtarcute777@gmail.com',
'romanziouzev@gmail.com',
'd.tarusov@gmail.com',
'melaniedarklove@gmail.com',
'valentina.vosk@gmail.com',
'monkphx@gmail.com',
'mayisaru@gmail.com',
'zaxquit@gmail.com',
'nivadow@gmail.com',
'ranjansahabandu@gmail.com',
'taras8055@gmail.com',
'xodacevich@yandex.ru',
'danmlisa2@gmail.com',
'acar_4788@hotmail.com',
'jianing.qi@gridmachina.com',
'roydiego@gmail.com',
'julienhardy94@gmail.com',
'gaivoronskystan@gmail.com']

geolocator = Nominatim(user_agent="Biblosphere")

for e in emails:
    auth_user = auth.get_user_by_email(e)
    if auth_user is None:
        print('!!! User auth missed for', e)
        continue
    user = db.collection('users').document(auth_user.uid).get()
    if user is None:
        print(f'!!! User record missed for {auth_user.display_name} ({e})')
        continue
    
    data = user.to_dict()
    
    # Find boos and wishes
    records = db.collection('bookrecords').where('holderId', '==', auth_user.uid).stream()
    records = [b.to_dict() for b in records]

    books = [b for b in records if not b['wish']]
    wishes = [b for b in records if b['wish']]

    # Skip if no books/wishes added
    if len(records) == 0:
        continue

    print('-------------------------------------------------------------')
    print(f'{auth_user.display_name} ({e})')

    # Show location
    location = geolocator.reverse(f"{records[0]['location']['geopoint'].latitude}, {records[0]['location']['geopoint'].longitude}", language='en', addressdetails=True)
    #print(location.raw)
    country = location.raw['address']['country']

    if 'state' in location.raw['address']:
        state = location.raw['address']['state']
    elif 'state' in location.raw['address']:
        state = location.raw['address']['state_district']
    else:
        state = location.raw['address']['city']
    
    if 'city' in location.raw['address']:
        city = location.raw['address']['city']
    elif 'town' in location.raw['address']:
        city = location.raw['address']['town']
    elif 'suburb' in location.raw['address']:
        city = location.raw['address']['suburb']
    else:
        city = location.raw['address']['county']
    print(f'LOCATION: {city}, {state}, {country}')
    print(f'ADDRESS: {location.raw["address"]}')

    # Show books
    if len(books) > 0:
        print('BOOKS:')
        for b in books:
            print(f'"{b["title"]}" by {",".join(b["authors"])}')
            
    # Show wishes
    if len(wishes) > 0:
        print('WISHES:')
        for b in wishes:
            print(f'"{b["title"]}" by {",".join(b["authors"])}')

    # TODO: Show chats
# Out:
# -------------------------------------------------------------
# Kanhai Kumar (kanhai.kcc@gmail.com)
# LOCATION: Bengaluru, Karnataka, India
# ADDRESS: {'neighbourhood': 'Vaikuntam Layout', 'suburb': 'Dodda Nekkundi', 'city_district': 'Mahadevapura Zone', 'city': 'Bengaluru', 'county': 'Bangalore East', 'state_district': 'Bangalore Urban', 'state': 'Karnataka', 'postcode': '560 037', 'country': 'India', 'country_code': 'in'}
# BOOKS:
# "Paradise Park" by Allegra Goodman
# "The Power of Logical Thinking: Easy Lessons in the Art of Reasoning...and Hard Facts About Its Absence in Our Lives" by Marilyn Vos Savant
# "Wild Designs: A Novel" by Katie Fforde
# "Proud Mary" by Iris Gower
# "Falling for You" by Jill Mansell
# "English Is Easy" by Chetananand Singh
# -------------------------------------------------------------
# Thomas Hibbard (thomashibbard89@gmail.com)
# LOCATION: Salta, Salta, Argentina
# ADDRESS: {'house_number': '453', 'road': 'General José María Paz', 'city_district': 'B Calixto Gauna', 'city': 'Salta', 'municipality': 'Municipio de Salta', 'state_district': 'Capital', 'state': 'Salta', 'postcode': '4.400', 'country': 'Argentina', 'country_code': 'ar'}
# BOOKS:
# "The Book of Barely Imagined Beings" by Caspar Henderson
# "The Runaway Jury" by JOHN GRISHAM
# "Undaunted Courage: Meriwether Lewis Thomas Jefferson and the Opening of the American West" by Stephen Ambrose
# "The Cultural Lives of Whales and Dolphins" by Hal Whitehead;Luke Rendell
# "Fundacion E Imperio/Foundation and Empire" by Isaac Asimov
# "Segunda Fundacion/Second Foundation" by Isaac Asimov
# "Fundacion" by Isaac Asimov
# WISHES:
# "Dat es K?lle, wie et l?v. R?mcher un Verz?llcher us K?lle un rundser?m" by
# "å° èª PSYCHO-PASS ã µã ¤ã  ã  ã  /ã ¼ã  å  å  ã ®ã ªã  æ ªç " by
# "The Rupa Laughter Omnibus" by Ruskin Bond
# "Revolution 2020: Love, Corruption, Ambition" by Chetan Bhagat
# "South Indian Hindu Festivals and Traditions" by Maithily Jagannathan
# "The Ruskin Bond Children's Omnibus" by Ruskin Bond
# "Mahatma Gandhi : His Life and Time" by Louis Fischer
# "HOMI JAHANGIR BHABHA(Hindi)" by GANESHAN VENKATRAMAN
# "Wings of Fire: An Autobiography of APJ Abdul Kalam" by A. P. J Abdul Kalam
# "Mahatma Gandhi: His Life and Ideas" by Charles F. Andrews
# "Freedom Fighters of India (in Four Volumes)" by M G Agrawal
# "How I Taught My Grandmother to Read and other Stories" by Sudha Murty
# "Healthy Breakfast" by Tarla Dalal
# "Mahabharata: The Kuru princes" by
# "The Bhagavadgita" by S. Radhakrishnan
# "Complete/convenient" by Ketan Bhagat
# -------------------------------------------------------------
# Александра Мартынова (mart.a.o.3393@gmail.com)
# LOCATION: Srednaya Rogatka, Saint Petersburg, Russia
# ADDRESS: {'house_number': '27', 'road': 'улица Фрунзе', 'suburb': 'Srednaya Rogatka', 'municipality': 'округ Московская застава', 'state_district': 'Московский район', 'state': 'Saint Petersburg', 'region': 'Northwestern Federal District', 'postcode': '190000', 'country': 'Russia', 'country_code': 'ru'}
# BOOKS:
# "Дом, в котором..." by Mariam Petrosyan
# "Усвятские шлемоносцы (сборник)" by Евгений Носов
# -------------------------------------------------------------
# Настя Топоева (topoeva.n@yandex.ru)
# LOCATION: Заневское городское поселение, Leningrad oblast, Russia
# ADDRESS: {'building': 'Дом у Каштановой аллеи', 'house_number': '1', 'road': 'Областная улица', 'city': 'Заневское городское поселение', 'county': 'Vsevolozhsky District', 'state': 'Leningrad oblast', 'region': 'Northwestern Federal District', 'postcode': '188689', 'country': 'Russia', 'country_code': 'ru'}
# BOOKS:
# "Есть, молиться, любить" by Элизабет Гилберт
# -------------------------------------------------------------
# Kate Lisovets (kamiomisuzu@yandex.ru)
# LOCATION: Pargolovo, Saint Petersburg, Russia
# ADDRESS: {'suburb': 'Torfyanoe', 'town': 'Pargolovo', 'state_district': 'Vyborgsky District', 'state': 'Saint Petersburg', 'region': 'Northwestern Federal District', 'postcode': '194362', 'country': 'Russia', 'country_code': 'ru'}
# BOOKS:
# "Письма к С. А. Толстой 1887-1910" by Л.Н. Толстой
# -------------------------------------------------------------
# avtar ashim (avtarcute777@gmail.com)
# LOCATION: Barsha Heights, Dubai, United Arab Emirates
# ADDRESS: {'building': 'Al Ghozlan 1', 'house_number': '1', 'road': '4 Street', 'suburb': 'Barsha Heights', 'state': 'Dubai', 'postcode': '34327', 'country': 'United Arab Emirates', 'country_code': 'ae'}
# BOOKS:
# "Zero to One: Notes on Startups, or How to Build the Future" by Peter Thiel, Blake  Masters
# -------------------------------------------------------------
# Zyu Roman (romanziouzev@gmail.com)
# "Money Road" by Garth Turner
# "The Entitlement Trap" by Richard Eyre,Linda Eyre
# "Harry Potter and the Cursed Child" by J. K. Rowling,Jack Thorne,John Tiffany
# "Steve Jobs" by Walter Isaacson
# "The Innovators: How a Group of  Hackers, Geniuses and Geeks Created the Digital Revolution" by Walter Isaacson
# "Trust Me, I'm Lying" by Ryan Holiday
# "Fight Less, Love More" by Laurie Puhn
# "All the Kremlin's Men" by Mikhail Zygar
# "Crisis Point" by Trent Lott,Tom Daschle,Jon Sternfeld
# "Focus (HBR Emotional Intelligence Series)" by Harvard Business Review,Daniel Goleman,Heidi Grant,Amy Jen Su,Rasmus Hougaard,Maura Nevel Thomas
# -------------------------------------------------------------
# Melanie DarkLove (melaniedarklove@gmail.com)
# LOCATION: Fili-Davydkovo District, Moscow, Russia
# ADDRESS: {'house_number': '35 к2', 'road': 'Кастанаевская улица', 'quarter': 'Давыдково', 'suburb': 'Fili-Davydkovo District', 'state_district': 'Western Administrative Okrug', 'state': 'Moscow', 'region': 'Central Federal District', 'postcode': '121108', 'country': 'Russia', 'country_code': 'ru'}
# BOOKS:
# "Над пропастью во ржи" by Джером Дэвид Сэлинджер
# "Франц Кафка. Замок" by Кафка Франц
# -------------------------------------------------------------
# Ernesto Monge (monkphx@gmail.com)
# LOCATION: Hermosillo, Sonora, Mexico
# ADDRESS: {'road': 'Fidel Velazco', 'neighbourhood': 'Metalera', 'hamlet': 'Buenos Aires 1', 'city': 'Hermosillo', 'county': 'Hermosillo', 'state': 'Sonora', 'postcode': '83000', 'country': 'Mexico', 'country_code': 'mx'}
# BOOKS:
# "Healthy Cooking for Kids: Building Blocks for a Lifetime of Good Nutrition" by Shelly Null
# "The Princeton Review: Word Smart : Building an Educated Vocabulary (Princeton Review (Hardcover))" by Adam Robinson
# "The Man Who Invented the Twentieth Century: Nikola Tesla, Forgotten Genius of Electricity" by Robert Lomas
# "Primer on the Metabolic Bone Disease and Disorders of Mineral Metabolism" by Murray J. Favus
# "Recetas El Poder del Metabolismo" by Frank Suarez
# "Le jour ne se leÌ ve pas pour nous: Roman (French Edition)" by Robert Merle
# "Los Nuevos Tests de Seleccion" by Gilles Azzopardi
# WISHES:
# "The diaries of Lord Louis Mountbatten, 1920-1922: Tours with the Prince of Wales" by Louis Mountbatten Mountbatten of Burma
# -------------------------------------------------------------
# Niva Dow (nivadow@gmail.com)
# LOCATION: New York, New York, United States of America
# ADDRESS: {'house_number': '441', 'road': '16th Street', 'neighbourhood': 'Park Slope', 'suburb': 'Brooklyn', 'hamlet': 'South Battery', 'city': 'New York', 'county': 'Kings County', 'state': 'New York', 'postcode': '11215', 'country': 'United States of America', 'country_code': 'us'}
# BOOKS:
# "The Design of Everyday Things" by Donald A. Norman
# WISHES:
# "Burnout" by Emily Nagoski,Amelia Nagoski
# -------------------------------------------------------------
# Taras Zagibalov (taras8055@gmail.com)
# LOCATION: Helsinki, Helsinki, Finland
# ADDRESS: {'house_number': '20', 'road': 'William Street', 'neighbourhood': 'Financial District', 'suburb': 'Manhattan', 'city': 'Manhattan Community Board 1', 'county': 'New York County', 'state': 'New York', 'postcode': '10005', 'country': 'United States of America', 'country_code': 'us'}
# BOOKS:
# "The BEAUTIFUL &amp; DAMNED (REISSUE) : The Life of Mathematical Genuis and Nobel Laureate John Nash (A Scribner classic)" by F. Scott Fitzgerald
# "Protestant Ethic and the Spirit of Capitalism" by Max Weber
# "END OF HISTORY AND THE LAST MAN" by Francis Fukuyama
# "Gulag Archipelago 1918-1956 (An Experiment in Literary Investigation V-VII)" by Aleksandr I. Solzhenitsyn
# "Ethics (Oxford Readers)" by Peter Singer
# "Vita Sexualis" by Ralph M. Leck
# "Programmed Visions" by Wendy Hui Kyong Chun
# "The Algebraic Mind" by Gary F. Marcus
# "Control and Freedom" by Wendy Hui Kyong Chun
# "Who Was Jacques Derrida?: An Intellectual Biography" by Mikics, David
# "The Paris Review Book of People with Problems" by The Paris Review
# "Civilization and Its Discontents" by Sigmund Freud
# "Naked Economics: Undressing the Dismal Science" by Charles Wheelan
# "Discipline and punish: The birth of the prison" by Michel Foucault
# "Max Weber" by Reinhard Bendix
# "Order of Things: An Archaeology of the Human Sciences (Routledge Classics)" by Michel Foucault
# "The Politics of Rights" by Stuart A. Scheingold
# "An Introduction to Information Theory" by John R. Pierce
# "The Conquest of Bread" by Peter Kropotkin
# "Bakunin: Statism and Anarchy" by Mikhail Aleksandrovich Bakunin,Michael Bakunin
# "Snow Crash" by Neal Stephenson
# "A Gentleman in Moscow" by Amor Towles
# "Madness and Civilization" by Michel Foucault
# "The Annotated Lolita" by Vladimir Nabokov
# "Personal Anthology" by Jorge Luis Borges
# "Discourse Networks 1800/1900" by Friedrich A. Kittler
# "The castle (Schocken classics)" by Franz Kafka
# "Distant Star" by Roberto Bolaño,Roberto Bolano,Dr Chris Andrews
# "Beautiful Data" by Orit Halpern
# "Deconstruction in a Nutshell: A Conversation With Jacques Derrida (Perspectives in Continental Philosophy)" by Jacques Derrida
# "Stories of power and purpose" by Anderson, Leland E
# "Heidegger" by John Richardson
# "Missing Out" by Adam Phillips
# "Lonely Planet Cuba" by Lonely Planet,Brendan Sainsbury,Carolyn McCarthy
# "Titan A.E. - Una Aventura Espacial (Spanish Edition)" by Frantz, Jennifer
# -------------------------------------------------------------
# Julien Hardy (julienhardy94@gmail.com)
# LOCATION: San Mateo, Alajuela Province, Costa Rica
# ADDRESS: {'road': 'Calle Machuca', 'residential': 'Resid. La Ecovilla', 'town': 'San Mateo', 'county': 'Cantón San Mateo', 'state': 'Alajuela Province', 'postcode': '20401', 'country': 'Costa Rica', 'country_code': 'cr'}
# BOOKS:
# "Bhagavad-Gita: The Song of God" by Swami Prabhavananda
# -------------------------------------------------------------
# Стасио Гайворонски (gaivoronskystan@gmail.com)
# LOCATION: Tbilisi, Tbilisi, Georgia
# ADDRESS: {'house_number': '23', 'road': 'Amaghleba Street', 'quarter': 'Zemo Vera', 'suburb': 'Mtatsminda District', 'city': 'Tbilisi', 'postcode': '0046', 'country': 'Georgia', 'country_code': 'ge'}
# BOOKS:
# "Little Women,: Or, Meg, Jo, Beth and Amy, Parts I and II" by Louisa May Alcott
# "Persepolis : The Story of a Childhood (Alex Awards (Awards))" by MARJANE SATRAPI
# "Houghton Mifflin Reading: The Nation's Choice: Reader's Library Grade 4 Theme 1 - Journeys" by HOUGHTON MIFFLIN
# "Animal Models in Cardiovascular Research" by Gross, D.R.
# "Chasovnikaryat (Ð§Ð°Ñ Ð¾Ð Ð½Ð ÐºÑ Ñ , Ð Ð¾Ð ÐµÐ»Ð°): Bulgarian Edition (Ð Ñ Ð»Ð Ð°Ñ Ñ ÐºÐ¾ Ð Ð Ð Ð°Ð½Ð Ðµ)" by Erishkigal, Anna
# "Игра в бисер" by Гессе Герман
# "Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian" by Leonid Soroka (Ð ÐµÐ¾Ð½Ð Ð Ð¡Ð¾Ñ Ð¾ÐºÐ°)
# "Ð Ñ Ð°Ð Ð Ð»Ð° Ð¿Ñ Ð¾Ñ ÐµÐ Ñ Ñ Ñ  Ð Ð¾Ð½Ñ Ñ Ð»Ñ Ñ Ð°Ñ Ð Ð Ð½Ð¾Ð Ð¾ Ñ Ð¾Ð ÐµÑ Ð°Ð½Ð Ñ  Ð¿Ð¾ Ð"Ð¾Ð Ð¾Ð Ð¾Ñ Ñ  Ð¾Ð± Ð Ð½Ñ Ð°Ñ ÐºÑ Ð ÐºÐµ Ð Ð Ð¾Ð¼Ð Ñ ÐµÑ Ð° Ð¿Ð¾ Ð¾Ñ Ñ Ð°Ð½Ðµ Ð¾ÐºÑ Ñ Ð Ð°Ñ Ñ ÐµÐ Ñ Ñ ÐµÐ" by Antarctic Treaty Consultative Meeting,
# WISHES:
# "К нам едет Пересвет" by Прилепин Захар

# %%
# Admin script to collect all unique locations for the website

db = firestore.client()

markers = pd.DataFrame(columns=('lat', 'lng'))

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('bookrecords').stream()

for i, b in enumerate(books):
    data = b.to_dict()
    if data['location'] is not None:
        #print({'lat': data['location']['geopoint'].latitude, 'lng': data['location']['geopoint'].longitude})
        markers.loc[i] = [data['location']['geopoint'].latitude, data['location']['geopoint'].longitude]

print('Full length:', len(markers))
markers.drop_duplicates(inplace=True)
print('Without duplicates:', len(markers))

json = markers.to_json(orient='records')
#print(json)

with open('locations.json', 'w') as f:
    f.write(json)
# Out:
# Full length: 1948
# Without duplicates: 623

# %%
# Admin script to get all books around the location

from math import pi, sin, cos, atan2, sqrt

# Function to calculate distance between two geo-points
def distance_between(lat1, lon1, lat2, lon2):
    r = 6378.137 # Radius of earth in KM
    d_lat = lat2 * pi / 180 - lat1 * pi / 180
    d_lon = lon2 * pi / 180 - lon1 * pi / 180
    a = sin(d_lat/2) * sin(d_lat/2) + cos(lat1*pi/180) * cos(lat2*pi/180) * sin(d_lon/2) * sin(d_lon/2)
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = r * c

    return distance

#lat, lon, distance = 60.1699, 24.9384, 80.0 # Helsinki
lat, lon, distance = 25.2048, 55.2708, 80000.0 # Dubai


db = firestore.client()

#books = db.collection('bookrecords').limit(10).stream()
books = db.collection('bookrecords').stream()

count = 0
for i, b in enumerate(books):
    data = b.to_dict()
    if data['location'] is not None:
        d = distance_between(data['location']['geopoint'].latitude, data['location']['geopoint'].longitude, lat, lon)
        if d < distance and data['ownerId'] != 'SJIyyqAGPTcXWaVnha5pWe4kuIC3':
            #print('%.2f %s %s [%s]' % (d, data['authors'], data['title'], data['ownerId']))
            count += 1
        
print(count, 'books found')
# Out:
# 2464 books found

# %%
Robert T. Kiyosaki: Rich Dad, Poor Dad: What the Rich Teach Their Kids About Money--That the Poor and Middle Class Do Not!
Peter Thiel, Blake  Masters: Zero to One: Notes on Startups, or How to Build the Future

# %%
# Admin script to get all book exchanges and its context

def print_chat(u1, u2):
    chat_id = ':'.join(sorted([u2,u1]))
    
    messages = db.collection('messages').document(chat_id).collection(chat_id).order_by('timestamp').stream()
    for m in messages:
        data = m.to_dict()
        print(data['content'])

db = firestore.client()

books = db.collection('bookrecords').where('lent', '==', True).stream()

for i, b in enumerate(books):
    data = b.to_dict()
    # Exclude testing ids
    if data['ownerId'] == 'rzvlcuAdFVS6238qqse4B4EjvUA3' or data['ownerId'] == 'oyYUDByQGVdgP13T1nyArhyFkct1'  or \
        data['holderId'] == 'rzvlcuAdFVS6238qqse4B4EjvUA3' or data['holderId'] == 'oyYUDByQGVdgP13T1nyArhyFkct1':
        continue
        
    # Print book details
    print('***************************************************************************')
    print('BOOK: %s' % data['title'])
        
    # Print names and emails of the users
    owner = auth.get_user(data['ownerId'])
    if owner is not None:
        print('BOOK OWNER: %s (%s)' % (owner.display_name, owner.email))
        
    holder = auth.get_user(data['holderId'])
    if holder is not None:
        print('BOOK HOLDER: %s (%s)' % (holder.display_name, holder.email))
        
        
    print_chat(data['holderId'], data['ownerId'])
    
    # Print latest conversation of the users
# Out:
# ***************************************************************************
# BOOK: Письма к С. А. Толстой 1887-1910
# BOOK OWNER: Марат Сабиров (avkhatovich@gmail.com)
# BOOK HOLDER: Екатерина Баранова (baranova-1@bk.ru)
# ***************************************************************************
# BOOK: Ð Ñ Ð¾ Ð¼Ñ Ñ Ð¾Ð½ÐºÐ° Ð Ð¾Ð½Ð°, Ð Ñ Ð¾ Ð°Ð¼Ñ Ñ ÐµÑ Ð Ð°Ð¼Ñ ÐºÐ¾Ð Ð¾ ÐºÐ¾Ñ Ð° Ð¢Ð¾Ð¼Ð°, Ð Ð Ñ Ð¾ Ñ Ð°Ð Ð½Ð¾Ðµ Ð Ñ Ñ Ð Ð¾Ðµ (Ð ÐµÑ Ñ ÐºÐ Ðµ Ñ Ñ Ð Ñ Ð ) | Pro mishonka Shona, Pro amsterdamskogo kota Toma i Pro raznoe drugoe (children poetry) | Russian
# BOOK OWNER: Анастасия Приказчикова (prikazav@gmail.com)
# BOOK HOLDER: Алена Рудюк (alenar91@mail.ru)
# ***************************************************************************
# BOOK: Ампир V. Vампир / Виктор Пелевин. - Москва : Эксмо, 2010. - 408 с.; 21 см. - (Новый Пелевин).; ISBN 978-5-699-40130-7
# BOOK OWNER: Людмила Дадова (dadovalyuda@rambler.ru)
# BOOK HOLDER: Вероника Эссен (None)
# ***************************************************************************
# BOOK: Hygge. Секрет датского счастья
# BOOK OWNER: Сергей Щетин (schetin.sv@gmail.com)
# BOOK HOLDER: Olga Konnova (olakon@gmail.com)
# ***************************************************************************
# BOOK: Чужак
# BOOK OWNER: Алла Здравствуйте (zdravstvujtealla@gmail.com)
# BOOK HOLDER: Ирина С (zadanje6@yandex.ru)
# Здравствуйте. Недавно только установила это приложение, пока разбиралась, случайно нажала не ту кнопку, вы могли бы книгу "Чужак" обратно "забрать"?
# ***************************************************************************
# BOOK: Как быть, когда все не так, как хочется
# BOOK OWNER: Julia Chernyaeva (caledonia17@yandex.ru)
# BOOK HOLDER: Женя Петрова (gekaka88@gmail.com)
# ***************************************************************************
# BOOK: Три чашки чая
# BOOK OWNER: Diana GreenMuse (dianagreenmuse@gmail.com)
# BOOK HOLDER: Лейсан Бикмухаметова (lcat555@mail.ru)
# ***************************************************************************
# BOOK: Техники Радикального Прощения. Радикальное Проявление
# BOOK OWNER: Victoria Yavorskaya (ya.victoria95@gmail.com)
# BOOK HOLDER: Женя Петрова (gekaka88@gmail.com)
# ***************************************************************************
# BOOK: What They Don't Teach You at Harvard Business School
# BOOK OWNER: Dmitry Petunin (sunmitrich@narod.ru)
# BOOK HOLDER: Vera Vostianova (vostyanova.vera@gmail.com)
# ***************************************************************************
# BOOK: Прежде чем начать свой бизнес
# BOOK OWNER: Dmitry Petunin (sunmitrich@narod.ru)
# BOOK HOLDER: Vera Vostianova (vostyanova.vera@gmail.com)
# ***************************************************************************
# BOOK: Chasovnikaryat (Ð§Ð°Ñ Ð¾Ð Ð½Ð ÐºÑ Ñ , Ð Ð¾Ð ÐµÐ»Ð°): Bulgarian Edition (Ð Ñ Ð»Ð Ð°Ñ Ñ ÐºÐ¾ Ð Ð Ð Ð°Ð½Ð Ðµ)
# BOOK OWNER: Dmitry Petunin (sunmitrich@narod.ru)
# BOOK HOLDER: Dizy Flores (dizyflores@gmail.com)
# ***************************************************************************
# BOOK: Я не умею худеть
# BOOK OWNER: Ирина Лящук (ira79166576892@gmail.com)
# BOOK HOLDER: Alexandra Kartashova (laddering@gmail.com)

# %%
# Admin script to check messages

db = firestore.client()

#chats = db.collection('messages').where('toId', '==', 'xrTVCEyCwfOtO8lDe5UKk2egF4c2').stream()
chats = db.collection('messages').stream()


for c in chats:
    data = c.to_dict()
    u1, u2 = data['fromId'], data['toId']

    # Skip incomplete records
    if u1 is None or u2 is None:
        #print('toId or fromId is missing')
        continue
    
    # Skip test users
    if u1 in ['rzvlcuAdFVS6238qqse4B4EjvUA3', 'TzbOEGICy0XVPCUA6XUbTOKPXap2', 'oyYUDByQGVdgP13T1nyArhyFkct1', '0000000000000000000000000000'] or \
        u2 in ['rzvlcuAdFVS6238qqse4B4EjvUA3', 'TzbOEGICy0XVPCUA6XUbTOKPXap2', 'oyYUDByQGVdgP13T1nyArhyFkct1', '0000000000000000000000000000']:
        continue
    
    message_ref = c.reference.collection(c.id)
        
    if message_ref is not None:
        results = message_ref.order_by('timestamp').stream()
        messages = [m.to_dict() for m in results]
        
        if len(messages) > 0:
            user1 = auth.get_user(u1)
            if user1 is None:
                #print('Auth user for %s NOT found' % u1)
                continue

            user2 = auth.get_user(u2)
            if user2 is None:
                #print('Auth user for %s NOT found' % u2)
                continue

            print('************************************************************')
            print('CHAT BETWEEN: %s (%s) and %s (%s)' % (user1.display_name, user1.email, user2.display_name, user2.email))

            for m in messages:
                print(m['content'])
# Out:
# ************************************************************
# CHAT BETWEEN: Владислав Макулов (vmagent80@gmail.com) and Айрат Денисламов (laryartufa@gmail.com)
# Привет!
# Рад, что ты здесь!
# Надо пополнять сообщество)
# привет!
# мне очень понравилась идея!
# друзьям теперь показываю и рассказываю
# нужно ещё книжки добавить
# как у тебя дела?
# похоже в этом приложении нифига нет оповещений
# дела хорошо, тоже думаю побольше книг выложить
# да, нет оповещений
# ************************************************************
# CHAT BETWEEN: Alfiya Kohanidze (ar.valiullina@gmail.com) and Владислав Макулов (vmagent80@gmail.com)
# Альфия, привет!
# Эта книга как-то связана с "Магической уборкой" ля взрослых?
# Марии Кондо?
# ************************************************************
# CHAT BETWEEN: Xodasevich Book Sharing (xodacevich@yandex.ru) and Стасио Гайворонски (gaivoronskystan@gmail.com)
# Стас привет проверяю приложение
# есс
# ************************************************************
# CHAT BETWEEN: Olga Pylaeva (olga.pylaeva@gmail.com) and Саша Старк (asashastark@icloud.com)
# Здравствуйте! а можно у Вас взять почитать сказки народов СССР?
# Здравствуйте
# да можно
# когда и где вам удобно встретится?
# ************************************************************
# CHAT BETWEEN: Oleg Aslamov (oleg.aslamov@gmail.com) and Саша Старк (asashastark@icloud.com)
# привет
# привет 2
# привет
# ************************************************************
# CHAT BETWEEN: Anton  Lashmanov (anton_lashmanov@mail.ru) and Anna Atanasova (fruitananas@rambler.ru)
# доброе утро, мы, конечно,далековато друг от друга, но "звёзды шамана" я не читала. вы бываете в центре Москвы?
# да, и "как эффективно управлять свободными людьми" тоже, должно быть, хорошая книга.
# ************************************************************
# CHAT BETWEEN: Марат Сабиров (avkhatovich@gmail.com) and Aleksey Kolmakov (kan-eco@mail.ru)
# здравствуйте Марат! я бы хотел взять у вас почитать сто подвигов обычных людей)
# ************************************************************
# CHAT BETWEEN: Ilya Korneyev (ilya.korneyev@gmail.com) and Anna Atanasova (fruitananas@rambler.ru)
# Илья, добрый вечер! достойная книга "Сновидения и символы"?
# Добрый, не знаю, это жены)
# а можно ее у Вашей жены взять почитать?
# ************************************************************
# CHAT BETWEEN: Анастасия Приказчикова (prikazav@gmail.com) and Катя Макарова (makarova0798@gmail.com)
# Можно взять у вас "Игры, в которые играют люди : психология человеческих отношений ; Люди, которые играют в игры : психология человеческой судьбы / Эрик Берн ; "?
# ************************************************************
# CHAT BETWEEN: Алена Рудюк (alenar91@mail.ru) and Владислав Ефремов (efremov.vlad.ser@gmail.com)
# Можно взять у вас "ЭКОsapiens. Простые правила осознанной жизни"?
# ************************************************************
# CHAT BETWEEN: Ирина Примерова (irida.ekb@gmail.com) and Ирина Борель (borelirina1990@gmail.com)
# привет
# ты мои Книги видишь?
# привет! да!
# кинь сюда ссылку на любую твою книгу
# ************************************************************
# CHAT BETWEEN: Людмила Дадова (dadovalyuda@rambler.ru) and Olga Pylaeva (olga.pylaeva@gmail.com)
# Добрый день! А можно у Вас взять почитать «Жутко громко и Запредельно близко»?
# ************************************************************
# CHAT BETWEEN: dacyon anthony (anthonydacyon@gmail.com) and Ranjan Sahabandu (ranjansahabandu@gmail.com)
# Can you give me "Rich Dad, Poor Dad: What the Rich Teach Their Kids About Money--That the Poor and Middle Class Do Not!"?
# Can you give me "Zero to One: Notes on Startups, or How to Build the Future"?
# ************************************************************
# CHAT BETWEEN: Dmitry  Solovyev (mityay_qu@mail.ru) and Мария Чагина (m79209357807@gmail.com)
# Привет
# в общем, я случайно добавила твою книгу в мои книги, а теперь не могу удплить
# за-за!
# ха-ха!
# а какую?
# а можешь ввести какую-то свою книгу, а я потестю, как её забрать у тебя?
# ок
# сейчас
# а ещё, при добавлении книги в моей библиотеке появляется ещё одна, вообще какая-то левая книга. Возможно это что-то вроде придложений, что можно взять. Но статус книги помечается, как у меня на руках
# ты через фото расшифровывешь книги? если да, то это программа расшифровки ошибается. надо удалить просто это несуществующие книги
# понятно
# Пожалуйста, верните книгу "Иду на грозу"?
# а вот так можешь вернуть книгу? или это просто сообщение ?
# ты когда загружала хроники Нарнии где была физически? у себя дома или недалеко от нас, у Сони, например?
# дома
# иду на грозу не удаляется
# а ещё некоторые твои книги в 0.9 км от меня, а некоторые а 0.2.
# Я у тебя забрал хроники Нарнии, а теперь они как-то вернулись. это ты сделала как-то?
# Хочу вернуть вам "Хроники Нарнии : Перевод] / / Клайв С. Льюис ; Худож. М. Овчинникова. - М. : МНПП "Гендальф" МЕТ, 1992-. - 20 см.
# Ч. 1: Племянник Чародея; Лев, Колдунья и платяной шкаф; Конь и его мальчик. - М. : МНПП "Гендальф" МЕТ, 1992. - 380,"?
# снова её забрал. попробуй вернуть себе
# нет, я ничего неделала
# и она отображается как у меня
# Пожалуйста, верните книгу "Хроники Нарнии : Перевод] / / Клайв С. Льюис ; Худож. М. Овчинникова. - М. : МНПП "Гендальф" МЕТ, 1992-. - 20 см.
# Ч. 1: Племянник Чародея; Лев, Колдунья и платяной шкаф; Конь и его мальчик. - М. : МНПП "Гендальф" МЕТ, 1992. - 380,"?
# не возвращается
# и я теперь не могу промотать к началу переписки. Только до определённого места
# разработчик написал, что эта и другие ошибки исправлена и в ближайшие дни будет доступна новая версия приложения
# хорошо
# ************************************************************
# CHAT BETWEEN: Svetlana Timofeeva (0580157@gmail.com) and Kost Zhukov (kost.zhukov@gmail.com)
# hey, can I please take a book about investments for a while?
# ************************************************************
# CHAT BETWEEN: Ирина Борель (borelirina1990@gmail.com) and Lilia Urazalieva (terrabitia01@gmail.com)
# 👋привет! книги видно?
# Привет! Видно) с ричардом Бахом что-то не то, длинный код высвечивается, но в целом ок все
# ************************************************************
# CHAT BETWEEN: Ирина Борель (borelirina1990@gmail.com) and Маргарита Пугина (margomargobrodyaga@gmail.com)
# Привет! разобралась? книжки видишь?
# Привет, да, спасибо. Чувствую себя динозавром, пока в декрете то сидишь, мир и прогресс шагает вперёд 🤭
# ************************************************************
# CHAT BETWEEN: Elena Prokopova (elena.prokopova@inbox.ru) and Наталь Наталь (2138506n@gmail.com)
# я не поняла в Казани только у тебя приложение? одна фотка
# ************************************************************
# CHAT BETWEEN: Kirin Hilliar (kirin.hilliar@gmail.com) and Ankit Mundada (aomundada@gmail.com)
# hey
# ************************************************************
# CHAT BETWEEN: Ankit Mundada (aomundada@gmail.com) and harish ram (harishr.dba27@gmail.com)
# Can you give me "The Diary of a Young Girl"?
# ************************************************************
# CHAT BETWEEN: Alina  Remizova (remizova_a@mail.ru) and Anna Atanasova (fruitananas@rambler.ru)
# Алина, добрый вечер! а о чем книга "Я слышу Вас насквозь"?
# Анна, добрый день! об умении слушать и использовать это качество в переговорах
# здорово! вы бываете в центре Москвы?
# проездом только. я работаю на тушинской, там чаще можно застать
# поняла, я на Преображенской площади. попробуем на следующей неделе в центре пересечься? Вам вот думаю, что предложить почитать...
# ************************************************************
# CHAT BETWEEN: Алла Здравствуйте (zdravstvujtealla@gmail.com) and Ирина С (zadanje6@yandex.ru)
# Здравствуйте. Недавно только установила это приложение, пока разбиралась, случайно нажала не ту кнопку, вы могли бы книгу "Чужак" обратно "забрать"?
# ************************************************************
# CHAT BETWEEN: Alexander Nagornyy (a.nagornyy@gmail.com) and Julia Chernyaeva (caledonia17@yandex.ru)
# Александр, добрый вечер. Я бы хотела почитать «Магическую уборку». Как можно с вами договориться? Спасибо )
# ************************************************************
# CHAT BETWEEN: Aleksei Egorov (egorov.aleksey@gmail.com) and Olga Ermishkina (yermishkina@gmail.com)
# hi. just testing. looks like we are the only users in the US?
# ************************************************************
# CHAT BETWEEN: Ирина Реброва (irinare86@gmail.com) and Anastasia Kostsova (nastya-kostsova@yandex.ru)
# Можно взять у вас "Семейный тайм-менеджмент. Книга для родителей, которые хотят «все успеть»"?
# ************************************************************
# CHAT BETWEEN: Vadim Mikhailov (dingoinlimbo@gmail.com) and Людмила Дадова (dadovalyuda@rambler.ru)
# Добрый день! у вас очень интересные книги ) я Вадим. и наверняка вы хорошо знаете Дениса с Женей)
# Привет!
# Да, знаю.но в основном Женю)
# ************************************************************
# CHAT BETWEEN: Margarita Ozhima (ozhimamargarita@gmail.com) and Хорошая Жена (goodwifeme@gmail.com)
# привет ) могу дать почитать
# ************************************************************
# CHAT BETWEEN: Ekaterina Gureeva (irracio.n@gmail.com) and Anastasia Gusakova (anastasiadatsik@gmail.com)
# здравствуйте, у вас такая тематическая полка чудесная!
# как вам «после трёх уже поздно»?
# здравствуйте, еще не читала))))
# ************************************************************
# CHAT BETWEEN: Svetlana Timofeeva (0580157@gmail.com) and Valentin (049279@gmail.com)
# Hi! Can I have the book “And Then There Were None”? When we can meet? Do you charge for that?
# хай
# ************************************************************
# CHAT BETWEEN: Valentin (049279@gmail.com) and Sveta Dmitrieva (svetikdm@mail.ru)
# Привет! Давно хотела перечитать Хоббита, можно одолжить книгу? Когда удобно встретиться?
# Да, давайте завтра вечером.
# ************************************************************
# CHAT BETWEEN: Oleg Aslamov (oleg.aslamov@gmail.com) and Vsevolod Iagovkin (viagovkin@gmail.com)
# хочу
# очень
# В последний раз
# а вот хрен тебе живи неучем
# может здесь переписываться?
# ************************************************************
# CHAT BETWEEN: Alina  Remizova (remizova_a@mail.ru) and Veronika Pekker (veronika@pekker.com)
# добрый день! я ещё не до конца разобралась, как пользоваться этим сервисом, но мне интересны книги на вашей полке)
# ************************************************************
# CHAT BETWEEN: Kristina Petushenko (petushenko.mail@gmail.com) and Veronika Pekker (veronika@pekker.com)
# добрый день! я ещё не до конца разобралась, как пользоваться этим приложением, но меня заинтересовали книги с вашей полки
# ************************************************************
# CHAT BETWEEN: Дарина Бирюлина (bambina-violino@yandex.ru) and Anastasia Laukkanen (laukkanen@mail.ru)
# hi! so this app works!
# i came to Istanbul for 1 week, so doesn't make sense to ask you for a book unfortunately)ll
# hi! but nice to know there is also a chat feature here! thanks for message :)
# ************************************************************
# CHAT BETWEEN: Марат Сабиров (avkhatovich@gmail.com) and Tatiana Redko (tanisredko@gmail.com)
# Марат, здравствуйте. Я могу у вас взять почитать "Путь в чистую страну"?

# %%
# Admin script to go through not identified ISBN and print it

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
isbns = db.collection('noisbn').where('found', '==', True).stream()

isbns = [b for b in isbns]

print('Number of records:', len(isbns))

count, resolved = 0, 0

# List of users with books to add
# {uid: {name: <name>, email: <email>, books: []}}
users = {}

for b in isbns:
    isbn = b.id
    data = b.to_dict()
    
    if len(isbn) == 10 and check_isbn_10(isbn) == 0:
        isbn = '978' + isbn
        isbn = isbn[:12] + str(calc_isbn_13(isbn))
        print('%s => %s' % (b.id, isbn))

    if len(isbn) != 13 or not isbn.startswith('97'):
        #print('ISBN %s are incorrect' % isbn)
        continue

    if 'requested_by' not in data or 'found' not in data or not data['found']:
        #print('ISBN %s has no users' % isbn)
        continue
        
    book = get_book(isbn)
    if book is not None:
        #print('%s requested by' % isbn, data['requested_by'])
        for uid in data['requested_by']:
            user = auth.get_user(uid)
            if user is not None:
            #print('%s requested by (%s, %s, %s)' % (isbn, uid, user.display_name, user.email))
                if uid in users:
                    users[uid]['books'].append(book)
                else:
                    users[uid] = {'name': user.display_name, 'email': user.email, 'books': [book]}
            else:
                print('Missing user:', uid)
    else:
        print('Book missing:', isbn)
# Out:
# Number of records: 86
# HTTP error: 504 b'upstream request timeout'
# Book missing: 9785222234976

# %%
i = 0
for uid in users:
    # Skip some users
    if uid in ['ot0jztXgSrMRYIWs3QwIRwTvimN2', 'mRGmf2rI7xSGqDq95NL5RTK43jl2', 'GO8apnl0KcU0uwfOyJWORUHAUGG3',
              'qKKPX23jaWO2VqYJShWKouup2P32']:
        continue
        
    data = users[uid]
    #print('%s has %d books to add' % (data['name'], len(data['books'])))
    
    user = db.collection('users').document(uid).get()
    if not user.exists:
        print(f'User record missing: {uid}, {data["name"]}')
    else:
        user_data = user.to_dict()
        if 'position' in user_data and user_data['position'] is not None:
            users[uid]['position'] = user_data['position']
        else:
            users[uid]['position'] = None
            other_books = db.collection('bookrecords').where('holderId', '==', uid).limit(1).stream()
            other_books = [b for b in other_books]
            
            if len(other_books) > 0:
                other_data = other_books[0].to_dict()
                if 'location' in other_data and other_data['location'] is not None:
                    print(f'Geo-position found {uid}, {data["name"]}')
                    users[uid]['position'] = other_data['location']['geopoint']

            if users[uid]['position'] is None:
                print(f'Position missed for {uid}, {data["name"]}')

        if 'photo' in user_data:
            users[uid]['photo'] = user_data['photo']
        elif 'photoUrl' in user_data:
            users[uid]['photo'] = user_data['photoUrl']
        else:
            users[uid]['photo'] = ''
            print(f'Photo missed for {uid}, {data["name"]}')
    
    print('-------------------------------------------------------')
    print(data['email'])

    print(f"Hello {data['name']},\n\nYou've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.\n")

    for i, b in enumerate(data['books']):
        print(f'{i+1}) {b.authors} "{b.title}"')
        
        b.keys.append(isbn)
        
        # Add bookrecord to Firestore
        rec = {
            'authors': [s.strip() for s in b.authors.split(',')],
            'confirmed': False,
            'holderId': uid,
            'holderName': data['name'],
            'holderImage': users[uid]['photo'],
            'id': f'b:{uid}:{isbn}',
            'image': b.image,
            'isbn': isbn,
            'keys': b.keys,
            'lent': False,
            'location': {
                  'geopoint': users[uid]['position'],
                  'geohash': geohash2.encode(users[uid]['position'].latitude, users[uid]['position'].longitude)[:9],
               },
            'matched': False,
            'matcheId': None,
            'ownerId': uid,
            'ownerName': data['name'],
            'ownerImage': users[uid]['photo'],
            'title': b.title,
            'transit': False,
            'users': [uid],
            'wish': False
        }
        db.collection('bookrecords').document(rec['id']).set(rec, merge=True)
        #print(f"Bookrecord added {rec['id']}, rec['authors']") 
        #print(f"AUTHORS {rec['authors']}") 

    print('\n- Denis Stark')

    #i += 1
    #if i >= 1:
    #    break
    #9785354014804
# Out:
# Geo-position found M8eWIMNYZrfelOEUg4T1EOusdxE3, Thomas Hibbard
# -------------------------------------------------------
# thomashibbard89@gmail.com
# Hello Thomas Hibbard,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Hal Whitehead;Luke Rendell "The Cultural Lives of Whales and Dolphins"
#
# - Denis Stark
# -------------------------------------------------------
# dstark1977@gmail.com
# Hello Денис Старк,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Don Tapscott, Anthony D. Williams "Wikinomics: How Mass Collaboration Changes Everything"
# 2) Mohammed Bin Rashid Al Maktoum "Reflections on Happiness and Positivity"
# 3) Nathalie Choux "The Ocean"
# 4) Ларссен Эрик Бертран, Айзятулова Иделия "Без жалости к себе. Раздвинь границы своих возможностей"
# 5) Дайер Алан "Звёзды"
#
# - Denis Stark
# Geo-position found 9tDwTcw20ZdPcanttQ0nGEPBjTd2, Marat Chasanov
# -------------------------------------------------------
# marat.chasanov@gmail.com
# Hello Marat Chasanov,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Thupten Jinpa "Tsongkhapa"
#
# - Denis Stark
# Geo-position found noaN3PE4YRQcOa4dtTeaPl5d2zN2, Добрая Земля
# -------------------------------------------------------
# dobrayazemlya@gmail.com
# Hello Добрая Земля,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Владимир Антонов "Дао-Дэ-Цзин"
# 2) Максакова, Валентина Ивановна. "Организация воспитания младших школьников : Метод. пособие для учителя / В.И. Максакова. - М. : Просвещение, 2003 (Твер. полигр. комб. дет. лит.). - 253, "
# 3)  "Тесты на семейную совместимость / "
# 4) Йогананда, Парамаханса (1893-1952). "Автобиография йога "
# 5) Морозов, Дмитрий Владимирович. "Разбить стекла теплицы "

#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Фрей, Стивен. "Инсайдер : роман / Стивен Фрей; "
#
# - Denis Stark
# Geo-position found pXJzbrxqy1Xl8JGS0zXkDuQp1G12, Mary Teterina
# -------------------------------------------------------
# maryteterina@gmail.com
# Hello Mary Teterina,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Оганян Марва Вагаршаковна, Оганян Вардан Сергеевич "Экологическая медицина. Будущее начинается сегодня. Доп. и пер. издание"
#
# - Denis Stark
# Geo-position found anzRPpWdIdcT9sKJLCKdKUOumeB2, Ирина С
# -------------------------------------------------------
# zadanje6@yandex.ru
# Hello Ирина С,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Токмакова, Ирина Петровна (1929-2018.). "Аля, Кляксич и буква А "
#
# - Denis Stark
# Geo-position found oRQROy5MsfYkMkk2tlBeBCwR9uD3, Татьяна Кравченко
# -------------------------------------------------------
# tak1979@inbox.ru
# Hello Татьяна Кравченко,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Тереза Питман, Диана Вест, Дайен Виссингер "Искусство Грудного Вскармливания"
#
# - Denis Stark
# -------------------------------------------------------
# dingoinlimbo@gmail.com
# Hello Vadim Mikhailov,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1)  "Воображаемая реальность"
#
# - Denis Stark
# -------------------------------------------------------
# greg.kisel@gmail.com
# Hello Григорий Кисель,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Алексей Поликовский "Ангелы любят белый"
#
# - Denis Stark
# Geo-position found wzkLkyqWeWXYUyYfXGxZocaTHZD2, Evgenia Faleeva
# -------------------------------------------------------
# faleeva.evgenia@gmail.com
# Hello Evgenia Faleeva,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Грэй, Джон (1951-). "Мужчины с Марса, женщины с Венеры / Джон Грэй ; "
#
# - Denis Stark
# -------------------------------------------------------
# irida.ekb@gmail.com
# Hello Ирина Примерова,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Франсуаза Дольто "На Стороне Подростка"
# 2) Стивен Р Кови  "7 Навыков Высокоэффективных Семей"
#
# - Denis Stark
# -------------------------------------------------------
# morfey812@gmail.com
# Hello Алексей Кудрин,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1)  "Энциклопедия для детей. Т. 23: Универсальный иллюстрированный энциклопедический словарь"
#
# - Denis Stark
# Geo-position found ooTvA7pNhaU4oPoacZ0LCRAJgpf1, Анастасия Ришко
# -------------------------------------------------------
# anastasia_rishko@list.ru
# Hello Анастасия Ришко,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Джон Морриш "Издание Журнала. От Идеи До Воплощения"
#
# - Denis Stark
# Geo-position found ZveBlwFVNOM6KsOxKDcYrEx93S32, harish ram
# -------------------------------------------------------
# harishr.dba27@gmail.com
# Hello harish ram,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Navi Radjou;Jaideep Prabhu;Simone Ahuja "Jugaad Innovation"
#
# - Denis Stark
# -------------------------------------------------------
# borelirina1990@gmail.com
# Hello Ирина Борель,
#
# You've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.
#
# 1) Андрей Сидерский "Третье Открытие Силы"
# 2)  "Как уложить ребенка спать без слез"
#
# - Denis Stark

# %%
# Admin script to go through not identified ISBN and try to find it

db = firestore.client()

#isbns = db.collection('noisbn').limit(20).stream()
isbns = db.collection('noisbn').stream()

isbns = [b for b in isbns]

print('Number of records:', len(isbns))

count, resolved = 0, 0

to_delete = []
found = []
for b in isbns:
    isbn = b.id
    data = b.to_dict()

    # Skip records if it was sorted out before
    if 'found' in data:
        continue

    # Skip record if no users recorded for it
    if 'requested_by' not in data:
        continue

    if len(isbn) == 10 and check_isbn_10(isbn) == 0:
        isbn = '978' + isbn
        isbn = isbn[:12] + str(calc_isbn_13(isbn))
        print('%s => %s' % (b.id, isbn))

    if len(isbn) == 13 and isbn.startswith('97'):
        #To just print ISBN
        #print(isbn)
        #continue
        
        count += 1
        #print('%s try to resolve...' % isbn)
        book = get_book(isbn)

        if book is not None:
            resolved += 1
            found.append(b.id)
            print('ISBN %s: resolved' % isbn)
            db.collection('noisbn').document(isbn).update({'found': True})
        else:
            print('ISBN %s: NOT resolved' % isbn)
            db.collection('noisbn').document(isbn).update({'found': False})
    else:
        to_delete.append(b.id)
        

print('%d out of %d resolved' % (resolved, count))
# Out:
# Number of records: 195
# ISBN 9781897510247: resolved
# ISBN 9785001311379: resolved
# ISBN 9785030038322: resolved
# ISBN 9785170026418: resolved
# ISBN 9785170511518: resolved
# ISBN 9785222025673: NOT resolved
# ISBN 9785222037355: resolved
# ISBN 9785271451942: resolved
# ISBN 9785389015234: resolved
# ISBN 9785699563890: resolved
# ISBN 9785887111773: NOT resolved
# ISBN 9785905906572: NOT resolved
# ISBN 9785906258205: NOT resolved
# ISBN 9785906264527: resolved
# ISBN 9785911031541: resolved
# ISBN 9785917430621: resolved
# ISBN 9785917592107: resolved
# ISBN 9785943554575: resolved
# ISBN 9785950054150: NOT resolved
# ISBN 9785953347686: resolved
# ISBN 9785979200064: resolved
# ISBN 9785982120182: resolved
# ISBN 9789088830310: NOT resolved
# ISBN 9789665215622: resolved
# ISBN 9789851301351: NOT resolved
# ISBN 9789851522350: resolved
# ISBN 9789851531659: resolved
# ISBN 9791587120366: NOT resolved
# ISBN 9795367002415: resolved
# ISBN 9799856307197: NOT resolved
# 21 out of 30 resolved

# %%
# ADD BOOKS IN MYSQL (Manually found in web)

books = []
books.append(Book('9781897510247', 'Дао-Дэ-Цзин', 'Владимир Антонов', image='https://www.ellibs.com/sites/default/files/imagecache/product/bookcover_9781897510247.jpg', language='rus'))
books.append(Book('9785001311379', '21 Урок Для Xxi Века', 'Юваль Ной Харари', image='https://www.rahvaraamat.ee/images/products/001/354/892/thumbnails/big/0ab9d8016fd041b7e31ef2a77cddcf646baa2706/21-%D1%83%D1%80%D0%BE%D0%BA-%D0%B4%D0%BB%D1%8F-xxi-%D0%B2%D0%B5%D0%BA%D0%B0.jpg', language='rus'))
books.append(Book('9785030038322', 'Физиология Человека', '', image='https://images-na.ssl-images-amazon.com/images/I/415MWsuJk-L._SX298_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785170026418', 'Ночной Портье', 'Ирвин Шоу', image='https://images-na.ssl-images-amazon.com/images/I/51kqNUUKtFL._SX301_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785170511518', '100 Способов Очистить Дом От Энергетической Грязи', 'Мариеа Миллер', image='https://images-na.ssl-images-amazon.com/images/I/41JA9htKUvL._BO1,204,203,200_.jpg', language='rus'))
books.append(Book('
O1,204,203,200_.jpg', language='rus'))
books.append(Book('9789851531659', '7 Навыков Высокоэффективных Семей', 'Стивен Р Кови ', image='https://www.troykaonline.com/files/product/large/246789_9789851531659.jpg', language='rus'))
books.append(Book('9795367002415', 'Русские Летописи Xi-Xvi Веков', 'А. Боброва', image='https://images-na.ssl-images-amazon.com/images/I/61ynENagZXL._SX339_BO1,204,203,200_.jpg', language='rus'))

add_books(books)

#book = get_book('9781897510247')
#if book is not None:
#    print(book.title, book.authors)
# Out:
# 21 books added

# %%
# Out:
# 181 out of 63 resolved
# 63 12
# ISBN 9780226325927 Requested by ['M8eWIMNYZrfelOEUg4T1EOusdxE3']
# ISBN 9780812928082 Requested by ['ot0jztXgSrMRYIWs3QwIRwTvimN2']
# ISBN 9781119209591 Requested by ['ot0jztXgSrMRYIWs3QwIRwTvimN2']
# ISBN 9781565921511 Requested by ['mRGmf2rI7xSGqDq95NL5RTK43jl2']
# ISBN 9782745976192 Requested by ['oyYUDByQGVdgP13T1nyArhyFkct1']
# ISBN 9783426274521 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785000572054 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785001006091 Requested by ['xem1khYLX0a3d7KuE2FTYa9QGcK2']
# ISBN 9785090117647 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785170164233 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785170259786 Requested by ['IEbwfDjHQcQkTm4uGDMCQfMsGuY2']
# ISBN 9785170804658 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785170896370 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785171164997 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785222136591 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785222234976 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785264001048 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785271404009 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785399004334 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785443100708 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785444802014 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785444805084 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785444805305 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785448598784 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785462007415 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785699137640 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785699492374 Requested by ['anzRPpWdIdcT9sKJLCKdKUOumeB2']
# ISBN 9785699529209 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785699873005 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785769538223 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785829700386 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785837005152 Requested by ['iTHNWQZQY8d8SqSJCVOpeodBgx42']
# ISBN 9785860382008 Requested by ['CpqlQ0GtcrNp2gVTZjTls2LAQF63']
# ISBN 9785901226049 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785904656836 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785906504036 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785906504531 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785911031213 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785911031435 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785912507564 Requested by ['wzkLkyqWeWXYUyYfXGxZocaTHZD2']
# ISBN 9785916712247 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785916712650 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785917612652 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785919490036 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785931341262 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785946230469 Requested by ['NW3sjiR8NQT6OwZyRFwCEmgbZ8j1']
# ISBN 9785946830492 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785978703429 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785986972473 Requested by ['8UJw0yj5ceVq2lDq5KQfLlB5UE52']
# ISBN 9785987120903 Requested by ['noaN3PE4YRQcOa4dtTeaPl5d2zN2']
# ISBN 9785990590076 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9785996308101 Requested by ['vDWiB1lV2yYAAd8t7J3PkeKhRpH2']
# ISBN 9788184002058 Requested by ['ZveBlwFVNOM6KsOxKDcYrEx93S32']
# ISBN 9788484784579 Requested by ['GZPqkoCE28UCRXlXCYuuDCIwS2G3']

# %%
# Admin script to add all books from Firestore to MySQL

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

print('Number of records:', len(books))

books_to_add = []

for b in books:
    data = b.to_dict()
    
    if 'migrated' in data and data['migrated']:
        continue
     
    if 'isbn' in data and ('title' in data or 'authors' in data):
        #print('Authors:', data['authors'])
        if 'authors' in data and data['authors'] is not None:
            authors = ','.join([a for a in data['authors'] if a is not None])
        else:
            authors = ''
        books_to_add.append(Book(data['isbn'], data['title'], authors, data['image']))

        if 'authors' in data and len(data['authors']) > 1:
            print('Multi-authors: %s' % data['isbn'], data['authors'])
    elif 'book' in data:
        data = data['book']
        if 'isbn' in data and ('title' in data or 'authors' in data):
            if 'authors' in data and data['authors'] is not None:
                authors = ','.join([a for a in data['authors'] if a is not None])
            else:
                authors = ''
            books_to_add.append(Book(data['isbn'], data['title'], authors, data['image']))

            if 'authors' in data and len(data['authors']) > 1:
                print('Multi-authors: %s' % data['isbn'], data['authors'])
    else:
        print('DATA MISSING:', data)
    
    if len(books_to_add) >= 10:
        add_books(books_to_add)
        for isbn in [b.isbn for b in books_to_add]:
            db.collection('books').document(isbn).update({'migrated': True})

        books_to_add = []

if len(books_to_add) > 0:        
    add_books(books_to_add)
    for isbn in [b.isbn for b in books_to_add]:
        db.collection('books').document(isbn).update({'migrated': True})
# Out:
# Number of records: 909

# %%
# Admin script to run shelf recognition for old shelves

db = firestore.client()


shelves = db.collection('shelves').where('user', '>', '').where('status', '==', 5).stream()
#shelves = db.collection('shelves').where('user', '>', '').stream()
shelves = [s for s in shelves]

print('Number of book shelves:', len(shelves))

for s in shelves:
    data = s.to_dict()
    
    # Skip shelves already requested for processing
    #if 'status' in data:
    #    continue

    # Run recognition via API
    print('Run recognition for user [%s], image [%s], shelf [%s], at coordinates [%.5f, %.5f]' % (data['user'], data['file'], s.id, data['position'].latitude, data['position'].longitude))
    res = recognize_image(data['user'], data['file'], s.id, data['position'])
# Out:
# Number of book shelves: 2
# Run recognition for user [wuwImhUnaNVYCV0eDy6ydoGLqYl1], image [1547731544738.jpg], shelf [-LWQzJKadlza372rDoPr], at coordinates [55.82460, 37.50127]
# b'Image recognition requested'
# Run recognition for user [zKhrMV3lusY7QyMqnO1kCHV8hs52], image [1555069784600.jpg], shelf [-LcGNSxjnTCPL-S15bGE], at coordinates [60.07477, 30.33278]
# b'Image recognition requested'

# %%
# Run recognition for one book shelf
#recognize_image('NW3sjiR8NQT6OwZyRFwCEmgbZ8j1', '1589726917860.jpg', '1589726917860', firestore.GeoPoint(43.7113831, 20.6709329))
recognize_image('0000000000000000000000000000', '0000000000034.jpg', '0000000000000000000000000000:0000000000034', firestore.GeoPoint(90.0, 135.0))

# Add books
#books = [Book('9785946230469', 'Энциклопедия для детей. Т. 23: Универсальный иллюстрированный энциклопедический словарь', '', image='https://images-na.ssl-images-amazon.com/images/I/21HqXNQA5FL._BO1,204,203,200_.jpg')]
#add_books(books)

# Get book by ISBN
#book = get_book('9785946230469')
#print(book.isbn, book.title)
# Out:
# b'Image recognition requested'
# True

# %%
# Script to check results of the recognition

db = firestore.client()

shelves = db.collection('shelves').where('user', '>', '').stream()
shelves = [s for s in shelves]

print('Number of book shelves:', len(shelves))

recognized, total, completed, failed, lookup = 0, 0, 0, 0, 0
for s in shelves:
    data = s.to_dict()
    
    if data['status'] == 6:
        completed += 1
        recognized += data['recognized']
        total += data['total']
    elif data['status'] == 7:
        failed += 1
    else:
        print('Other status:', data['status'])

print('Completed: %d, Failed: %d, Lookup: %d' % (completed, failed, lookup))
print('Recognized: %d (%d%%), Total: %d'  % (recognized, 100 * recognized / total, total))
# Out:
# Number of book shelves: 170
# Completed: 170, Failed: 0, Lookup: 0
# Recognized: 1010 (50%), Total: 2017

# %%
# Admin script to visualize recognition
# Get the image and recognition json from GCS and visualize
import cv2
import numpy as np
from firebase_admin import storage

bucket = storage.bucket('biblosphere-210106.appspot.com')

#user = '0000000000000000000000000000'
#shelf = '0000000000034'

user = 'AWsv5n9QiJYIUcDQmxWlBKRoBzZ2'
shelf = '1590618924998' # '1590619142574', '1590619327951'
#shelf = '1590619142574' # '1590619327951'
#shelf = '1590619327951'

image_blob = bucket.blob('images/%s/%s.jpg' % (user, shelf))
result_blob = bucket.blob('images/%s/%s.json' % (user, shelf))

img = imread_blob(image_blob)
results = json.loads(result_blob.download_as_string())

for b in results['recognized']:
    cv2.drawContours(img, np.array([b['outline']]), 0, (0, 255, 0), 7)

for b in results['unrecognized']:
    cv2.drawContours(img, np.array([b['outline']]), 0, (0, 0, 255), 7)

cv2.imwrite('results/'+user+'-'+shelf+'.jpg', img)
# Out:
# True

# %%
for b in results['recognized']:
    print(b['book']['isbn'], '"%s"' % b['book']['title'])
# Out:
# 9781565922204 "Advanced Perl Programming"
# 9781558605824 "GUI Bloopers: Don'ts and Do's for Software Developers and Web Designers"
# 9781449342685 "Microinteractions: Designing with Details"
# 9780963124685 "Those Who Trespass: A Novel of Murder and Television"
# 9780596000356 "Information Architecture for the World Wide Web: Designing Large-Scale Web Sites"
# 9780735710368 "Photoshop 6 Web Magic (Magic (New Riders))"
# 9781510710306 "My Robot Ate My Homework: Project Droid #3 (Paperback)"
# 9781565922570 "Mastering Regular Expressions"
# 9780596551872 "Apache Cookbook"
# 9781118026687 "Professional jQuery"
# 9781491913550 "Information Architecture"
# 9781401322915 "Free: The Future of a Radical Price"
# 9780201657968 "XML and SQL: Developing Web Applications"
# 9781731036841 "Introduction to Data Science with Python: Basics of Numpy and Pandas (Paperback)"
# 9780596004477 "Google Hacks: 100 Industrial-Strength Tips &amp; Tools"
# 9780470843710 "Web Programming: Building Internet Applications, 2nd Editon"
# 9781565924642 "Learning Python (Help for Programmers)"
# 9780321344762 "Don't Make Me Think: A Common Sense Approach to Web Usability"
# 9781607455721 "I Love Ewe"

# %% [markdown]
# **FIRST RUN (Error in web-search)**
# * Number of book shelves: 171
# * Completed: 117, Failed: 51
# * Recognized: 560 (40%), Total: 1384
#
# **SECOND RUN (only processed schelves have been taken)**
# * Number of book shelves: 170
# * Completed: 170, Failed: 0, Lookup: 0
# * Recognized: 1010 (50%), Total: 2017

# %%
# TODO actions:

# 1. Corrupted symbols (abebooks):
# 9789874024770, 9785733103037

# %%
# Out:
# Potsdamer Platz, Bellevuestraße, Botschaftsviertel, Tiergarten, Mitte, Berlin, 10785, Deutschland
