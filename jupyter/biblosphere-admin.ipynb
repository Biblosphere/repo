# %% [markdown]
# ***Admin functions for Biblosphere***
#
# - MySQL functions
# -- Delete ISBN record
# -- Query book by ISBN
#
# - API functions
# -- Add book with ISBN
# -- Recognize book shelf by photo
# -- Scan not found ISBN

# %%
#from google.auth import credentials
from google.cloud import firestore
from google.cloud import storage
from google import auth
from math import pi, sin, cos, atan2, sqrt
import requests
import re
import geohash2
from geopy.geocoders import Nominatim
from google.cloud.firestore_v1 import Increment

import cv2
import pandas as pd
import json

import google.auth
import google.auth.transport.requests

from subprocess import PIPE, Popen

#cred = credentials.Certificate("biblosphere-firebase-adminsdk.json")
#firebase_admin.initialize_app(cred)

class Book:
    def __init__(self, isbn, title, authors, image='', language=None):
        self.isbn = isbn
        self.title = title
        self.authors = authors
        self.image = image
        if language is not None:
            self.language = language
        self.keys = lexems(title + ' ' + authors + ' ' + isbn, full=True)

    @classmethod
    def from_json(cls, obj):
        return cls(obj['isbn'], obj['title'], obj['authors'], obj['image'])

    def catalog_title(self):
        return self.title + ' ' + self.authors
    
def lexems(s, full = False):
    if type(s) is str:
        return re.sub('[;()\",/&!?:.\-*·|+$\'«@•]',' ',s.lower()).split()
    elif type(s) is set:
        return [w.lower() for w in s]
    

class Block:
    def __init__(self, book=None, bookspine=None, outline=None):
        self.book = book
        self.bookspine = bookspine
        self.outline = outline


    @classmethod
    def from_json(cls, obj):
        return cls(book=obj['book'], bookspine=obj['bookspine'], outline=obj['outline'])


# Class to decode JSON to class objects
class JsonDecoder(json.JSONDecoder):
    def __init__(self, *args, **kwargs):
        json.JSONDecoder.__init__(self, object_hook=self.object_hook, *args, **kwargs)

    def object_hook(self, obj):
        if '_type' not in obj:
            return obj
        type = obj['_type']
        if type == 'Book':
            return Book.from_json(obj)
        elif type == 'Block':
            return Block.from_json(obj)
        
        
# Function to calculate distance between two geo-points
def distance_between(lat1, lon1, lat2, lon2):
    r = 6378.137 # Radius of earth in KM
    d_lat = lat2 * pi / 180 - lat1 * pi / 180
    d_lon = lon2 * pi / 180 - lon1 * pi / 180
    a = sin(d_lat/2) * sin(d_lat/2) + cos(lat1*pi/180) * cos(lat2*pi/180) * sin(d_lon/2) * sin(d_lon/2)
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = r * c

    return distance / 1000


def check_isbn_10(isbn):
    i, s, t = 0, 0, 0

    digits = [int(d) for d in isbn]
    
    for d in digits: 
        t += d
        s += t

    return s % 11


def calc_isbn_13(isbn):
    digits = [int(d) for d in isbn]
    
    check = 0
    for i, d in enumerate(digits[0:12]):
        #print(i, d)
        #print(d * (1 + 2 * (i % 2))
        check += d * (1 + 2 * (i % 2))
        
    return (10 - check % 10) % 10


# Test recognize:
# gcloud auth print-identity-token
#headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjY1YjNmZWFhZDlkYjBmMzhiMWI0YWI5NDU1M2ZmMTdkZTRkZDRkNDkiLCJ0eXAiOiJKV1QifQ..oby53OATR_4VfLZpiXPWJSac0PDG_MS6a5FBxIrdZYucy4-_5vVoggx1xNOOhOd7WRhrJ_6awYdf_eIes_kbVdPjfUsTslJUQCOc6tjH8sy69dqilwrSNqub1WPttcMUlq_t8qxKRlyZRL6a5uw7RjmU3MBJrjTyaNEq-XM1KrcVY1bW1Gwt7nAGGE8yqvuPzfVSyz-EgZ9fJFkl9hXDYhoBoL2mPv_43Z1dXBjK9QOcZ_3p4sKJKjERmXrWHANY-mA4__qeaTnpA-eh9nVr-H6CGFdOEmhRKNrHecW0QBi5aZYgLK3Af1DBDFUhaq5Ot34f4XZ81P7S1u--JmDtCA"}

    
def get_book(isbn):
    try:
        endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/get?isbn=%s" % isbn

        res = requests.get(endpoint, headers=headers)

        if not res.ok:
            print('HTTP error:', res.status_code, res._content)
            return None
        
        res_json = json.loads(res._content)
        books = [Book.from_json(obj) for obj in res_json]

        if books is not None and len(books) > 0:
            return books[0]
        else:
            return None
    except Exception as e:
        print('Exception for book [%s]' % book['id'], e)
        traceback.print_exc()
        return None

    
def add_books(books):
    endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/add"

    body = {'books': [
        {"isbn": b.isbn, 
         "title": b.title, 
         "authors": b.authors,
         "image": b.image,
        } for b in books]
    }
    res = requests.post(endpoint, headers=headers, json=body)
    
    if res.ok:
        print('%d books added' % len(books))
    else:
        print('HTTP error:', res.status_code, res._content)
        
    return    
    
    
def search(query):
    try:
        endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/search?q=%s" % query

        res = requests.get(endpoint, headers=headers)

        if not res.ok:
            print('HTTP error:', res.status_code, res._content)
            return None
        
        res_json = json.loads(res._content)
        
        print(res_json)
        
        books = [Book.from_json(obj) for obj in res_json]

        if books is not None and len(books) > 0:
            return books[0]
        else:
            return None
    except Exception as e:
        print('Exception for book [%s]' % book['id'], e)
        traceback.print_exc()
        return None
    
    
def recognize_image(uid, image, shelf, point):
    #endpoint = "https://biblosphere-api-ihj6i2l2aq-uc.a.run.app/add_user_books_from_image"
    endpoint = "https://us-central1-biblosphere-210106.cloudfunctions.net/add_user_books_from_image"
    body = {
              'uid': uid,
              'uri': 'images/%s/%s' % (uid, image),
              'shelf': shelf,
              'notification': False,
              'location': {
                  'lat': point.latitude,
                  'lon': point.longitude,
                  'geohash': geohash2.encode(point.latitude, point.longitude)[:9],
               }
            }
    
    #print('Input:', body)
    
    res = requests.post(endpoint, headers=headers, json=body)

    if res.ok:
        print(res._content)
        return True
    else:
        print('HTTP error:', res.status_code, res._content)
        return False
    

# Run command line to get JWT token
def cmdline(command):
    process = Popen(
        args=command,
        stdout=PIPE,
        shell=True
    )
    return process.communicate()[0]

# %%
# Script to create data for Bilblosphere v3 
# - copy "bookrecords" to "books"
# - "users" with books to "bookplaces" (group books by location hash)
# - "shelves" to "photos"
# - copy wishlists from "bookrecords" to "users"
# CLEAN "photos", "books", "photos", "bookplaces" BEFORE RUN!!! 

db = firestore.client()

# Loop throug all users. Select for each user all shelves and bookrecords (wish and books).
#users = db.collection('users').limit(30).stream()
users = db.collection('users').stream()
users = [u for u in users]

for u in users:
    u_data = u.to_dict()

    # - Copy all wishes to "wishlist" property
    wishes = db.collection('bookrecords').where('ownerId', '==', u.id).where('wish', '==', True).stream()
    wishlist =  [w.to_dict()['isbn'] for w in wishes] 

    if len(wishlist) > 0:
        print('Wishlist updated', u.id)
        db.collection('users').document(u.id).update({'wishlist': wishlist})
            
    # - Group all books and shelves for the same geo-hash (first 7 positions). Create bookplace for each geo-hash.
    books = db.collection('bookrecords').where('ownerId', '==', u.id).where('wish', '==', False).order_by('location.geohash').stream()
    books_data = [b.to_dict() for b in books]

    # Only do for users with books
    if len(books_data) > 0:
        # Get user email 
        user_auth = auth.get_user(u.id)

        # - Create "photos" records for each "shelves" record. Link it to user.
        shelves = db.collection('shelves').where('userId', '==', u.id).stream()
        shelves_data = [s.to_dict() for s in shelves]
        photos = {}
        
        for s in shelves_data:
            if 'image' in s and s['image'] is not None:
                photo = {'photo': s['image'],
                         'reporter': s['userId']}
                
                if 'position' in s and s['position'] is not None:
                    photo['location'] =   {
                         'geopoint': s['position'],
                         'geohash': geohash2.encode(s['position'].latitude, s['position'].longitude)[:9],
                        }

                photo_ref = db.collection('photos').document()
                photo_ref.set(photo)
                photo['id'] = photo_ref.id

                photos[s['image']] = photo

        bookplaces = {}
        geohash = ''
        bookplace = {}

        for b in books_data:

            # If first book or book from another location -> create bookplace
            if b['location']['geohash'][0:7] != geohash:
                geohash = b['location']['geohash'][0:7]

                # Create bookplace record
                bookplace = {'users': [u.id], 'location': b['location']}
                
                if user_auth is not None:
                    bookplace['email'] = user_auth.email
                    bookplace['name'] = user_auth.display_name
            
                # Keep bookplace record in Firestore
                bookplace_ref = db.collection('bookplaces').document()
                bookplace_ref.set(bookplace)
                
                bookplace['id'] = bookplace_ref.id
                bookplaces[geohash] = bookplace

            # Create book record
            book = {'bookplace': bookplace['id'], 
                    'location': b['location'],
                    'owner_id': b['ownerId'],
                    'authors': b['authors'],
                    'title': b['title'],
                    'isbn': b['isbn'],
                    'cover': b['image'],
                   }
            
            # If book refer to shelf -> update shelf location and bookplace (if missing)
            if 'shelf_image' in b:
                book['photo'] = b['shelf_image']
                
                if b['shelf_image'] in photos: 
                    book['photo_id'] = photos[b['shelf_image']]['id']
                else:
                    print('DATA MISSING: shelf is missing:', b['shelf_image'])
                
                if b['shelf_image'] in photos and 'location' not in photos[b['shelf_image']]: 
                    photos[b['shelf_image']]['location'] = b['location']

                if b['shelf_image'] in photos and 'bookplace' not in photos[b['shelf_image']]: 
                    photos[b['shelf_image']]['bookplace'] = bookplace['id']


            if 'ownerName' in b:
                book['owner_name'] = b['ownerName']

            # Store book in Firestore
            db.collection('books').document().set(book)

        for key in photos:
            p = photos[key]
            
            if 'location' not in p:
                if 'location' in u_data:
                    p['location'] = u_data['location']
                else:
                    print('DATA MISSING: location missing:', u.id, p['photo'])

            # Update photo in Firestore
            if 'location' in p and 'bookplace' in p:
                db.collection('photos').document(p['id']).update({'location': p['location'], 'bookplace': p['bookplace']})

# %%
# Script to fill data for PHOTOS
# 1. Add thumbnail link
# 2. Add data from place (name, contact, privacy, type)
# 3. Check that location is present
# 4. Update count from number of linked books (compare to GCS .json file)
# 5. Update privacy if missing

db = firestore.Client()

photos = db.collection('photos').stream()
photos = [p for p in photos]

count = 0
for p in photos:
    # Calculate number of books for each photo
    books = db.collection('books').where('photo_id', '==', p.id).stream()
    books = [b for b in books]
    
    db.collection('photos').document(p.id).update({'count': len(books)})
    print('Photo %s updated: book count = %d' % (p.id, len(books)))
# Out:
# Photo 023YA6RIB7A3boAmZBOq updated: book count = 3
# Photo 04XS6mfIPPNfdLANKW15 updated: book count = 8
# Photo 0Ftx3WNzNuVOEYz6qjI7 updated: book count = 7
# Photo 0HH4DJqHLNGKDt8vZFI7 updated: book count = 0
# Photo 0HRgzb6AOCcE7fjNrwEV updated: book count = 5
# Photo 0OpvuxYsnEKWrlCsYQOr updated: book count = 5
# Photo 0PKtBScyNv6PHqXCZD9d updated: book count = 6
# Photo 0SYzLN5iJpzVpgV7XQJ6 updated: book count = 1
# Photo 0TO9zoqBofca2EyVLAA8 updated: book count = 6
# Photo 0TpQuSgadZ4lycM6GV6q updated: book count = 0
# Photo 0XecNURSwdYuv2sAp8Oy updated: book count = 2
# Photo 0eX4PP0z099MKwmZZe3w updated: book count = 2
# Photo 0fLNBTsNo9X0YeKGxWoh updated: book count = 0
# Photo 0hbjyQo4DlFftYV8WN9s updated: book count = 4
# Photo 0kLjOqC3Z8g7HIvRPMGi updated: book count = 0
# Photo 0sqllUakEpoSPAJSvVjX updated: book count = 15
# Photo 0tBkHqzASZCdvjeChSQW updated: book count = 1
# Photo 0tQcqKdofvFjxbG8QdhR updated: book count = 2
# Photo 0wxgeFWJ5y7C3yAfhhY4 updated: book count = 2
# Photo 0yUOgq7hjApGwORz0FDw updated: book count = 16
# Photo 11sCXZT4AmfT1fyP3uQh updated: book count = 4
# Photo 13PH07ieRKtMl0KtxZ7f updated: book count = 1
# Photo 153cDVzxCLLxRdWYuHJ1 updated: book count = 0
# Photo 15X3RtHTvUo4abwRJNgO updated: book count = 0
# Photo 1Bywd45CFQW6pzgnsznn updated: book count = 2
# Photo 1DoUjJezsAcWaeyNdXUx updated: book count = 0
# Photo 1ElJ9RPKkIgBqnz4Ponv updated: book count = 0
# Photo 1HnMo7rNG0F1vdhufkL6 updated: book count = 1
# Photo 1Nkiz3YNQyGVvdHolf6x updated: book count = 2
# Photo 1Qkw3EZgnMNoyLwwsPmr updated: book count = 0
# Photo 1Sbg2s4bg75N4Pe6QEio updated: book count = 6
# Photo 1V95Jt3s5DBMUzCC8xIT updated: book count = 3
# Photo 1VTMXzJW7mMWuVM5DQ4Y updated: book count = 9
# Photo 1esSFQfqb1pWbGOc1Rmj updated: book count = 12
# Photo 1f8tAkKX7Sw4jhZBJmzb updated: book count = 3
# Photo 1oAsujD1ST5LeVd7oya1 updated: book count = 2
# Photo 1uPh6Zn9PnPej1SsOG8l updated: book count = 6
# Photo 1w0XxB5H1nyY0yfkLRYl updated: book count = 0
# Photo 1xbzGeQPqLRh5F0MabTg updated: book count = 6
# Photo 1yMmhG6CbwGdkOay2xBT updated: book count = 2
# Photo 250nojMEjQGHwQYkF0og updated: book count = 0
# Photo 2KXNdOBpL1WCmAGE4fle updated: book count = 0
# Photo 2SalfEzhS2HHxQ3rQW0M updated: book count = 7
# Photo 2WZpOd4vEiwEkAljRzRw updated: book count = 0
# Photo 2gvFhyE2fZ9OWET8GRc7 updated: book count = 8
# Photo 2m4AjksJpRn9K1AEi8iE updated: book count = 1
# Photo 2p5uX5aKaUFUKlAo7KhW updated: book count = 11
# Photo 2sbdY7e3VD8hIVcoeh1s updated: book count = 7
# Photo 2yUy6Dcz2AafGS1QfRAx updated: book count = 13
# Photo 34MjZF59QMu3m8vHbSi5 updated: book count = 3
# Photo 3BG1udQExfDwZMBDK5zK updated: book count = 2
# Photo 3EBjcY5eua7XjfQxbSm8 updated: book count = 6
# Photo 3FjgVRGCoNDdC18sCp23 updated: book count = 12
# Photo 3NLT2MSwBqcRLWyfe6qj updated: book count = 12
# Photo 3NXpOnCp0gq62pxQmxRE updated: book count = 0
# Photo 3SFB8BHNjcuZpcDsWtq6 updated: book count = 4
# Photo 3aQ5Aq6y00yd2QlcH92k updated: book count = 6
# Photo 3cKVvuschO7CKf7R89hi updated: book count = 4
# Photo 3hXAuge6zIo8xrIxutCh updated: book count = 4
# Photo 3l2x1rabL9QaJzzBsE7c updated: book count = 3
# Photo 3l62P2NKmgJXANzmV6As updated: book count = 0
# Photo 3nWI40PQJ8u0rCfTaiWp updated: book count = 7
# Photo 3s6Am4UxI1EAT8JzHplv updated: book count = 0
# Photo 3wMRdfSiaVY3shVKcegp updated: book count = 9
# Photo 3wfqTgvP6txKNYy37DdG updated: book count = 0
# Photo 43fKfeqs2JwgnvhJC5ZQ updated: book count = 4
# Photo 46ZcPTkOGmB5tfa7YA8e updated: book count = 2
# Photo 4EukdH5XqrEyge0bKCsl updated: book count = 6
# Photo 4HPeyWLfochIbngtfQTO updated: book count = 0
# Photo 4K4e42A1pt3Rt2mbjpmY updated: book count = 3
# Photo 4NUevorzlIfmp4xlB6HV updated: book count = 8
# Photo 4RqusVKIR43YoBcc0DIR updated: book count = 2
# Photo 4iwC8cmXZTw1hxher3TP updated: book count = 0
# Photo 4ylNLCPdaMUG3NbSUZSg updated: book count = 3
# Photo 5E8YuQtkfDnUEtaGRETt updated: book count = 10
# Photo 5JOxISfEsPm0ZBI5yVje updated: book count = 11
# Photo 5V0OqR3qXDuwdScMmFp4 updated: book count = 0
# Photo 5hsLKJg9rKHBrOI5wydR updated: book count = 5
# Photo 5pU1arpOuy6jhI2ogz2k updated: book count = 7
# Photo 5q7RrvPTPbfmgUqOyY5W updated: book count = 7
# Photo 5qzFGbFdTiGYVms76rjX updated: book count = 3
# Photo 5rUVebvsjxFxB39CMaKc updated: book count = 0
# Photo 5wT7bve0jXyOZoIdC3Fv updated: book count = 3
# Photo 61I0ebFB06bY2vyn11CZ updated: book count = 15
# Photo 6OZ9l9sXT8GSTgbZtTka updated: book count = 3
# Photo 6RpKdfzzRb3QVyy1heKR updated: book count = 12
# Photo 6WW3jwqkxjqdIFUIbEsl updated: book count = 12
# Photo 6jj1bANfCHQU22bR9u6V updated: book count = 0
# Photo 6qBtsxh3rliUZStveDc7 updated: book count = 0
# Photo 6rDo8jSUkQU7QPRGQrbL updated: book count = 16
# Photo 6sMNbyTuG1HQiLpW7Jtn updated: book count = 0
# Photo 6uTgaC95qdS6I1AQNlim updated: book count = 2
# Photo 73NGwrx73wIVKcZpiVDE updated: book count = 11
# Photo 79Bv2iCZeotiY7BhgO4j updated: book count = 0
# Photo 7ILqQ3kohApC9dslGwbT updated: book count = 5
# Photo 7IltgoMHMg4PROfNwqHh updated: book count = 10
# Photo 7MpISTN2OS1Q7l0cH1Pa updated: book count = 3
# Photo 7SFfHM9zXlWRB9Byjl1b updated: book count = 0
# Photo 7WMnEUIWfimvCZK0kmtz updated: book count = 3
# Photo 7XOU0bawdjbjJEDSsolE updated: book count = 0
# Photo 7gIfWCldyDSSZFfTY6od updated: book count = 2
# Photo 7kOsf04nUCAcXxUT4nol updated: book count = 0
# Photo 7maInPHJXNO0SzLs69mz updated: book count = 3
# Photo 7ov4FV2ixBO98jw3RQDT updated: book count = 0
# Photo 7r2PHrkZudcgr6GawVq1 updated: book count = 15
# Photo 7tUfqxxch6Qxl2SsOOSO updated: book count = 4
# Photo 7y73L20Nx2YsSM6Dz2vg updated: book count = 0
# Photo 7ylDjrr6LgDcWKtg82Gg updated: book count = 0
# Photo 80gzxpRaGKrtfAtameBQ updated: book count = 12
# Photo 895bwysLt2Fqyj8bri8Z updated: book count = 0
# Photo 89NqkpKlyyaS0MRk6rIO updated: book count = 0
# Photo 89WCVEWsvMP2CaXoWYGw updated: book count = 0
# Photo 8Fj5MbvHyj4B9KiDtjZE updated: book count = 0
# Photo 8N1BzzkSIpoSKLVlHo60 updated: book count = 11
# Photo 8NpmRXfWzeMMDS55a8Wx updated: book count = 5
# Photo 8Rog0PGHTmCMbBYttBFV updated: book count = 0
# Photo 8SuxFxlnZkN0cq7yeonG updated: book count = 7
# Photo 8UGrloIEXDP776knW1sC updated: book count = 5
# Photo 8eb77vVcHm5M4GLNV7yA updated: book count = 0
# Photo 8ehUapMrlf6uZy4dWWNH updated: book count = 0
# Photo 8hjq7kCRM5Nmu6qhrNPI updated: book count = 11
# Photo 8ncrxiC6VdnYXF06cPDw updated: book count = 2
# Photo 8qe4qNx3Ow3oY7TWPJB0 updated: book count = 16
# Photo 8tebPe78jJgKyB9lNQnr updated: book count = 2
# Photo 95axISflDh5U30X299TE updated: book count = 1
# Photo 9JDQENNtnaTdk7bPuNlj updated: book count = 5
# Photo 9VYD5qhYjKZdd2G0Jov7 updated: book count = 0
# Photo 9brfDRRf36P0YFazT3g4 updated: book count = 0
# Photo 9fBSKBbmO9KSJjq8UoDf updated: book count = 0
# Photo 9gyQAqexAd4VkgqWx9Xf updated: book count = 6
# Photo 9ig60ozX50xIl92YqsJF updated: book count = 5
# Photo 9qyeYkKj1fz3BoP2LrDN updated: book count = 0
# Photo 9v576kkUa0IekfuWD3Ts updated: book count = 6
# Photo 9wRP92iU3QUdGJgTXOYE updated: book count = 1
# Photo 9xe0Lf6PEoScZcl7qtNW updated: book count = 13
# Photo A3ykUX2w9YOekZoTYo34 updated: book count = 4
# Photo A5uFvTUKAyjGP2DkR0J4 updated: book count = 17
# Photo ADT5v1U0y3T2XWsFlKk2 updated: book count = 1
# Photo AJpi5VRwiVuTmR3MIhR4 updated: book count = 0
# Photo AM8oeb92BDUP3TAt6RKi updated: book count = 3
# Photo AP5Sf86B9J9fPHcULDw7 updated: book count = 3
# Photo ASz2X4pRhVv73qiPq5fF updated: book count = 0
# Photo AT1bZRpeVTc4ijFaeB3H updated: book count = 0
# Photo AVc6zY8z1eTZFU4JFMu8 updated: book count = 10
# Photo AYAyh2pk43HRcItFpg6Y updated: book count = 0
# Photo Aa599pfY3pI50ZHOz4bC updated: book count = 0
# Photo ApAMIugSuz9ec1RGa3Cm updated: book count = 3
# Photo ArOEeyziDsFyz6RlWGIJ updated: book count = 12
# Photo Arh8FKz0vkIpJCWVUL19 updated: book count = 0
# Photo B1tP6Q4MYPJqAjV1YVln updated: book count = 11
# Photo B2tktnRXM57pwyP8JPO6 updated: book count = 7
# Photo B3CHDUeRZLGnwZck7gEz updated: book count = 4
# Photo BC819A7J9qv3hioMGaoK updated: book count = 0
# Photo BGlcvWy9QsDROeSzGdi7 updated: book count = 0
# Photo Bfee3OqObsyQ09tcG6Rb updated: book count = 7
# Photo Bhz21Ony9a4E4HWJRCRk updated: book count = 2
# Photo Bmbyhrep6YU7ONuZE005 updated: book count = 9
# Photo Bo3gXefCAuZKcjIkzFMZ updated: book count = 0
# Photo BoJy7maGfIdagj7XF7Xr updated: book count = 4
# Photo Bp2Qfn0eT0nfFTmWhEwh updated: book count = 12
# Photo Bps4kRUPEueTAqT9EzuA updated: book count = 3
# Photo BqpqfVn2SlPwBLVAEtgt updated: book count = 2
# Photo BtATp6mapjzCSLKAFQJ6 updated: book count = 0
# Photo C58iEnYFYzLoP4EUMkgT updated: book count = 5
# Photo C5kY7tHMgVtw88ooZ63e updated: book count = 5
# Photo C9MjmyOMkzcuchirEB93 updated: book count = 0
# Photo CBJmtGWS8AWuAC082Rlc updated: book count = 0
# Photo CI8X1nqVj26ORKlVnrqP updated: book count = 7
# Photo CIixLkCia4SdHds1UX7n updated: book count = 0
# Photo CJU2SgEMqK1yJQEPxHxP updated: book count = 0
# Photo CORY3iF0zajgQ4hLFeaS updated: book count = 2
# Photo CTf4vcHtxZcbLDTP7BCE updated: book count = 0
# Photo CX70I3KztZNu2WJSsWqZ updated: book count = 0
# Photo CZ6ObWBVnjJvIyq9TS2c updated: book count = 11
# Photo CdY3RAZ7rYcxwF6nxLoJ updated: book count = 0
# Photo CheWC5Jq2qrgZzIFKEWS updated: book count = 0
# Photo CmwA8M3lp1F83tU0sB5Y updated: book count = 0
# Photo CnlNQmEYyCmGjapd7LF0 updated: book count = 0
# Photo Co2WlVB3yYhZXEnB8c9P updated: book count = 0
# Photo Cp1v9WPom7IDCA9EFQd4 updated: book count = 0
# Photo CpoMRBxM26x39jcqSQId updated: book count = 5
# Photo CqDpE71xmMurRpNRkerk updated: book count = 0
# Photo Crtra2mByVu1AdWAwqMx updated: book count = 6
# Photo CuH1BUmnxi5hN0kPzM3H updated: book count = 7
# Photo CyYnjAO3L1qRKaZan28q updated: book count = 8
# Photo CzMPMbVi1lYbgqnpfGGF updated: book count = 4
# Photo D0h4i9dpNKSVMUsWXM6N updated: book count = 0
# Photo D16Nv3GEPfTwvw4Xex5q updated: book count = 4
# Photo D2DvSVxSZM8zKQ15LRv9 updated: book count = 2
# Photo D7vSOYqTdhHzrWFUqfW3 updated: book count = 7
# Photo DDsABRWogR15hGvlTuSg updated: book count = 4
# Photo DEhjhED7f8oTPPHDcLPT updated: book count = 0
# Photo DRUhFPh8czC5FeCI4VGe updated: book count = 6
# Photo DSNWrcLunxM5hEolLTQw updated: book count = 5
# Photo DXQpBtcXQxvf7wkQwWbv updated: book count = 8
# Photo DXyKvHcvXxVMnV3wAO3z updated: book count = 4
# Photo DYXbqQQurgg3OrUiNL9R updated: book count = 11
# Photo Dighh8tFa0iVomT7iVlw updated: book count = 4
# Photo Dn2hNmlzbKYVz2d92Zei updated: book count = 0
# Photo DroLMbSELNPLNMkfHCaK updated: book count = 1
# Photo Drwl2ub1ODCjr3Sfvsvm updated: book count = 5
# Photo Ds3hQ4ojXEAILZ7d8IDe updated: book count = 3
# Photo Dvdjxoayhl47tRTlSXCs updated: book count = 8
# Photo DwDChAwGVxaYYtDKMNqi updated: book count = 0
# Photo E0PZsCAExHLx9njYPrKL updated: book count = 0
# Photo E2nwrbgujtZbthByWaGA updated: book count = 1
# Photo E4Y4OVkBCHa4cdiqngyc updated: book count = 0
# Photo E6uMUQYMGu7GGDD3wpk0 updated: book count = 4
# Photo E8Z1kTomaH6fC6iChdZM updated: book count = 5
# Photo EAQJ7qvyY8OjZsc1eSHx updated: book count = 0
# Photo EAgRF03G7DMRFRUEBOYA updated: book count = 0
# Photo EFNoQ3ttY2rN1iA0cX7c updated: book count = 7
# Photo EFON9vFxepGIZGGXwwxY updated: book count = 5
# Photo EONy79JpYL6YY2oPnstQ updated: book count = 2
# Photo EVogUznsrQtpe5RHpLkl updated: book count = 6
# Photo Efal1n4KldbfafqKKQaq updated: book count = 17
# Photo EhrgL2eYjsNCzPXcjSxL updated: book count = 0
# Photo Em7CQD2DmIog7A7WGGRp updated: book count = 11
# Photo EvVa2RvSuw6ZJQd72zzT updated: book count = 0
# Photo F0NFXCeNZvGCq0aHBdjf updated: book count = 16
# Photo F8ItDeVB3UsRklIs7mEN updated: book count = 1
# Photo FI7whKwEMrzMUqZrxzXk updated: book count = 3
# Photo FJL7sGsakx8iqFPlB27p updated: book count = 0
# Photo FK7Dq7avP4En3LS0vWkt updated: book count = 2
# Photo FMBACbLLL1pQMtAHXQNX updated: book count = 8
# Photo FNDaB6XKS2iDaphjnqN9 updated: book count = 0
# Photo FSXwP5Kglqrc1oHj0T4g updated: book count = 0
# Photo FTtxQesBzUE5AKZHA4AB updated: book count = 3
# Photo FUaLYC13wYRIXZmA78q2 updated: book count = 0
# Photo FYWPWC5gqsDXghRDKjS4 updated: book count = 1
# Photo FbjBSeajoAMP5n3dBKMx updated: book count = 0
# Photo FdiCi0R9Tu8v3ITQIwVL updated: book count = 4
# Photo Ff4YWnVZpXGXPeLQsHiE updated: book count = 2
# Photo FkUf4U6f9rI5pb0KZBOY updated: book count = 7
# Photo Fnz8axPKGGcCV5RKQUOt updated: book count = 0
# Photo FpdPvfjdlXmSrRnsyPvj updated: book count = 0
# Photo Fr8mEfweHNMr5Fyq9a25 updated: book count = 1
# Photo Fs8ldaeE3jYcgLApuvM3 updated: book count = 9
# Photo FwP3J7kYgxrNyWFLdEnu updated: book count = 4
# Photo G1JsvvZphPTcE4VeqIOL updated: book count = 5
# Photo G5rkWLkkWZEK0unSIpQl updated: book count = 7
# Photo G6eg5gkBLoaWuO2166GU updated: book count = 0
# Photo G8JXCkUe0vA4nAOA0WdY updated: book count = 5
# Photo GGtO528y4ZFkNRVaosUL updated: book count = 0
# Photo GIqHuzVFhhLOd5XLU81K updated: book count = 0
# Photo GL6o0xRxOKFMKXpEiiaw updated: book count = 1
# Photo GOmp3GATr5QeNsFnFPOe updated: book count = 9
# Photo GQBKupQSvjL6WRayOVte updated: book count = 0
# Photo GVzTyI72pq5D7PytfSeJ updated: book count = 0
# Photo GWsswhwOIPs3pApNE7Ze updated: book count = 0
# Photo GYOTuyyxLMYD7fQlDagE updated: book count = 0
# Photo GYrXscRV3ZRNaGMGN6lh updated: book count = 1
# Photo GZlviYqXUQY4TPQttzE0 updated: book count = 8
# Photo GcKo1dqCk3CTFIIJBnrX updated: book count = 12
# Photo GgHERIn9fIt9Ppfya9PL updated: book count = 1
# Photo GlfYgqMhLjkZuA2SRXWu updated: book count = 0
# Photo GrHkIhTxNpfWD4aS1PZ8 updated: book count = 2
# Photo GvtNni037IXPvDu8Yrw7 updated: book count = 2
# Photo Gxa0U9GeKWULY4T3NQX3 updated: book count = 1
# Photo GyEKpNaPnVlA0O1MUGYL updated: book count = 1
# Photo H2DcnL0qISfjStgzvqOb updated: book count = 2
# Photo H97Xoe4faA52rF6yxalV updated: book count = 0
# Photo H9Pm3piKozJf0aTLz4GX updated: book count = 1
# Photo HBMAbtmVSPcBgOraUJYV updated: book count = 6
# Photo HH5tgVWC7uxylTSe8UUt updated: book count = 11
# Photo HM5Q0bspSa4zDrtpwfVC updated: book count = 2
# Photo HPHsByvDPf4jseSjjUPU updated: book count = 5
# Photo HPsk4sqTq2YSjqW5FzUX updated: book count = 0
# Photo HbPQJeDsBbtg1OsxouNe updated: book count = 0
# Photo Hcwg2Y5J6s5GSeTQo39Y updated: book count = 1
# Photo HgO2xKq7RwziMyNvKIYO updated: book count = 6
# Photo Hi1nnrGz6KUzypeXaP36 updated: book count = 0
# Photo HoGhaJWF9D6jt8XYIQbL updated: book count = 4
# Photo Hor4iyLQCsQfUGVLVJHW updated: book count = 0
# Photo HrGK8IZGdBI4GbDuH1V5 updated: book count = 3
# Photo HtXsWWBX14qwZSYDNCd8 updated: book count = 1
# Photo HwJkQU5a5pviM80T128Q updated: book count = 0
# Photo HyZ5THH6pUIeDL77Qjdp updated: book count = 9
# Photo I2hrsNVME2NGVYLzFmJh updated: book count = 0
# Photo I4dGcJWd6W8fiSOBRP5w updated: book count = 0
# Photo I6S4EW0Lq2ZqPoaifirf updated: book count = 1
# Photo INqA5UiP1EE7IuCZuKbS updated: book count = 2
# Photo Ifbe9T9AOTlk8VtVgNlV updated: book count = 0
# Photo Ifi0aWPMPR8dtuGLU8Fu updated: book count = 0
# Photo IgK9WX5xA2wGUxq3h6y1 updated: book count = 5
# Photo IkBL2sHl5mjMb3JLOxJB updated: book count = 1
# Photo IkKUXe7jdnCBvnxB7PTj updated: book count = 1
# Photo ImOhWdpecVMUvidfufTa updated: book count = 0
# Photo Imsh5Xlz1cDeZoH4zRN3 updated: book count = 8
# Photo Ioim0tfNEvlo9JqeHLVQ updated: book count = 0
# Photo Iv8Mtj1OscVqEepIjXpS updated: book count = 5
# Photo IvbMxVizsnTKEuS0Csmr updated: book count = 1
# Photo Iz9g9f3MfvFiTV8RY1pV updated: book count = 3
# Photo J5Aeo1edjWR8b09RhyUr updated: book count = 5
# Photo J6PeUMAJEhDrpuCzBDhh updated: book count = 11
# Photo J7mTQGfYBmeNhgip9dV9 updated: book count = 1
# Photo JIu9wRFb9nQVZ2iXazU9 updated: book count = 2
# Photo JWTLmVFtp27iHTO1RnP3 updated: book count = 0
# Photo JaK8nEdNJZZZ8LzqQHTb updated: book count = 0
# Photo JgM9cglDUMY3GggExH7P updated: book count = 22
# Photo Ji38UcxcMg3E6d0VM6tT updated: book count = 0
# Photo JkI2fILad7e6XOw8mMDj updated: book count = 0
# Photo JqSZrh4kiKBfH0bjUavn updated: book count = 0
# Photo Js4YUGEMPCUblPgUaeAG updated: book count = 2
# Photo JymEkvipuLkKT3uqztrV updated: book count = 6
# Photo Jzh4gg1IfXvcEpaKf0dh updated: book count = 7
# Photo K1BDe7c1F2f4ueCGA1X3 updated: book count = 2
# Photo K2VcKsNS4VXqcZBOtCtF updated: book count = 1
# Photo K9demzBpcmtHxE94S8E2 updated: book count = 1
# Photo KD8y5wezW2TAomGBiB1Y updated: book count = 5
# Photo KLXNYJcT8ewjI1Qnyrc7 updated: book count = 0
# Photo KOl9cwPakHRnLeDpiXJ1 updated: book count = 1
# Photo KUcj84EzIOooUnONiVww updated: book count = 8
# Photo KbpD2fIsuij1f8cBr0F5 updated: book count = 4
# Photo KcJwV0BXuAuPMOHKCCGt updated: book count = 0
# Photo KcgoL01kNZzSGkFpyRRQ updated: book count = 0
# Photo KifpQZTixzEM7UClaocm updated: book count = 5
# Photo Kn28AWeW5XigMmeLs005 updated: book count = 3
# Photo KoLlyVtuPM8KcOC6BoKl updated: book count = 2
# Photo KplUPTCF80xUEiAiYEIg updated: book count = 6
# Photo KrZ8GdQaaFaqPi751lc8 updated: book count = 2
# Photo Kwpeb58ay8E7u6g3Ej6y updated: book count = 7
# Photo L8CFmfzeCgrO8o3q5qQR updated: book count = 8
# Photo LAlPafanc0jNUTx69SBP updated: book count = 2
# Photo LG2e7TJQBA8K7CxuBqPi updated: book count = 2
# Photo LOirlXE2qDAbLGn9ZTGo updated: book count = 1
# Photo LXv2bkoHNKXDMrkArH5s updated: book count = 2
# Photo LYe7egJttfyTOoxypKVW updated: book count = 4
# Photo LZreliwTt005qhyqnjPQ updated: book count = 0
# Photo LeRpU2W6MZJDX6o8RMCG updated: book count = 13
# Photo LhaleY6bua6CutSeWTXn updated: book count = 18
# Photo Lm0oEdni3dmnvZM5DpiI updated: book count = 2
# Photo LmWGyr3WEBeT5YnJ8CEc updated: book count = 1
# Photo LntWF0a6utWgaOEyKHK8 updated: book count = 0
# Photo LqUNHOz2KwRsqyrIeacB updated: book count = 1
# Photo LvAwSYR1eqjlnpzp5EWs updated: book count = 4
# Photo LxriX9M8cHCCEBvpU0zS updated: book count = 0
# Photo M4UxMFwvg8sAneD2iEJA updated: book count = 0
# Photo M4ph1z3LS8ubDFtaFOlZ updated: book count = 3
# Photo M71jq4HYLHHPKlko8eRO updated: book count = 6
# Photo M7soif9oidqFbtP0mJZK updated: book count = 4
# Photo MFbagup4BnoUsVCLkPhL updated: book count = 2
# Photo MLcW6feu93xAGjL8BgO7 updated: book count = 13
# Photo MMuaHly8LQTDmOgheKM2 updated: book count = 7
# Photo MOkYAi6hyEF3GH3hJ4zq updated: book count = 0
# Photo MQlY8ik35vLZJpCytg7s updated: book count = 8
# Photo MRfKHcH7jUprtrXHLyPF updated: book count = 8
# Photo MS3DTFAA3u9zJrR55DSQ updated: book count = 3
# Photo MeHg2imnU7Tq5wW2G29k updated: book count = 3
# Photo Mjry3coBrw2jvluQf3ZK updated: book count = 0
# Photo MmEkmuFDe7P5yx0PJcJ0 updated: book count = 6
# Photo Mv0XXMCldaLrMB9n7di2 updated: book count = 9
# Photo MzZZavyf0Goo6zv1mINl updated: book count = 3
# Photo N1rof8rHRxT4cjBDQS71 updated: book count = 5
# Photo N1syKL5eIWiwBC1ffnOE updated: book count = 0
# Photo N2WuuIKUC2wuhfikkIVO updated: book count = 0
# Photo NGxql7IBFO2qKugYtWKY updated: book count = 13
# Photo NHWDooK8JjMVPsqy5OTm updated: book count = 5
# Photo NIitxRiHQtTlMp3lsQLU updated: book count = 0
# Photo NIxhZ0bk5bjHsMEXgKT7 updated: book count = 16
# Photo NL3323fKYicFKe8wj2ay updated: book count = 3
# Photo NTtVpnlZWRwesSvICWxH updated: book count = 1
# Photo NUNd4Atl1plmiZ5FfzeU updated: book count = 4
# Photo NYNi32ZZThs9I89d7LQV updated: book count = 0
# Photo NZkEuq2x21xqynqwcnAa updated: book count = 8
# Photo NhwYL48iy97sOSSWD16m updated: book count = 0
# Photo NoDdDBWFxvRqA9kN2I3t updated: book count = 8
# Photo NoTWtqf4dcguREVFP5Ll updated: book count = 0
# Photo NqWLuAGEzLCyzIxpqt7B updated: book count = 0
# Photo NtWhjV0OIzhShfVOJGCH updated: book count = 2
# Photo NtaynAAAQDKMjWRCloZw updated: book count = 2
# Photo NvmuSTVtdqcosETeFURk updated: book count = 0
# Photo NyfeVzaACDVhFyfE6AbY updated: book count = 0
# Photo O04d7F3LZjK8lqsOaaTb updated: book count = 6
# Photo O1KKFAGCzf5fPPgl3uTi updated: book count = 1
# Photo O4NO0EuHjJDo2n70jGtd updated: book count = 1
# Photo O97gIy8kSATm6W5HfWtx updated: book count = 10
# Photo O9DEhcS2GpnSNjLuWTPK updated: book count = 3
# Photo OK2BTIje31GepuLVbz0d updated: book count = 0
# Photo OMcYCPA1orodpIJvjWpM updated: book count = 9
# Photo OOn36050uP3djdGuuRt7 updated: book count = 0
# Photo ORSWz1g2mJTnRUjydCPL updated: book count = 1
# Photo OYstDzo6MA4sJGUsCRjL updated: book count = 0
# Photo OZYsVlltfYVzhLQiFzyw updated: book count = 18
# Photo OdyMLUKQAjyFtwSfXOep updated: book count = 1
# Photo OgbSwaOnjWPc6PE3w8ig updated: book count = 2
# Photo OlFhmgn3ewLNSgFRJIs4 updated: book count = 9
# Photo OuhhOKDtsSVXn02I2iBo updated: book count = 4
# Photo P0TeqZimBpSoeXtlSuNc updated: book count = 5
# Photo P3EeBemEm1ezp8UKCHIQ updated: book count = 4
# Photo P99aOmceOaFF3GeBFsKL updated: book count = 6
# Photo PFXAgmDJTWyQrqroDoxE updated: book count = 0
# Photo PFvvWHYNO8t8dAgeoG0W updated: book count = 0
# Photo PPyY8Z1XcFSyEz7oQzoc updated: book count = 2
# Photo PWl43zznCmPJ1FrvAnTR updated: book count = 0
# Photo PXhBMwabDX2gbBxLGqjt updated: book count = 1
# Photo PYphccqFoN6PBiPism50 updated: book count = 0
# Photo PbACP7a2o8UljMu5eVWj updated: book count = 10
# Photo PouwY6nPM3LPiAqfBxbQ updated: book count = 3
# Photo PqfBH6rK0Taf2qHdB4q7 updated: book count = 9
# Photo PyxOInOjthOEFEoovGlN updated: book count = 15
# Photo PzU94ctPzZFCVtdhh7VX updated: book count = 3
# Photo Q2ODIZwhxGdb3DaEa55g updated: book count = 3
# Photo Q3FgiYNBSABAeHq9wgXF updated: book count = 12
# Photo QDLNaRHkLwZuCiszVVlX updated: book count = 0
# Photo QFAwjmsbZMpGxGE6pVlu updated: book count = 0
# Photo QKGVnxOYJilYBW5I910s updated: book count = 8
# Photo QTiDBe3HmrHNec1ooQFw updated: book count = 12
# Photo QWQHQ7hO0Z1ENuA4cioq updated: book count = 5
# Photo Qe8VuQ8AMe73TmVVOYOl updated: book count = 0
# Photo QgS1WFPU6ZWddHOB1RB4 updated: book count = 3
# Photo Qn4GaqOnQYAzNAxqgdNK updated: book count = 6
# Photo QnhJi9JwJvegP4ik2d78 updated: book count = 6
# Photo QsWz6vDdzMcKnG9gGtoR updated: book count = 0
# Photo Qt9iQ3eGwUwdZaoJ38Ky updated: book count = 3
# Photo QtfHbGoycBzmuEHKl5JP updated: book count = 8
# Photo Qv1tBXJg3iajoZsiUx2p updated: book count = 4
# Photo QwNvhFYEHQXgT2quBeKQ updated: book count = 4
# Photo QxLp1syqsWK2iYSaGX8X updated: book count = 0
# Photo QzHkB2piBnmgASJQvMmx updated: book count = 1
# Photo QzPfG9F3TE7W0CU0zkvk updated: book count = 2
# Photo RCLA5P17AiA6cF0bxqvd updated: book count = 12
# Photo RHxa7OOXgEtWPC3e0aKc updated: book count = 6
# Photo RK8IOJcf2pINDGxdPAsX updated: book count = 7
# Photo RKnzNPvNWnFBB9MTFJiB updated: book count = 9
# Photo RRSp6PGXF5n97X5C7wbq updated: book count = 4
# Photo RTLWafsfnRZGkVJhmi6f updated: book count = 0
# Photo RVtzzaSnpPFRW2UuCLUt updated: book count = 0
# Photo RacyH7foerW4FG9z3aT7 updated: book count = 2
# Photo RlrJS9KWntOtsAE1uhI5 updated: book count = 1
# Photo RmOj5BbSLUbGKET3KtUE updated: book count = 0
# Photo RnURcWLMzXdLWZM1v25G updated: book count = 0
# Photo RqbMcxt8qLZCZzBUIvOT updated: book count = 1
# Photo RsWACiOa7ypwFrlUnI14 updated: book count = 2
# Photo RtvbU0T8l4Y5QWmAl960 updated: book count = 14
# Photo RwUL0t57AcSFT0TwZAhU updated: book count = 0
# Photo S1Y1LuNVilv05egaz0dv updated: book count = 0
# Photo SD7jsrIk5mvwDyVFpsrE updated: book count = 4
# Photo SEmyaC1dr8XmpvAQHZF8 updated: book count = 7
# Photo SFgyEY55URhMLNlstiJ9 updated: book count = 0
# Photo SHF9GeJZ9WzwCjJNFZHt updated: book count = 0
# Photo SHSMX1DfvFYIBKTSrHQ2 updated: book count = 1
# Photo SM6RMosGbprrYokxtbfj updated: book count = 0
# Photo SPm023uVSvqYJh0X9oiH updated: book count = 5
# Photo SSkCZOmVYjaeWG0uvZRT updated: book count = 0
# Photo SUGDPV5ago3aJmhoL6EE updated: book count = 5
# Photo SWu48WskBYIXOyZ13kPA updated: book count = 1
# Photo SXAXDE3nSh2M3nAhjRvq updated: book count = 0
# Photo SbAdQ65879BxI5HQBDaZ updated: book count = 3
# Photo ScLqp6wejTB6F0sNAvZx updated: book count = 5
# Photo SuDP1zmhz174H6unL5U3 updated: book count = 4
# Photo SvCK77kNeD8GFguB5Kns updated: book count = 3
# Photo SwcZmShc1eDhNnJpsM2X updated: book count = 0
# Photo T64b7zQ5J16bmyiCraaw updated: book count = 0
# Photo TExEhqQQ5BJXhhQKzR9S updated: book count = 3
# Photo TZAXtgdoDmrhy8KwPhqq updated: book count = 8
# Photo TgIBFAlv6Tu7SanI04tR updated: book count = 4
# Photo TkLH6MXw1xAPvkTh7xlh updated: book count = 6
# Photo TnPHhsMGqxWFo9UjNteH updated: book count = 4
# Photo TnvPErBMeIqnUnyYcwxI updated: book count = 9
# Photo Tnzk2AktwNWTI40034dV updated: book count = 0
# Photo TzlyaxAiCninH0VGvQ4s updated: book count = 3
# Photo U73IYD9tT3K1ce7PevZa updated: book count = 4
# Photo U7StBPzL9VSDwUjIcV9P updated: book count = 7
# Photo UHXa1cCyH2pk8KXlJJ6v updated: book count = 1
# Photo UHbOtiq4mtaSuMfBqtWR updated: book count = 4
# Photo UKzgKPf3FY5GlCOFL7Or updated: book count = 3
# Photo ULbowR0wQl2ICEltvQZH updated: book count = 0
# Photo UU4Sdcbr9EpgJFQQjvX3 updated: book count = 7
# Photo UUDOWIjBSBH2lgEWaVqp updated: book count = 0
# Photo UUX9BsPP18sqgapkGX7f updated: book count = 11
# Photo UXw291UdQ2zJrGxyuiBj updated: book count = 0
# Photo UeolKF3TLZPIRhDx8ABF updated: book count = 3
# Photo Ufg0DTY4dZs6nFBQlSDh updated: book count = 0
# Photo UhViZ7Gg96C1Y924HNil updated: book count = 0
# Photo Umwiy5MXiGirWTUxAld1 updated: book count = 0
# Photo UvbI835Zqif12ljtBGmw updated: book count = 1
# Photo V0zGwDmgB1gW1DkkiXHu updated: book count = 13
# Photo V2uId4dkXO3PLp3Cu2ol updated: book count = 3
# Photo V2w1mIKZldN6Chm3Nnzl updated: book count = 2
# Photo V3IVEMONuBoR56Xfb8XX updated: book count = 0
# Photo V6ImQyyEZBeSDgURvmRy updated: book count = 4
# Photo VD8fSbzFVc76F97pmJHI updated: book count = 8
# Photo VDSwiBzBeDZhw99MRtE9 updated: book count = 4
# Photo VIngFrfv1n16z2HWXCnk updated: book count = 1
# Photo VKzUCA8Tq4dttNGxSSJa updated: book count = 0
# Photo VQXV3wgMpz7GvqDdxQCv updated: book count = 0
# Photo Vg28aSSmbePNCFgH5Oqz updated: book count = 5
# Photo VjtU7dViKuBIVdvKFibc updated: book count = 0
# Photo Vq75oXjXMOmzq1KKXr9p updated: book count = 5
# Photo Vt2l9pYGugz73FmiecSz updated: book count = 5
# Photo W7cHop851JAkYa3sKi4d updated: book count = 12
# Photo WGJxcFQ0Od7VPln60xVN updated: book count = 2
# Photo WHFJRPbjgPMEH7tn4Kpv updated: book count = 13
# Photo WLAgK3MIGiJqP6pi8v5x updated: book count = 2
# Photo WLqgDeGMiCLJNqhOzVse updated: book count = 0
# Photo WQkrx9QH7U0zAYwODCae updated: book count = 5
# Photo WS945v5wZ0bFyHaFN5NT updated: book count = 2
# Photo WTZcuO4KrdtlIPsCdjvK updated: book count = 5
# Photo WVpOvMp73MzOnglh6Kiv updated: book count = 2
# Photo WX4TK3uVoHEmfa24zxNY updated: book count = 4
# Photo WXtOoSpvVzfDRG0bERr1 updated: book count = 3
# Photo WYl5k5UBjYuzTxlCxkWn updated: book count = 1
# Photo WbKAn97yssIjVWKruVnD updated: book count = 1
# Photo WfVr66COscJCmaIFzqfm updated: book count = 13
# Photo WfpQrBMmAv7x0ULpoczb updated: book count = 0
# Photo WhVpaURLOXoXOnOv97oY updated: book count = 0
# Photo WiaVYXeCWjH5sxjDdAe2 updated: book count = 11
# Photo WlhNaUjdO8qYEWnkbzyq updated: book count = 0
# Photo WmOFpQlRTZtSZPzAUf50 updated: book count = 0
# Photo WmgRf5XOnROos1ktxtpF updated: book count = 10
# Photo WpfMqhzNHRPhkNlVsPRw updated: book count = 8
# Photo Wq47cfgpF13oNTW2E4l6 updated: book count = 2
# Photo X7Ed3uYJjmJgzwIYXGEG updated: book count = 0
# Photo XFmhmAZCSekr3Y4uVFwp updated: book count = 0
# Photo XIVO8xW6TYr3OkgxoScK updated: book count = 0
# Photo XLKjU6DKzxkVU9HdaGvs updated: book count = 0
# Photo XMRPLkaH1GhDXpqd9oX1 updated: book count = 5
# Photo XN3Ee8LQaxoMLpvYy8bF updated: book count = 0
# Photo XS4FcJE0GRZ4ckvDsKfo updated: book count = 11
# Photo XTlw12RJ9kFkhKqxUMcW updated: book count = 0
# Photo XWNo73rXmbtGL3Axb5dd updated: book count = 0
# Photo XXnAQfbbU6D0nCHVYuDH updated: book count = 1
# Photo XYJPU213U16v7EbQ3pWs updated: book count = 1
# Photo XbnHv09QDFIrHxc5R0LX updated: book count = 0
# Photo XecjFZIYihKInGikZJlr updated: book count = 2
# Photo XiCFBvGf9YqeTGlYfHQY updated: book count = 0
# Photo XjaRvHZzc6oxRIl5P0j8 updated: book count = 0
# Photo XopB1uMOLgH3e90Pf2rx updated: book count = 3
# Photo XpZiK9JQNXCXDZlwJhk9 updated: book count = 8
# Photo XpkemHmvwI1548sb7Vix updated: book count = 6
# Photo XuvJ8MZ1EWElUZlY0APv updated: book count = 5
# Photo XzrRX2EUeKOz4YNKFHAs updated: book count = 0
# Photo Y7tQ7PFEb0JWGQFDhtsT updated: book count = 0
# Photo YB1hvuWPG5yTgFuRyadj updated: book count = 5
# Photo YDcMwetg7pOTafNZpjYg updated: book count = 0
# Photo YEQaSuCmK2ShspOaNOjo updated: book count = 4
# Photo YHq4ibSBXaAPntydZgIS updated: book count = 0
# Photo YHuXF8jOkKpmB7WkN2t4 updated: book count = 0
# Photo YIKaoJnWdqNIe7GleZ8D updated: book count = 1
# Photo YKKCsmX3i2LihpQkBprj updated: book count = 0
# Photo YL3f9Jg0CFccx15MeiWW updated: book count = 10
# Photo YNapQxGwC80oMuLIBWvy updated: book count = 0
# Photo YOEkSeQ0l7kkoI8xmr0h updated: book count = 0
# Photo YP5QqYyiSJtiv3G9tyem updated: book count = 7
# Photo YR46jm1vgL3hBCM4sa7t updated: book count = 8
# Photo YSGTCknHVaUOBv3u2kI9 updated: book count = 7
# Photo YSRYWlsjvplwX5EgmxCW updated: book count = 1
# Photo YeC9boBqeBmd3GYA2wVc updated: book count = 11
# Photo Yk5FE6TIK50NcIb9qyfz updated: book count = 0
# Photo YqZJSjfFrPOZjxvwAAIg updated: book count = 2
# Photo Z23o6tZhFspR4cDBxlVh updated: book count = 2
# Photo Z36PmKTsfNCoChp247mE updated: book count = 0
# Photo ZAqEJAlFtT1pbcSAidEA updated: book count = 1
# Photo ZCBcTYUZkvcYT3vQtOvI updated: book count = 3
# Photo ZDZ6HVtPa8quyrd53HUF updated: book count = 0
# Photo ZFyHGmeGzh1z37tDgAQ7 updated: book count = 0
# Photo ZULBBvwxYwUpHxeFDu6u updated: book count = 1
# Photo ZVW0nz5yRbLRVJFOWjFo updated: book count = 2
# Photo ZVn0gEfdQn7wPjG4Q9Yk updated: book count = 0
# Photo ZYHwF2o12O0tWJlyKVq8 updated: book count = 3
# Photo ZZ3tvctNHdzBxoLNtucG updated: book count = 0
# Photo Zhnhcshkxz23gG1JNv62 updated: book count = 9
# Photo ZnOUoPAhA1BkpraABIum updated: book count = 1
# Photo Zoleicv6gcx7mRT4Yrou updated: book count = 0
# Photo ZxJdNoYEp1OaGPSXJkJa updated: book count = 3
# Photo ZxYFVr045MInWyk81EU7 updated: book count = 0
# Photo ZyKoz3mEEBRSVW0XKmKg updated: book count = 6
# Photo a0k2BtY236dEPobwKslk updated: book count = 4
# Photo a1LWD1XdtaMA8EYCmexj updated: book count = 5
# Photo a2DniUyUUvZcfjpFgxJn updated: book count = 2
# Photo a3FdxVMkhc0vEkhGJd90 updated: book count = 6
# Photo a6C9NZaKTM3SJV2UzGhw updated: book count = 4
# Photo aDSqexO47k0ajxXu9JAQ updated: book count = 0
# Photo aKZ2f7kqt6FbwDHqYipR updated: book count = 0
# Photo aKirAr0HAurFAMC72EeB updated: book count = 21
# Photo aO3KAWOV9ZfpP12YWD8C updated: book count = 0
# Photo aOeth5sjMRG01Oir6kon updated: book count = 5
# Photo aPYQnRAKRXTr62pkaXHJ updated: book count = 0
# Photo aPfraNicq1FBWO5Mr7OB updated: book count = 0
# Photo aR21TK09dw6S8ulsHm56 updated: book count = 0
# Photo aaRfzspu1n5k3OK1F311 updated: book count = 15
# Photo aiVhTgZl2PJWUKvh6WdY updated: book count = 9
# Photo amEKXfqq9v1I02FRfDnv updated: book count = 0
# Photo axPwbkt4YsySdyz3SRcm updated: book count = 0
# Photo ay34VaJKLJBFUsSei9sF updated: book count = 8
# Photo b3fhhsQslXh7TrVdPQRp updated: book count = 2
# Photo bD1ANlVCHbzy1YyZUiJL updated: book count = 13
# Photo bDzFDwNhmEKAOSjBxQgY updated: book count = 1
# Photo bFuht3Vnc75CIpzMEMnG updated: book count = 0
# Photo bJFAUYZQ25laZvRtpjEX updated: book count = 0
# Photo bQmJ02JNAm16tINess7j updated: book count = 1
# Photo bb4OkZMWF54xt0cxjobX updated: book count = 3
# Photo br1Hi7CErsdyXziLC69V updated: book count = 1
# Photo br6TGa4HGXU35k7DOgKq updated: book count = 2
# Photo buFBEdlPHfL8oPP86NkU updated: book count = 1
# Photo bzLTdG9VYUnkPMbyHgDH updated: book count = 0
# Photo bzmTohnZ14U8KzUzWTbn updated: book count = 0
# Photo c3OF7bClqpm8fxSMtEpc updated: book count = 16
# Photo cCej38JSPsV7L1hWhEPl updated: book count = 6
# Photo cF1ORgrST9AuOVzIUoR9 updated: book count = 0
# Photo cIi9hJWSrA0B825gkcZt updated: book count = 0
# Photo cPE9v8h03wcn2UHA6Hti updated: book count = 4
# Photo cU1K2ip0eQe6U8chzpjg updated: book count = 0
# Photo cUuiOksEohQfHQa7hATv updated: book count = 4
# Photo cVIBOTbvANVhp1cD2MBY updated: book count = 0
# Photo cWmnahDjz4yLYoiL4aF4 updated: book count = 6
# Photo cWuD5vVrZyZ2Jll7y6bu updated: book count = 3
# Photo cibkWiNMbbpkpoJjRVSd updated: book count = 0
# Photo ctfd55zWIgEo3N1WqJF2 updated: book count = 1
# Photo cuOtxh8J9M4A5rVlRWWM updated: book count = 10
# Photo cxrSMLUWHWM2lFF7dsm6 updated: book count = 0
# Photo d5zq0XdelkbHBoL0Yzv8 updated: book count = 0
# Photo dAkKkQJ8CQrsOGGOdd72 updated: book count = 0
# Photo dEZhFXpSbzviyAy1TKR3 updated: book count = 0
# Photo dRxnol7DpKP7IQOifjVa updated: book count = 2
# Photo dbBHJk6wQHXTE5XHTX92 updated: book count = 5
# Photo dd9ce4aL6tLbKociWoeq updated: book count = 4
# Photo dehZO4gcKnBo7lcvdWHI updated: book count = 0
# Photo dfxBfT6ihevWyvDRKSqu updated: book count = 9
# Photo dr50Qb94IIL6RKEeU9J5 updated: book count = 2
# Photo dt1US0Kqzay4fZPTLXfe updated: book count = 0
# Photo duiUsVkNLxsYHPtX4foB updated: book count = 0
# Photo dupiVgqy1DsZRUtJC0Gr updated: book count = 11
# Photo e79opeRXT5jMVHk1mTVJ updated: book count = 0
# Photo e7UP9afcfhrPqFmnNSkT updated: book count = 0
# Photo eD6kfjKB4987Gaxarf17 updated: book count = 5
# Photo eED8ZoicBqLLK1jrApbk updated: book count = 2
# Photo eIG03M8bE0ocPorNLbsJ updated: book count = 0
# Photo eLdelN0uemPSetgKlWrT updated: book count = 0
# Photo eOtjUo1QcEnI3JugWYLB updated: book count = 0
# Photo eQN0KXtkiQHFln6TMaFo updated: book count = 7
# Photo eSwBih8cCc8zQ9r5osyz updated: book count = 3
# Photo eUUAJhi3OeBAWkTbk7dL updated: book count = 8
# Photo ebzuV2poXtLJnVESCkts updated: book count = 0
# Photo ecmG1GKtJzazhN5bpV1s updated: book count = 3
# Photo egtsrMnh0jWXfFNyVdgm updated: book count = 7
# Photo ehVHRYNYy7QcLDX7jKPY updated: book count = 1
# Photo en2BZ0iaM5RwPKqu0sDZ updated: book count = 0
# Photo eqr681I3Z6bVom0lI3Jw updated: book count = 8
# Photo etKYp4gGJ2Aum1dAxYD4 updated: book count = 2
# Photo f06rhAyupwwzWuMkbKHW updated: book count = 1
# Photo f3Vpt7Si62qCokE4Nf11 updated: book count = 6
# Photo f5v2GYfSZK00al9Ewmqf updated: book count = 4
# Photo f65OHUM92nC0Il7L13Ox updated: book count = 7
# Photo f6rFWm3k23JZHywJMPk5 updated: book count = 5
# Photo f7Kq9OnDuUZApdcI0UKV updated: book count = 22
# Photo fBExtQHmBv4aj6ecH0dA updated: book count = 0
# Photo fDMQxRcvB987buvTeBNW updated: book count = 8
# Photo fF2pW0Qf3wB4TbfyHlGJ updated: book count = 8
# Photo fF62diF9TG9ZU9w9N8rZ updated: book count = 1
# Photo fFlJpBdIEx1xfnWcADsK updated: book count = 0
# Photo fGDynr9ClQWsdNNMBy3O updated: book count = 1
# Photo fMwyBKODipSZ15cts9kl updated: book count = 0
# Photo fSJHJSbVjkWBceFtqeEk updated: book count = 0
# Photo fYPJdeA4enE6NSR2Pzzl updated: book count = 10
# Photo fdWiJORTHguybj9yOUIb updated: book count = 0
# Photo fwxgUmlOVWqiFKkJ4Qfd updated: book count = 5
# Photo g0HwhEW3m6IEN0YhNEgL updated: book count = 0
# Photo g5uHNsbA4iFpyCEmd0Ny updated: book count = 0
# Photo gJHrzmUn3sv760fQhxeO updated: book count = 3
# Photo gUbhjxuBJocaGPpfFyHt updated: book count = 4
# Photo gUfjUZJVRD0rKW9bOQ3O updated: book count = 1
# Photo gZGrD0UjPrFjm4OE6vYo updated: book count = 3
# Photo gg95MesKQHXzomjR2zc5 updated: book count = 1
# Photo gkH8OMD2OjqLVwSWwsNI updated: book count = 0
# Photo gyt9nASPHgwnhZFr1Jom updated: book count = 4
# Photo h4IzF48wQdG58PN373xc updated: book count = 0
# Photo h68oaba9yjE6IkWOj0Bj updated: book count = 2
# Photo h8RC3bwvLJin5DecDeII updated: book count = 0
# Photo hIL5VSZWvjiPDIpxwfAK updated: book count = 7
# Photo hOf08BeTz8ptxHx1pXZV updated: book count = 0
# Photo hQKhU3Gtvi9QrBiwZMdy updated: book count = 10
# Photo hQkZmHWV1W10WFCYjoUn updated: book count = 4
# Photo hSAEdhY7Qmv5MndRTL1j updated: book count = 12
# Photo hSZr5MpmoCPYp71CVjz8 updated: book count = 12
# Photo hbMVw7iGjLs5qoEHhLaX updated: book count = 6
# Photo hboMcVIs3bUXpPWRy2iV updated: book count = 6
# Photo hhYIptTaJIofq169G9wH updated: book count = 7
# Photo hmRjodhX6iNLK6ck3Y8z updated: book count = 2
# Photo horImitTTILeMWUHgp2T updated: book count = 0
# Photo hrFTI0FWIUttwmbnUynR updated: book count = 0
# Photo huGbduGpxDjWgB59gGTY updated: book count = 6
# Photo i75Ltourlbe73iLmY6T6 updated: book count = 8
# Photo i9qPy5vOhYCveL4W0qXw updated: book count = 0
# Photo iCujdmGkzSWIoU8G4DON updated: book count = 0
# Photo iKAYwHeShC5YHtoxD802 updated: book count = 0
# Photo iKJJ0p4IK4oXixWwOIE1 updated: book count = 6
# Photo iN5n9Xw6qfXjb4wtQYGi updated: book count = 4
# Photo iQJxQqRaXJQAWnNU5tZe updated: book count = 2
# Photo iUdeCbpl447ST2JCwoyS updated: book count = 6
# Photo iVM36GWVT5gSpHYkUvxm updated: book count = 0
# Photo ijdkDFjMYWpgTKQwYhbf updated: book count = 0
# Photo imvlzs2H6t24NP7WdHZt updated: book count = 8
# Photo irSjzs5eciZcBMBclzfa updated: book count = 1
# Photo ixxq9w7AvZjcvQA6x5eW updated: book count = 1
# Photo jB9DpyT8ER4oWoBnnjfY updated: book count = 18
# Photo jH1mzPfEVwcciYyRgcSP updated: book count = 4
# Photo jKhWkOyXi49PXFPqdF0g updated: book count = 5
# Photo jUQBt5SPCRVyKpfvmeEp updated: book count = 11
# Photo jUx6E4hwqC5hnTajVzH7 updated: book count = 5
# Photo jWVJjYsbmlqgkPrtzivi updated: book count = 0
# Photo jXvHcTlbqFAsOOJv0BJL updated: book count = 0
# Photo jZt6ja5IWKhBFJPdrUqA updated: book count = 0
# Photo jiXh6VZAkwxHWA9kheTZ updated: book count = 0
# Photo juyXL1cOwPts0V9Qua0k updated: book count = 1
# Photo jwq3vUT1pcbUrvLQFFZD updated: book count = 15
# Photo jy96R0444j909PWvqWz8 updated: book count = 5
# Photo jzjFFLuXKEVlPJvitqRe updated: book count = 0
# Photo k0kOHrpqfRugglMgQPyZ updated: book count = 0
# Photo k3oE1FahMwJrv1fX2zm3 updated: book count = 4
# Photo kDnCKQb9ZfyIpOF7svjj updated: book count = 6
# Photo kFzkUX72NNSlUnc6ERKb updated: book count = 13
# Photo kS47xIgNbZIFjkXlkuN9 updated: book count = 0
# Photo kcr0KmIPxg4g6MosRlCS updated: book count = 21
# Photo kevHFMxapkyPsZnqa0Qd updated: book count = 3
# Photo kfIZLVBztM8CcwGlc4Qw updated: book count = 3
# Photo ksUNTJ6h4f1a9BgdaEI9 updated: book count = 0
# Photo lGjERs2etbz5jJOQ0qt6 updated: book count = 0
# Photo lUJMSxoFtjzqHE9gLd7d updated: book count = 13
# Photo lbzutcMD8GhSiZJUM6Gg updated: book count = 0
# Photo lf6UBdjdyvsa61YueKZ0 updated: book count = 8
# Photo lfDkU66RwecNnzNcmwwi updated: book count = 9
# Photo lfE1OdbjozAaRyf4zP78 updated: book count = 2
# Photo llWniw1IDKG6BXOQK6Iu updated: book count = 1
# Photo ludpMfgzfISGhq62vn7h updated: book count = 13
# Photo lw7bBY2Yc9pol0UWPhEM updated: book count = 3
# Photo m0DQSP35CNto3wQPxI6M updated: book count = 0
# Photo m0Wou9un8nWzUujhu4IJ updated: book count = 6
# Photo m254awGabJntKgKAtKCa updated: book count = 0
# Photo m2797VgSvGH93GwS4GY3 updated: book count = 6
# Photo m4ftiHETD9mZeNQxfq58 updated: book count = 9
# Photo m8WzALslkDuriCWgztYf updated: book count = 17
# Photo mAZYOtp7YJJASK5zMDgK updated: book count = 0
# Photo mJ8L7FlyrtFbLcgtaAb7 updated: book count = 0
# Photo mQYfPurz4YjTvRxuy06h updated: book count = 0
# Photo mWF1vFTWHwtNeLryc2A3 updated: book count = 0
# Photo mj6Fl87va6OihbPBz4P1 updated: book count = 1
# Photo mn3MNnnqLlaNI6Ks5Q33 updated: book count = 4
# Photo moBs9bHquMj0PQImSxKJ updated: book count = 5
# Photo mpFMTlkkdLZiGbEH8mOJ updated: book count = 10
# Photo mpqMqct26sZ2ZBx3G7Jy updated: book count = 0
# Photo msrWZzjRZWIPJ33X5UEd updated: book count = 0
# Photo muPhHgSpIoB7LgfLEFh6 updated: book count = 9
# Photo mv6UjjviE6Q921uV1i8K updated: book count = 5
# Photo nAqjzl1dGRyjABrgO5ay updated: book count = 14
# Photo nHaHXr5wAPCIu9qblAn2 updated: book count = 0
# Photo nIZ4fVF7LEnzLLMDSGDR updated: book count = 0
# Photo nJuOptTWTJ1HUG1ToPdB updated: book count = 6
# Photo nKguw9e8bknuN8QIG3Th updated: book count = 0
# Photo nNk3ZTgmmMhRKRweco49 updated: book count = 1
# Photo nOHINGOrMNuPkT0b8E4N updated: book count = 0
# Photo nRRr6uhvq2zAtnGOkbq3 updated: book count = 0
# Photo nTpRXABWHntlXdB26gBR updated: book count = 2
# Photo nUmslDFKfqvAIuFFPwqe updated: book count = 10
# Photo nWBLmkGoiWxZ7pmP9o5r updated: book count = 11
# Photo nZXZPj1ACQwsbUee4fht updated: book count = 2
# Photo naimwy07dliuXSOSsJSe updated: book count = 9
# Photo nb2YmhI43vaDGa2tPhBq updated: book count = 0
# Photo nfDOzLQq43Z4hEAeVMQH updated: book count = 0
# Photo nh39QyGNsQMXjp0nuf2c updated: book count = 1
# Photo nmsSS6fXxygMk2kKimRj updated: book count = 0
# Photo nqqEX6Yu3liUxlZiZe0q updated: book count = 0
# Photo o3b9Z0Z9IreN3AsELhgF updated: book count = 0
# Photo o5XYxvqxTq7QKbxvMXE1 updated: book count = 0
# Photo o7zdKGv7tQ3IU2Cge1ea updated: book count = 4
# Photo oAe9hbKqiDx3o8WZP5ot updated: book count = 0
# Photo oEuDoK2DQxmG4nirMLBw updated: book count = 0
# Photo oLjJwcUhS95OZkXWZKIm updated: book count = 0
# Photo oN0bDYaCAyq10FTvmKDM updated: book count = 0
# Photo oaIOYIz8aKmWH0Z4NoVw updated: book count = 0
# Photo obn6Z6HpVynRhN369RXV updated: book count = 17
# Photo ogVeMEzJvHC76WVDv2BP updated: book count = 6
# Photo ojpWg6EIDflMaJfgwcMp updated: book count = 0
# Photo omRVOBDleEgoIXQi16f4 updated: book count = 0
# Photo onmISvuXUSE8D8HGFdUh updated: book count = 3
# Photo p0mu5NHxaz5FW895pZlQ updated: book count = 0
# Photo p2vVziTxBDxsGtb7rdAv updated: book count = 7
# Photo p5kbXmTbekPZ37Jif8FB updated: book count = 0
# Photo pDntabI61kZjZTj3JAB7 updated: book count = 0
# Photo pHi17S33WnGzWrf7fzFJ updated: book count = 13
# Photo pMKHWs84uZS7gne9gbQu updated: book count = 0
# Photo pOWAwx9JRPya6iG8qrgF updated: book count = 1
# Photo pRDcosO8TDuQLP6oalIK updated: book count = 0
# Photo pWeubDg6vDO5l84Iz91O updated: book count = 1
# Photo pYTmpPbWjyVuNTlc72MO updated: book count = 0
# Photo pZB6kVsy4yqiXHoUZylb updated: book count = 0
# Photo peVHyMQLQzZkkiNzx1q6 updated: book count = 0
# Photo pjXYw3sknwjXrQyicRRl updated: book count = 0
# Photo pjrLYXXZYoz4KIWpAQN4 updated: book count = 2
# Photo pkXSZnbxKGiOVVsRooOW updated: book count = 2
# Photo psb0MeEB2ENjlfZhjBUt updated: book count = 4
# Photo pvY1DhYZXOO8wBRLWEyL updated: book count = 12
# Photo pzaMrO03EF7l0F6z7J60 updated: book count = 1
# Photo q1L4PV1oUSRjeuZw9kNR updated: book count = 0
# Photo q6eao3xT8lKlrYTmQGvv updated: book count = 1
# Photo qKR4KWGwdsbwEOw6WvVo updated: book count = 8
# Photo qL94JZW5ae02l976igtY updated: book count = 8
# Photo qaZU2SUeESSAVC64Qksu updated: book count = 7
# Photo qb5A5s5U7pRX5XOEsK83 updated: book count = 1
# Photo qe0W0j2WwpfPiKIdVj3M updated: book count = 3
# Photo qgXvwODtNDL0XWsp9O2V updated: book count = 0
# Photo qhHrewHs1wk6c9vaqUHV updated: book count = 0
# Photo qkkeCYdJXMfbuIKtuqYL updated: book count = 4
# Photo qvCT6r8HKles7JiY9Yim updated: book count = 4
# Photo qxmfLgEnoXMyg6j85zVF updated: book count = 0
# Photo qzgzYl9wehZng3GUJqTH updated: book count = 0
# Photo r62bVKiPCebit66zkpD8 updated: book count = 1
# Photo r6hEJNFWpXACeND3WZwY updated: book count = 0
# Photo rBmM6k1dpRfDRxkJoI49 updated: book count = 0
# Photo rKIyTImKNHRYCjGUcwJY updated: book count = 10
# Photo rTFAJ3fHoQ3abkC92NLf updated: book count = 0
# Photo rVELklv0gSanscWHMNyv updated: book count = 1
# Photo riU2BgmkLSTc8bpgyXLh updated: book count = 1
# Photo rk6mKAKWyrdmYG9WtFrZ updated: book count = 0
# Photo rlOdlh6Kh5L17FyYNtDb updated: book count = 6
# Photo roO7OzOhXmUUGepvajks updated: book count = 0
# Photo rsrNEvH94c8XvhDp9XBn updated: book count = 5
# Photo rus2GlSqKMFg8NNaX8Dd updated: book count = 0
# Photo sCKIvvFUvbq37aHaomMX updated: book count = 0
# Photo sGWrMgPVQ4EvqfJlf8jq updated: book count = 0
# Photo sT60NRG3VchPSuDGIqlT updated: book count = 0
# Photo sXYvxPbjgpXmmQeIquhD updated: book count = 0
# Photo sbzzBsdZPyWPDm78g7tq updated: book count = 11
# Photo sedczGVZKvRKIyTzYwGs updated: book count = 1
# Photo sgahVJbFJ35GCfkaTDtP updated: book count = 0
# Photo sjk9bVNHRYiG3OqnriIu updated: book count = 0
# Photo sncQRryxFWNaj5e322ZC updated: book count = 3
# Photo sqHpsfKC98A8IdVu5Sue updated: book count = 1
# Photo sromElXTwf0OjreHkf2Q updated: book count = 9
# Photo sucgei5EE6g2tfNUZFVz updated: book count = 5
# Photo svOwZQBBg2dO4E3Flfhb updated: book count = 0
# Photo svUD1KDxemG1wFNHyaiM updated: book count = 0
# Photo t50vinUXlKXjfQaEQzUw updated: book count = 0
# Photo tCLmZJJQTkF3jWBq9O6E updated: book count = 2
# Photo tDbVYGzZZJfHBtX0YXES updated: book count = 0
# Photo tDcqbE6J1yFeN2Zdz5CT updated: book count = 1
# Photo tLb44BHoGPObouHq1itf updated: book count = 1
# Photo tNXy8XGTGeFbRlyCV6US updated: book count = 3
# Photo tRLxsbrMfZ8wB86DvXID updated: book count = 9
# Photo tVhyaD58sySEaqbsQFw5 updated: book count = 4
# Photo tXHOKJ5GfSnj7nN5JkFo updated: book count = 0
# Photo tXs0DGpttGb3bylkD4Wg updated: book count = 3
# Photo tZPPc7fLecLaSVhASHSh updated: book count = 4
# Photo taoKjBnJKNxJGMhNHf9I updated: book count = 8
# Photo tdwjvZc4tgffETeM6pNK updated: book count = 0
# Photo tnNjofDDKsxQZKKNzFoR updated: book count = 4
# Photo tqPJHfsFyfq3Xnl4IRAA updated: book count = 2
# Photo twvqk5UOnqI3Y4LNXvfc updated: book count = 3
# Photo tzIJ4yS7Ur84XVs2dG6N updated: book count = 1
# Photo uGeaFv66sjbbxFYadQps updated: book count = 0
# Photo uMv3TyuXczDpqyDSeDjv updated: book count = 2
# Photo uQjXHsAhtJaH8t5d0doF updated: book count = 9
# Photo uYU43Z6mpCFi0JxQ6sqg updated: book count = 0
# Photo ubP95HX8OhstiOttkfrE updated: book count = 0
# Photo udUo0olneXUv4b9INl8M updated: book count = 1
# Photo umI7d2rHbnhbDM4z7DKB updated: book count = 0
# Photo urA56b7ZtOy2cotj9jjd updated: book count = 5
# Photo ut4tZdsypP2VJRUflccj updated: book count = 2
# Photo vD4bhG02D5MWnAmIpZlH updated: book count = 0
# Photo vEI1aWWsQSHUfpQZrlHy updated: book count = 1
# Photo vFOlEN6P9g7FrZP4D9JH updated: book count = 0
# Photo vX3VmMAPU8qWItriMtOd updated: book count = 0
# Photo vYZmUpwZOfcbHDbFTuhe updated: book count = 3
# Photo vYoUox9BdhFcdJiiFYB5 updated: book count = 0
# Photo vam3p5XQY9rMtNLyohcs updated: book count = 0
# Photo vdVqAol9vC5eJUtfncya updated: book count = 0
# Photo vgAAh6eVW8Qmc5PRt6K4 updated: book count = 0
# Photo vgGrjjinaW2Q56x5wBuS updated: book count = 2
# Photo vgR7ZP97J0wz6fPWcsMJ updated: book count = 9
# Photo viYAfiLRmpNKAHOJOMQL updated: book count = 2
# Photo vicMq2qBIIdabceBLh07 updated: book count = 7
# Photo vpM5qJbKUAhvkr1w6gRb updated: book count = 17
# Photo vq8veEbS9AW7ql13c3Vj updated: book count = 0
# Photo vsnjdvwm9q56Iye0HERv updated: book count = 4
# Photo vwaFKszti3oxlFXYJpau updated: book count = 4
# Photo vxWtD2NtmzvXAyszF2Q7 updated: book count = 14
# Photo w07Bfzqg38Z4nlRVRLMu updated: book count = 9
# Photo wKlB2hA0lWcwstttuoyD updated: book count = 0
# Photo wLtUo6LTE2fK3QYO8YYw updated: book count = 0
# Photo wLzU4ZbS9cURyN4Rt6s1 updated: book count = 0
# Photo wSOaifTc15d5xM6fsxnC updated: book count = 0
# Photo wYCO0top09yRE4IRwyTR updated: book count = 7
# Photo wcVNAmlklenkjL3I5vX9 updated: book count = 0
# Photo wet781F5zHETlkmGSXpz updated: book count = 5
# Photo wffS8iSqhfOc31BNI1Rr updated: book count = 4
# Photo wms8r1hKhNJzLx1Plqaf updated: book count = 0
# Photo wo2NP0KVfNwwxqwyAsKU updated: book count = 11
# Photo wrLlATxzyLNqf2aRdsPL updated: book count = 5
# Photo wsxu8QqiN3KSXhOjwlBN updated: book count = 9
# Photo xEc7BfiBdnRuhqouboLn updated: book count = 3
# Photo xJq0R1U8J0pEsicfrfSn updated: book count = 1
# Photo xYVf9JCAzHgZO4W8ru8L updated: book count = 6
# Photo xg6wW7z0t0EIGdhx3zxm updated: book count = 4
# Photo xkdjZPHT8RgVUvxjES2p updated: book count = 3
# Photo xnNXRN8sOi9z0UrXY6yS updated: book count = 6
# Photo xqRvOoLph7JXj4Yhtelo updated: book count = 0
# Photo xzb5ejlbRzYwHvLdsGwo updated: book count = 0
# Photo y1N3H7RVW6hclGuLWbTG updated: book count = 14
# Photo y1nyu9nzOXciFogKZLQo updated: book count = 0
# Photo y4MRu4ezr3CLsl5cXjfN updated: book count = 0
# Photo yF0HH55JFGZAXcSJRE6g updated: book count = 0
# Photo yLJCpCz9yrcTzB2hrjx3 updated: book count = 4
# Photo yMbn1fCdq75aQgFB0FxG updated: book count = 0
# Photo yVItikskvSAdza6Dr0m6 updated: book count = 0
# Photo yWKbJGXkXbQ6WGinA7bN updated: book count = 8
# Photo yY0TKCPS84Gqcnt9hSDB updated: book count = 8
# Photo yZLim0RuVq9ULtuKHrGd updated: book count = 4
# Photo ya0jRimqU2LSUFY93dsl updated: book count = 1
# Photo yhO2obJioizGJinDK16r updated: book count = 0
# Photo ylg0ylWIPZFDM61PpojE updated: book count = 3
# Photo yp38sOBHTTuSnwjijcP2 updated: book count = 14
# Photo yt5dZjSaeKJIjmWlECUT updated: book count = 0
# Photo yuVZJL0FSdYRFPwD7Lih updated: book count = 0
# Photo zAA431cMptoZhCAQz0sS updated: book count = 3
# Photo zB7BQJBa7n63tJHxzIZK updated: book count = 5
# Photo zDLVnggsE2xYy8BZXPfO updated: book count = 0
# Photo zEs3IzkL3JDnAvqnDHqU updated: book count = 5
# Photo zJ7fUVKk09hcyT9bX5hV updated: book count = 0
# Photo zLsGzpSMOq9tOtrLSeUB updated: book count = 0
# Photo zMXWwN9NLPfXELxMKBiy updated: book count = 0
# Photo zNlEiTh4Lv8IipyRHouI updated: book count = 4
# Photo zQFpnPFRFU8sQibebpXQ updated: book count = 0
# Photo zWGG2kgwO6lzyCjBJf5A updated: book count = 0
# Photo zWb3FsD48ucJjFQRzAGV updated: book count = 3
# Photo zWrVjcKYBSMwf9RhpwBP updated: book count = 0
# Photo zXQQeAVX61eaAQm02R6i updated: book count = 2
# Photo zXuIiUglZJLczlPIk0C7 updated: book count = 0
# Photo zcn83PJEFx4CMbTxIuhk updated: book count = 0
# Photo zi9jEkEbH2lK2YC47ZSN updated: book count = 5
# Photo zn2FsOCjQa1u4K2Bm1ZM updated: book count = 5
# Photo zzWgQROlE6HHLznORDJO updated: book count = 1
# Photo zzXJzBxTqngG7iB4PCxz updated: book count = 6

# %%
# Admin script to build book clusters
# There are 4 levels of clusters:
# - At geo-hash length 7 (150 m)
# - At geo-hash length 5 (5 km)
# - At geo-hash length 3 (150 km)
# - At geo-hash length 2 (1200 km)

# DROP 'clusters' BEFORE RERUN!!!

# Function to update clusters on all 4 levels
def updateGeoHash(geohash, geopoint, count):

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:7])
    db.collection('clusters').document(geohash[:7]).set({'id': geohash[:7],  
                                                         'level': 7,
                                                         'hash5': geohash[:5],
                                                         'hash6': geohash[:6],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:5])
    db.collection('clusters').document(geohash[:5]).set({'id': geohash[:5],  
                                                         'level': 5,
                                                         'hash3': geohash[:3],
                                                         'hash4': geohash[:4],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:3])
    db.collection('clusters').document(geohash[:3]).set({'id': geohash[:3],  
                                                         'level': 3,
                                                         'hash2': geohash[:2],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)

    lat, lon, _, _ = geohash2.decode_exactly(geohash[:2])
    db.collection('clusters').document(geohash[:2]).set({'id': geohash[:2],  
                                                         'level': 2,
                                                         'hash1': geohash[:1],
                                                         'location': firestore.GeoPoint(lat, lon), 
                                                         'count': Increment(count)}, merge=True)
    return


db = firestore.client()

#places = db.collection('bookplaces').limit(30).stream()
places = db.collection('bookplaces').stream()
places = [p for p in places]

count = 0
for p in places:
    # Calculate number of books for each bookplace
    books = db.collection('books').where('bookplace', '==', p.id).stream()
    books = [b for b in books]
    
    db.collection('bookplaces').document(p.id).update({'count': len(books), 'id': p.id})
    print('Bookplace %s updated: book count = %d' % (p.id, len(books)))

    # Update clusters for each bookplace
    place = p.to_dict()
    if 'location' not in place:
        print('************** ERROR: place %s does not have location' % p.id)
    else:
        updateGeoHash(place['location']['geohash'], place['location']['geopoint'], len(books))

# %%
# Script to assign language to the books

def has_cyrillic(text):
    return bool(re.search('[а-яА-Я]', text))

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

for b in books:
    data = b.to_dict()
    if has_cyrillic(data['title']):
        language = 'RUS'
    else:
        language = 'ENG'
 
    db.collection('books').document(b.id).update({'language': language})

# %%
# Script to add shelf image URL

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

for b in books:
    data = b.to_dict()

    # Skip if book does not have photo or already converted
    if 'photo' not in data or data['photo'].startswith('https'):
        continue
     
    # Get URL for cloud storage path
    blob = bucket.blob(data['photo'])
    blob.make_public()
    
    # TODO: Get outline from json file

    # Store URL in firestore
    db.collection('books').document(b.id).update({'photo': blob.public_url})

# %%
# Script to add thumbnail image URL to PHOTOS

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#photos = db.collection('photos').limit(3).stream()
photos = db.collection('photos').stream()
photos = [p for p in photos]

for p in photos:
    data = p.to_dict()

    # Skip if book does not have photo or already converted
    if 'photo' not in data or not data['photo'].startswith('images/'):
        print('Missing or wrong photo:', p.id, data)
        continue

        
    # Get URL for cloud storage path
    blob = bucket.blob('thumbnails' + data['photo'][6:])
    blob.make_public()
    
    # TODO: Get outline from json file

    # Store URL in firestore
    db.collection('photos').document(p.id).update({'thumbnail': blob.public_url})

# %%
# Script to add place_name based on bookplace id

db = firestore.client()

#books = db.collection('books').limit(10).stream()
books = db.collection('books').stream()
books = [b for b in books]

for b in books:
    data = b.to_dict()

    # Skip if book does not have photo or already converted
    if 'bookplace' not in data:
        continue
     
    # Get URL for cloud storage path
    place_id = data['bookplace']

    place = db.collection('bookplaces').document(place_id).get()
    place_data = place.to_dict()
    
    if 'name' in place_data and len(place_data['name']) > 0:
        # Store URL in firestore
        db.collection('books').document(b.id).update({'place_name': place_data['name']})

# %%
# Script to add book outline coordinates

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#photos = db.collection('photos').limit(1).stream()
photos = db.collection('photos').stream()
photos = [p for p in photos]

for p in photos:
    data = p.to_dict()

    # Read JSON with recognition detailes
    json_file = data['photo'][:-3] + 'json'
    print('JSON file: ', json_file)
    
    blob = bucket.blob(json_file)
    
    if not blob.exists():
        print('BLOB does not exist', json_file)
        continue
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)
    
    recognized_blocks = results['recognized']
    #unrecognized_blocks = stored_results['unrecognized']

    for b in recognized_blocks:
        # Set the Firestore bookrecord
        #print('Book:', b.book.isbn, b.outline)

        # Find each book by ISBN and photo id
        docs = db.collection('books').where('photo_id', '==', p.id).where('isbn', '==', b.book.isbn).stream()
        docs = [d for d in docs]

        if len(docs) == 0:
            print('Book not found for %s, photo id %s, title %s' % (b.book.isbn, p.id, b.book.title))
        
        if len(docs) > 1:
            print('More than 1 book found for %s and photo id %s' % (b.book.isbn, p.id))

        # Update book with coordinates
        outline = [{'x': v[0], 'y': v[1]} for v in b.outline]
    
        for doc in docs:
            db.collection('books').document(doc.id).update({'outline': outline})

# %%
# Procedure to calculate best place for book cover image within the shelf photo

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Aspect ration of book cover (Width / Height)
ratio = 2.0 / 3.0 

def imread_blob(blob):
    img = cv2.imdecode(np.asarray(bytearray(blob.download_as_string()), dtype=np.uint8), cv2.IMREAD_COLOR)
    return img

# Function to fit biggest rectangle with given aspect ratio
def fit(ratio, contour):
    
    # TODO: Make it working for triangles and polygons
    # For each point of the contour draw two diagonals of the potential rectangle
    # Discard diagnals which are outside the angle of enclosing sides
    # Find intersection of diagonal with the rest of the sides
    # Calculate complimentary diagonal and check if corners are inside the photo
    # Choose biggest candidate, if several are biggest join them together
    
    width, height = abs(contour[2,0] - contour[0,0]), abs(contour[2,1] - contour[0,1])
    
    return min(width, height * ratio)


# Function to determine the biggest free part outside of book image
def cover(width, height, contour):
    min_x, max_x = min(contour[:, 0]), max(contour[:, 0])
    min_y, max_y = min(contour[:, 1]), max(contour[:, 1])
    
    if min_x > width - max_x:
        candidate1 = np.array([[0, 0], [0, height], [min_x, height], [min_x, 0]])
    else:
        candidate1 = np.array([[max_x, 0], [max_x, height], [width, height], [width, 0]])

    if min_y > height - max_y:
        candidate2 = np.array([[0, 0], [0, min_y], [width, min_y], [width, 0]])
    else: 
        candidate2 = np.array([[0, max_y], [0, height], [width, height], [width, max_y]])

    if fit(ratio, candidate1) > fit(ratio, candidate2):
        cover = candidate1
    else: 
        cover = candidate2
        
    return cover

# Function to return book spine rectangle
def spine(contour):
    spine = cv2.minAreaRect(contour)
    return np.int0(cv2.boxPoints(spine))

db = firestore.client()
bucket = storage.bucket('biblosphere-210106.appspot.com')

#photos = db.collection('photos').limit(5).stream()
photos = db.collection('photos').stream()
photos = [p for p in photos]

for p in photos:
    data = p.to_dict()

    # Read JSON with recognition detailes
    json_file = data['photo'][:-3] + 'json'
    print('JSON file: ', json_file)
    
    blob = bucket.blob(json_file)
    
    if not blob.exists():
        print('BLOB does not exist', json_file)
        continue
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)
    
    recognized_blocks = results['recognized']
    #unrecognized_blocks = stored_results['unrecognized']
    
    uri = results['uri']

    image_blob = bucket.blob(uri)
    img = imread_blob(image_blob)

    height, width = img.shape[0:2]
    
    results = json.loads(blob.download_as_string(), cls=JsonDecoder)

    for b in recognized_blocks:
        # Update book with coordinates
        outline = np.array(b.outline)
        
        place_for_cover = cover(width, height, outline)
        spine = bookspine(outline)

        #print('Cover:', place_for_cover)
        #print('Bookspine:', spine)
        #cv2.drawContours(img, np.array([outline]), 0, (0, 0, 255), 15)
        #cv2.drawContours(img, np.array([place_for_cover]), 0, (0, 255, 0), 15)
        #cv2.drawContours(img, np.array([spine]), 0, (255, 0, 0), 15)
        #plt.imshow(img)

        # Find each book by ISBN and photo id
        docs = db.collection('books').where('photo_id', '==', p.id).where('isbn', '==', b.book.isbn).stream()
        docs = [d for d in docs]

        if len(docs) == 0:
            print('Book not found for %s, photo id %s, title %s' % (b.book.isbn, p.id, b.book.title))
        
        if len(docs) > 1:
            print('More than 1 book found for %s and photo id %s' % (b.book.isbn, p.id))

        # Update book with coordinates
        spine = [{'x': v[0], 'y': v[1]} for v in spine.tolist()]
        place_for_cover = [{'x': v[0], 'y': v[1]} for v in place_for_cover.tolist()]
            
        #print('Cover:', place_for_cover)
        #print('Bookspine:', spine)

        for doc in docs:
            db.collection('books').document(doc.id).update({'spine': spine, 'place_for_cover': place_for_cover, 'photo_height': height, 'photo_width': width})

# %%
# Script to fill contacts for the books

db = firestore.client()

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

places = {}

for b in books:
    data = b.to_dict()

    if 'owner_id' not in data:
        print('Owner Id missing for', b.id);
        continue;

    # Skip processed ones
    if 'place_contact' in data:
        continue;

    # Print names and emails of the users
    owner = auth.get_user(data['owner_id'])
    if owner is not None and owner.email is not None and '@' in owner.email:
        db.collection('books').document(b.id).update({'place_contact': owner.email})
        
        if 'bookplace' in data:
            places[data['bookplace']] = owner.email
        else:
            print('Bookplace id missing for', b.id);
            
    else:
        print('Email is missing or invalid for', b.id);
        
#for place in places:
#    db.collection('bookplaces').document(place).update({'contact': places[place]})
# Out:
# Owner Id missing for 9785000835869
# Owner Id missing for 9785170846214
# Owner Id missing for 9785179826040
# Email is missing or invalid for Fcujp6ekrSOGclLAgMt1
# Email is missing or invalid for H8xxvVoaQXlBFaqhSOI4
# Email is missing or invalid for IUzztrnZJBa8d4b7WMVR
# Email is missing or invalid for MuaqFNbpSCFnUfkTtg60
# Email is missing or invalid for S6zxyXU93KiOgiIeVpBd
# Email is missing or invalid for TP6VQoxIr6QLYy8xKPXt
# Email is missing or invalid for Y3tSjAzDqOWdrHBwMJGO
# Email is missing or invalid for bYuI1bAgL23kKkwn5OZm
# Email is missing or invalid for dbxxcSu78D6HqDmCe6ML
# Email is missing or invalid for gpQjGKtLpPVGkBPfXUyF
# Email is missing or invalid for piLpaaSIHp3nlSFKnBAZ
# Email is missing or invalid for rNyej5VIIKglTXeByKLz

# %%
# Script to generate links for each book

db = firestore.client()

#books = db.collection('books').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

places = {}

for b in books:
    data = b.to_dict()

{
  "dynamicLinkInfo": {
    "domainUriPrefix": string,
    "link": string,
    "androidInfo": {
      "androidPackageName": string,
      "androidFallbackLink": string,
      "androidMinPackageVersionCode": string
    },
    "iosInfo": {
      "iosBundleId": string,
      "iosFallbackLink": string,
      "iosCustomScheme": string,
      "iosIpadFallbackLink": string,
      "iosIpadBundleId": string,
      "iosAppStoreId": string
    },
    "navigationInfo": {
      "enableForcedRedirect": boolean,
    },
    "analyticsInfo": {
      "googlePlayAnalytics": {
        "utmSource": string,
        "utmMedium": string,
        "utmCampaign": string,
        "utmTerm": string,
        "utmContent": string,
        "gclid": string
      },
      "itunesConnectAnalytics": {
        "at": string,
        "ct": string,
        "mt": string,
        "pt": string
      }
    },
    "socialMetaTagInfo": {
      "socialTitle": string,
      "socialDescription": string,
      "socialImageLink": string
    }
  },
  "suffix": {
    "option": "SHORT" or "UNGUESSABLE"
  }
}

# %%
# Script to find multiple ISBNs
import collections 

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('books').stream()
books = [b.to_dict()['isbn'] for b in books]

# using collections.Counter() 
# Identical Strings Grouping 
counters = collections.Counter(books)

res = [[i, j] for i, j in counters.items() if j > 1]
res = sorted(res, key=lambda i: -i[1])

print(res)

# %%
# Script to debug image recognition    

#token = cmdline("gcloud auth application-default print-access-token")
#token = cmdline("gcloud auth print-identity-token")
#token = token.decode("utf-8").rstrip()
#headers = {"Authorization": "Bearer %s" % token}

#books = search('9785990174764')
#books = search('денис старк')
#print(books)
#recognize_image('0000000000000000000000000000', '0000000000034.jpg', '0000000000000000000000000000:0000000000034', firestore.GeoPoint(90.0, 135.0))

db = firestore.client()

db.collection('bookplaces').document('0000000000000000000000000000').set({
    'id': '0000000000000000000000000000',
    'name': 'Denis Stark', 
    'mobile': '+50663042667',
})

ref = db.collection('photos').document()
ref.set({
    'id': ref.id,
    'photo': 'images/0000000000000000000000000000/0000000000034.jpg', 
    'reporter': '0000000000000000000000000000',
    'bookplace': '0000000000000000000000000000',
    'location': {
                 'geopoint': firestore.GeoPoint(90.0, 135.0),
                 'geohash': geohash2.encode(90.0, 135.0)[:9],
                },
    'url': 'https://storage.cloud.google.com/biblosphere-210106.appspot.com/images/0000000000000000000000000000/0000000000034.jpg'
})

print('Photo created:', ref.id)
# Out:
# Photo created: m8WzALslkDuriCWgztYf

# %%
# Script to re-create photo records for manual recognition
import collections 

ids = ['3l62P2NKmgJXANzmV6As', 'Bo3gXefCAuZKcjIkzFMZ', 'I2hrsNVME2NGVYLzFmJh', 'Tnzk2AktwNWTI40034dV', 'cVIBOTbvANVhp1cD2MBY', 'nmsSS6fXxygMk2kKimRj', 'nqqEX6Yu3liUxlZiZe0q', 'qgXvwODtNDL0XWsp9O2V', 'uGeaFv66sjbbxFYadQps']

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
photos = db.collection('photos').where('reporter', '==', 'QJzc7XcmelSpr1aWrHLw0SnW27h2').stream()
old_ids = [p.id for p in photos]
for id in old_ids:
    if id not in ids:
        db.collection('photos').document(id).delete()

new_ids = []
for id in ids:
    photo = db.collection('photos').document(id).get()
    data = photo.to_dict()
    #print(data)
    ref = db.collection('photos').document()
    data['id'] = ref.id
    ref.set(data)
    new_ids.append(ref.id)
    
print(new_ids)
# Out:
# ['YOEkSeQ0l7kkoI8xmr0h', 'AP5Sf86B9J9fPHcULDw7', 'f06rhAyupwwzWuMkbKHW', 'cPE9v8h03wcn2UHA6Hti', '7kOsf04nUCAcXxUT4nol', 'wffS8iSqhfOc31BNI1Rr', 'XTlw12RJ9kFkhKqxUMcW', '1Nkiz3YNQyGVvdHolf6x', 'IkBL2sHl5mjMb3JLOxJB']

# %%
db = firestore.client()

books = db.collection('books').where('bookplace', '==', '0000000000000000000000000000').stream()
books = [b.id for b in books]

print(len(books), 'books found to delete')
for b in books:    
    db.collection('books').document(b).delete()
# Out:
# 20 books found to delete

# %%
db = firestore.client()

place = db.collection('bookplaces').document('UoHvjtrwwKGWNfQOFeN7zM3YaTfV2:d1ey7yj').get()

print(place)
print(place.to_dict())
# Out:
# <google.cloud.firestore_v1.document.DocumentSnapshot object at 0x0000021D279ED340>
# {'languages': None, 'location': {'geohash': 'd1ey7yj1ug6x', 'geopoint': <google.cloud.firestore_v1._helpers.GeoPoint object at 0x0000021D279ED3A0>}, 'privacy': 'all', 'name': 'Denis Stark', 'users': None, 'contact': None, 'type': 'contact', 'emails': [None], 'phones': ['+50663042667'], 'count': None, 'genres': None, 'placeId': None}

# %%
#['9785222234976', 21], ['9785699031023', 9], ['9789874024770', 8], ['9785990174764', 5], ['9781949763287', 5], ['9785733103037', 5], ['9785171012359', 4], ['9785040940455', 4], ['9780439358071', 4], ['9785170828432', 4], ['9785446520596', 4], ['9780062120991', 4], ['9785170848614', 4], ['9785906504500', 3], ['9785811422111', 3], ['9785699827954', 3], ['9785906686626', 3], ['9785906686572', 3], ['9785399000084', 3], ['9785041050146', 3], ['9780007107001', 3], ['9785519505017', 3], ['9785446104703', 3], ['9780312019273', 3], ['9785906601230', 3], ['9785080060472', 3], ['9785041045340', 3], ['9786176791041', 3], ['9785222206874', 3], ['9780545010221', 3], ['9785904584696', 3], ['9780312195007', 3], ['9785389141681', 3], ['9785389098947', 3], ['548400194305210', 3]

import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]='Biblosphere-7fea7c2aa326.json'
#from google.oauth2 import service_account
#credentials = service_account.Credentials.from_service_account_file('biblosphere-firebase-adminsdk.json')
                                                                        
creds, project = google.auth.default(scopes = 'https://www.googleapis.com/auth/cloud-platform')

#creds = credentials.Certificate("biblosphere-firebase-adminsdk.json")

# creds.valid is False, and creds.token is None
# Need to refresh credentials to populate those

auth_req = google.auth.transport.requests.Request()
creds.refresh(auth_req)

#print(creds.token)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\stark\appdata\local\programs\python\python38\lib\site-packages\google\oauth2\_client.py in jwt_grant(request, token_uri, assertion)
#     155     try:
# --> 156         access_token = response_data["access_token"]
#     157     except KeyError as caught_exc:
#
# KeyError: 'access_token'
#
# The above exception was the direct cause of the following exception:
#
# RefreshError                              Traceback (most recent call last)
# <ipython-input-17-ec4813fef2a3> in <module>
#      14
#      15 auth_req = google.auth.transport.requests.Request()
# ---> 16 creds.refresh(auth_req)
#      17
#      18 #print(creds.token)
#
# c:\users\stark\appdata\local\programs\python\python38\lib\site-packages\google\oauth2\service_account.py in refresh(self, request)
#     359     def refresh(self, request):
#     360         assertion = self._make_authorization_grant_assertion()
# --> 361         access_token, expiry, _ = _client.jwt_grant(request, self._token_uri, assertion)
#     362         self.token = access_token
#     363         self.expiry = expiry
#
# c:\users\stark\appdata\local\programs\python\python38\lib\site-packages\google\oauth2\_client.py in jwt_grant(request, token_uri, assertion)
#     157     except KeyError as caught_exc:
#     158         new_exc = exceptions.RefreshError("No access token in response.", response_data)
# --> 159         six.raise_from(new_exc, caught_exc)
#     160
#     161     expiry = _parse_expiry(response_data)
#
# c:\users\stark\appdata\local\programs\python\python38\lib\site-packages\six.py in raise_from(value, from_value)
#
# RefreshError: ('No access token in response.', {'id_token': 'eyJhbGciOiJSUzI1NiIsImtpZCI6ImUxOTdiZjJlODdiZDE5MDU1NzVmOWI2ZTVlYjQyNmVkYTVkNTc0ZTMiLCJ0eXAiOiJKV1QifQ.....X6TDFtOX-_Q8LWMp9C10APoaIHyF8elQ6XsSPEWvOYYsAsPYJ3EUwtiglvm8TiNVvLyV3725rly6OdXl0bXgLYPq-uejOS1EvHBo5F5ofuML2Q2Edd5mvR500Zunmk6HDaqRj1tdQtLmXVUEmcsI4i0D4itA1xMZqCQ8oLCZMB499EVV9dcIWlyZPb6T_Q8o4iF3uqu47lw2Fw23FdIJsBpXK3TagYgfuZbgKLgYT9nUm9B-CAF_PO8gCZgrvRo7QP1raP691vpbXTww0ED60lMROOKRxymeS0o9h6IQJAw2zl_fIvb-qLsdbr4BL3O8PrpWqsk-MgSEfRINPHH0Kg'})

# %%
# Script to count recognized books for a period

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('shelves').where('id', '>=', '1593006003543').stream()

count = 0
for i, b in enumerate(books):
    data = b.to_dict()
    if data['recognized'] is not None and data['recognized'] > 0:
        print('Recognized %d %s' % (data['recognized'], data['image']))
        count += data['recognized'] 

print('TOTAL RECOGNIZED:', count)

# %%
emails = ['webdoedie@gmail.com',
'camilleguzman.10880@gmail.com',
'angiewelch.88990@gmail.com',
'samueldixon.34540@gmail.com',
'skaplichniy@gmail.com',
'sof5859@yandex.ru',
'gingeralina@mail.ru',
'kanhai.kcc@gmail.com',
'anbarbery@gmail.com',
'mchusick@gmail.com',
'thomashibbard89@gmail.com',
'kolbasa12393@mail.ru',
'bdinh14@gmail.com',
'ashima.odsharma@gmail.com',
'mart.a.o.3393@gmail.com',
'poleshchukolala@gmail.com',
'pelageya99@gmail.com',
'topoeva.n@yandex.ru',
'kamiomisuzu@yandex.ru',
'avtarcute777@gmail.com',
'romanziouzev@gmail.com',
'd.tarusov@gmail.com',
'melaniedarklove@gmail.com',
'valentina.vosk@gmail.com',
'monkphx@gmail.com',
'mayisaru@gmail.com',
'zaxquit@gmail.com',
'nivadow@gmail.com',
'ranjansahabandu@gmail.com',
'taras8055@gmail.com',
'xodacevich@yandex.ru',
'danmlisa2@gmail.com',
'acar_4788@hotmail.com',
'jianing.qi@gridmachina.com',
'roydiego@gmail.com',
'julienhardy94@gmail.com',
'gaivoronskystan@gmail.com']

geolocator = Nominatim(user_agent="Biblosphere")

for e in emails:
    auth_user = auth.get_user_by_email(e)
    if auth_user is None:
        print('!!! User auth missed for', e)
        continue
    user = db.collection('users').document(auth_user.uid).get()
    if user is None:
        print(f'!!! User record missed for {auth_user.display_name} ({e})')
        continue
    
    data = user.to_dict()
    
    # Find boos and wishes
    records = db.collection('bookrecords').where('holderId', '==', auth_user.uid).stream()
    records = [b.to_dict() for b in records]

    books = [b for b in records if not b['wish']]
    wishes = [b for b in records if b['wish']]

    # Skip if no books/wishes added
    if len(records) == 0:
        continue

    print('-------------------------------------------------------------')
    print(f'{auth_user.display_name} ({e})')

    # Show location
    location = geolocator.reverse(f"{records[0]['location']['geopoint'].latitude}, {records[0]['location']['geopoint'].longitude}", language='en', addressdetails=True)
    #print(location.raw)
    country = location.raw['address']['country']

    if 'state' in location.raw['address']:
        state = location.raw['address']['state']
    elif 'state' in location.raw['address']:
        state = location.raw['address']['state_district']
    else:
        state = location.raw['address']['city']
    
    if 'city' in location.raw['address']:
        city = location.raw['address']['city']
    elif 'town' in location.raw['address']:
        city = location.raw['address']['town']
    elif 'suburb' in location.raw['address']:
        city = location.raw['address']['suburb']
    else:
        city = location.raw['address']['county']
    print(f'LOCATION: {city}, {state}, {country}')
    print(f'ADDRESS: {location.raw["address"]}')

    # Show books
    if len(books) > 0:
        print('BOOKS:')
        for b in books:
            print(f'"{b["title"]}" by {",".join(b["authors"])}')
            
    # Show wishes
    if len(wishes) > 0:
        print('WISHES:')
        for b in wishes:
            print(f'"{b["title"]}" by {",".join(b["authors"])}')

    # TODO: Show chats

# %%
# Admin script to collect all unique locations for the website

db = firestore.client()

markers = pd.DataFrame(columns=('lat', 'lng'))

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('bookrecords').stream()

for i, b in enumerate(books):
    data = b.to_dict()
    if data['location'] is not None:
        #print({'lat': data['location']['geopoint'].latitude, 'lng': data['location']['geopoint'].longitude})
        markers.loc[i] = [data['location']['geopoint'].latitude, data['location']['geopoint'].longitude]

print('Full length:', len(markers))
markers.drop_duplicates(inplace=True)
print('Without duplicates:', len(markers))

json = markers.to_json(orient='records')
#print(json)

with open('locations.json', 'w') as f:
    f.write(json)

# %%
# Admin script to get all books around the location

from math import pi, sin, cos, atan2, sqrt

# Function to calculate distance between two geo-points
def distance_between(lat1, lon1, lat2, lon2):
    r = 6378.137 # Radius of earth in KM
    d_lat = lat2 * pi / 180 - lat1 * pi / 180
    d_lon = lon2 * pi / 180 - lon1 * pi / 180
    a = sin(d_lat/2) * sin(d_lat/2) + cos(lat1*pi/180) * cos(lat2*pi/180) * sin(d_lon/2) * sin(d_lon/2)
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = r * c

    return distance

#lat, lon, distance = 60.1699, 24.9384, 80.0 # Helsinki
lat, lon, distance = 25.2048, 55.2708, 80000.0 # Dubai


db = firestore.client()

#books = db.collection('bookrecords').limit(10).stream()
books = db.collection('bookrecords').stream()

count = 0
for i, b in enumerate(books):
    data = b.to_dict()
    if data['location'] is not None:
        d = distance_between(data['location']['geopoint'].latitude, data['location']['geopoint'].longitude, lat, lon)
        if d < distance and data['ownerId'] != 'SJIyyqAGPTcXWaVnha5pWe4kuIC3':
            #print('%.2f %s %s [%s]' % (d, data['authors'], data['title'], data['ownerId']))
            count += 1
        
print(count, 'books found')

# %%
Robert T. Kiyosaki: Rich Dad, Poor Dad: What the Rich Teach Their Kids About Money--That the Poor and Middle Class Do Not!
Peter Thiel, Blake  Masters: Zero to One: Notes on Startups, or How to Build the Future

# %%
# Admin script to get all book exchanges and its context

def print_chat(u1, u2):
    chat_id = ':'.join(sorted([u2,u1]))
    
    messages = db.collection('messages').document(chat_id).collection(chat_id).order_by('timestamp').stream()
    for m in messages:
        data = m.to_dict()
        print(data['content'])

db = firestore.client()

books = db.collection('bookrecords').where('lent', '==', True).stream()

for i, b in enumerate(books):
    data = b.to_dict()
    # Exclude testing ids
    if data['ownerId'] == 'rzvlcuAdFVS6238qqse4B4EjvUA3' or data['ownerId'] == 'oyYUDByQGVdgP13T1nyArhyFkct1'  or \
        data['holderId'] == 'rzvlcuAdFVS6238qqse4B4EjvUA3' or data['holderId'] == 'oyYUDByQGVdgP13T1nyArhyFkct1':
        continue
        
    # Print book details
    print('***************************************************************************')
    print('BOOK: %s' % data['title'])
        
    # Print names and emails of the users
    owner = auth.get_user(data['ownerId'])
    if owner is not None:
        print('BOOK OWNER: %s (%s)' % (owner.display_name, owner.email))
        
    holder = auth.get_user(data['holderId'])
    if holder is not None:
        print('BOOK HOLDER: %s (%s)' % (holder.display_name, holder.email))
        
        
    print_chat(data['holderId'], data['ownerId'])
    
    # Print latest conversation of the users

# %%
# Admin script to check messages

db = firestore.client()

#chats = db.collection('messages').where('toId', '==', 'xrTVCEyCwfOtO8lDe5UKk2egF4c2').stream()
chats = db.collection('messages').stream()


for c in chats:
    data = c.to_dict()
    u1, u2 = data['fromId'], data['toId']

    # Skip incomplete records
    if u1 is None or u2 is None:
        #print('toId or fromId is missing')
        continue
    
    # Skip test users
    if u1 in ['rzvlcuAdFVS6238qqse4B4EjvUA3', 'TzbOEGICy0XVPCUA6XUbTOKPXap2', 'oyYUDByQGVdgP13T1nyArhyFkct1', '0000000000000000000000000000'] or \
        u2 in ['rzvlcuAdFVS6238qqse4B4EjvUA3', 'TzbOEGICy0XVPCUA6XUbTOKPXap2', 'oyYUDByQGVdgP13T1nyArhyFkct1', '0000000000000000000000000000']:
        continue
    
    message_ref = c.reference.collection(c.id)
        
    if message_ref is not None:
        results = message_ref.order_by('timestamp').stream()
        messages = [m.to_dict() for m in results]
        
        if len(messages) > 0:
            user1 = auth.get_user(u1)
            if user1 is None:
                #print('Auth user for %s NOT found' % u1)
                continue

            user2 = auth.get_user(u2)
            if user2 is None:
                #print('Auth user for %s NOT found' % u2)
                continue

            print('************************************************************')
            print('CHAT BETWEEN: %s (%s) and %s (%s)' % (user1.display_name, user1.email, user2.display_name, user2.email))

            for m in messages:
                print(m['content'])

# %%
# Admin script to go through not identified ISBN and print it

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
isbns = db.collection('noisbn').where('found', '==', True).stream()

isbns = [b for b in isbns]

print('Number of records:', len(isbns))

count, resolved = 0, 0

# List of users with books to add
# {uid: {name: <name>, email: <email>, books: []}}
users = {}

for b in isbns:
    isbn = b.id
    data = b.to_dict()
    
    if len(isbn) == 10 and check_isbn_10(isbn) == 0:
        isbn = '978' + isbn
        isbn = isbn[:12] + str(calc_isbn_13(isbn))
        print('%s => %s' % (b.id, isbn))

    if len(isbn) != 13 or not isbn.startswith('97'):
        #print('ISBN %s are incorrect' % isbn)
        continue

    if 'requested_by' not in data or 'found' not in data or not data['found']:
        #print('ISBN %s has no users' % isbn)
        continue
        
    book = get_book(isbn)
    if book is not None:
        #print('%s requested by' % isbn, data['requested_by'])
        for uid in data['requested_by']:
            user = auth.get_user(uid)
            if user is not None:
            #print('%s requested by (%s, %s, %s)' % (isbn, uid, user.display_name, user.email))
                if uid in users:
                    users[uid]['books'].append(book)
                else:
                    users[uid] = {'name': user.display_name, 'email': user.email, 'books': [book]}
            else:
                print('Missing user:', uid)
    else:
        print('Book missing:', isbn)

# %%
i = 0
for uid in users:
    # Skip some users
    if uid in ['ot0jztXgSrMRYIWs3QwIRwTvimN2', 'mRGmf2rI7xSGqDq95NL5RTK43jl2', 'GO8apnl0KcU0uwfOyJWORUHAUGG3',
              'qKKPX23jaWO2VqYJShWKouup2P32']:
        continue
        
    data = users[uid]
    #print('%s has %d books to add' % (data['name'], len(data['books'])))
    
    user = db.collection('users').document(uid).get()
    if not user.exists:
        print(f'User record missing: {uid}, {data["name"]}')
    else:
        user_data = user.to_dict()
        if 'position' in user_data and user_data['position'] is not None:
            users[uid]['position'] = user_data['position']
        else:
            users[uid]['position'] = None
            other_books = db.collection('bookrecords').where('holderId', '==', uid).limit(1).stream()
            other_books = [b for b in other_books]
            
            if len(other_books) > 0:
                other_data = other_books[0].to_dict()
                if 'location' in other_data and other_data['location'] is not None:
                    print(f'Geo-position found {uid}, {data["name"]}')
                    users[uid]['position'] = other_data['location']['geopoint']

            if users[uid]['position'] is None:
                print(f'Position missed for {uid}, {data["name"]}')

        if 'photo' in user_data:
            users[uid]['photo'] = user_data['photo']
        elif 'photoUrl' in user_data:
            users[uid]['photo'] = user_data['photoUrl']
        else:
            users[uid]['photo'] = ''
            print(f'Photo missed for {uid}, {data["name"]}')
    
    print('-------------------------------------------------------')
    print(data['email'])

    print(f"Hello {data['name']},\n\nYou've tryed to add books to Bibloshere app and some books were not found by ISBN. I've corrected problems with ISBN search and added below books into your catalog. Sorry for inconvenience. Let me know if I can help you with the app.\n")

    for i, b in enumerate(data['books']):
        print(f'{i+1}) {b.authors} "{b.title}"')
        
        b.keys.append(isbn)
        
        # Add bookrecord to Firestore
        rec = {
            'authors': [s.strip() for s in b.authors.split(',')],
            'confirmed': False,
            'holderId': uid,
            'holderName': data['name'],
            'holderImage': users[uid]['photo'],
            'id': f'b:{uid}:{isbn}',
            'image': b.image,
            'isbn': isbn,
            'keys': b.keys,
            'lent': False,
            'location': {
                  'geopoint': users[uid]['position'],
                  'geohash': geohash2.encode(users[uid]['position'].latitude, users[uid]['position'].longitude)[:9],
               },
            'matched': False,
            'matcheId': None,
            'ownerId': uid,
            'ownerName': data['name'],
            'ownerImage': users[uid]['photo'],
            'title': b.title,
            'transit': False,
            'users': [uid],
            'wish': False
        }
        db.collection('bookrecords').document(rec['id']).set(rec, merge=True)
        #print(f"Bookrecord added {rec['id']}, rec['authors']") 
        #print(f"AUTHORS {rec['authors']}") 

    print('\n- Denis Stark')

    #i += 1
    #if i >= 1:
    #    break
    #9785354014804

# %%
# Admin script to go through not identified ISBN and try to find it

db = firestore.client()

#isbns = db.collection('noisbn').limit(20).stream()
isbns = db.collection('noisbn').stream()

isbns = [b for b in isbns]

print('Number of records:', len(isbns))

count, resolved = 0, 0

to_delete = []
found = []
for b in isbns:
    isbn = b.id
    data = b.to_dict()

    # Skip records if it was sorted out before
    if 'found' in data:
        continue

    # Skip record if no users recorded for it
    if 'requested_by' not in data:
        continue

    if len(isbn) == 10 and check_isbn_10(isbn) == 0:
        isbn = '978' + isbn
        isbn = isbn[:12] + str(calc_isbn_13(isbn))
        print('%s => %s' % (b.id, isbn))

    if len(isbn) == 13 and isbn.startswith('97'):
        #To just print ISBN
        #print(isbn)
        #continue
        
        count += 1
        #print('%s try to resolve...' % isbn)
        book = get_book(isbn)

        if book is not None:
            resolved += 1
            found.append(b.id)
            print('ISBN %s: resolved' % isbn)
            db.collection('noisbn').document(isbn).update({'found': True})
        else:
            print('ISBN %s: NOT resolved' % isbn)
            db.collection('noisbn').document(isbn).update({'found': False})
    else:
        to_delete.append(b.id)
        

print('%d out of %d resolved' % (resolved, count))

# %%
# ADD BOOKS IN MYSQL (Manually found in web)

books = []
books.append(Book('9781897510247', 'Дао-Дэ-Цзин', 'Владимир Антонов', image='https://www.ellibs.com/sites/default/files/imagecache/product/bookcover_9781897510247.jpg', language='rus'))
books.append(Book('9785001311379', '21 Урок Для Xxi Века', 'Юваль Ной Харари', image='https://www.rahvaraamat.ee/images/products/001/354/892/thumbnails/big/0ab9d8016fd041b7e31ef2a77cddcf646baa2706/21-%D1%83%D1%80%D0%BE%D0%BA-%D0%B4%D0%BB%D1%8F-xxi-%D0%B2%D0%B5%D0%BA%D0%B0.jpg', language='rus'))
books.append(Book('9785030038322', 'Физиология Человека', '', image='https://images-na.ssl-images-amazon.com/images/I/415MWsuJk-L._SX298_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785170026418', 'Ночной Портье', 'Ирвин Шоу', image='https://images-na.ssl-images-amazon.com/images/I/51kqNUUKtFL._SX301_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785170511518', '100 Способов Очистить Дом От Энергетической Грязи', 'Мариеа Миллер', image='https://images-na.ssl-images-amazon.com/images/I/41JA9htKUvL._BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785222037355', 'Техника Быстрого Чтения', 'Андреев', image='', language='rus'))
books.append(Book('9785271451942', 'Ружья, Микробы И Сталь', 'Джаред Даймонд', image='https://www.rahvaraamat.ee/images/products/000/067/415/thumbnails/view/ae1f30730f4669ffb44de832d34af385aa4475df/%D1%80%D1%83%D0%B6%D1%8C%D1%8F-%D0%BC%D0%B8%D0%BA%D1%80%D0%BE%D0%B1%D1%8B-%D0%B8-%D1%81%D1%82%D0%B0%D0%BB%D1%8C.jpg', language='rus'))
books.append(Book('9785389015234', 'Звёзды', 'Дайер Алан', image='https://images-na.ssl-images-amazon.com/images/I/3156Utn8GRL._BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785699563890', 'Искусство Грудного Вскармливания', 'Тереза Питман, Диана Вест, Дайен Виссингер', image='https://www.rahvaraamat.ee/images/products/000/084/180/thumbnails/view/ce340ce3290c5b1909fc829894c1b6dbc7963bb0/%D0%B8%D1%81%D0%BA%D1%83%D1%81%D1%81%D1%82%D0%B2%D0%BE-%D0%B3%D1%80%D1%83%D0%B4%D0%BD%D0%BE%D0%B3%D0%BE-%D0%B2%D1%81%D0%BA%D0%B0%D1%80%D0%BC%D0%BB%D0%B8%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F.jpg', language='rus'))
books.append(Book('9785906264527', 'Голодный Город. Как Еда Определяет Нашу Жизнь', 'Кэролин Стил', image='https://pictures.abebooks.com/isbn/9785906264527-us.jpg', language='rus'))
books.append(Book('9785911031541', 'Культура Маркетинга. Маркетинг Культуры', 'Джон Сибрук', image='https://www.rahvaraamat.ee/images/products/000/697/105/thumbnails/view/9408fabc13d5dd5720304b128bbca92fe2001b2a/%D0%BA%D1%83%D0%BB%D1%8C%D1%82%D1%83%D1%80%D0%B0-%D0%BC%D0%B0%D1%80%D0%BA%D0%B5%D1%82%D0%B8%D0%BD%D0%B3%D0%B0-%D0%BC%D0%B0%D1%80%D0%BA%D0%B5%D1%82%D0%B8%D0%BD%D0%B3-%D0%BA%D1%83%D0%BB%D1%8C%D1%82%D1%83%D1%80%D1%8B-nobrow.jpg', language='rus'))
books.append(Book('9785917430621', 'На Стороне Подростка', 'Франсуаза Дольто', image='https://libs.ru/book/441/cover_441202.jpg', language='rus'))
books.append(Book('9785917592107', 'Мой Внутренний Элвис', 'Яна Шерер', image='https://www.knigi-club.ru/thumb/324x477xCUT/upload/iblock/8a7/moy_vnutrenniy_elvis_.jpeg', language='rus'))
books.append(Book('9785943554575', 'Брак Умер... Да Здравствует Семья!', 'Анатолий Некрасов', image='https://www.knygy.com.ua/pix/0c/bf/c9/0cbfc9ea4445d3a199f77c47e7c0a5ab.jpg', language='rus'))
books.append(Book('9785953347686', '100 Великих Людеи', 'Сергей Мусский', image='https://images-na.ssl-images-amazon.com/images/I/51MDNUk-0BL._SX298_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9785979200064', 'Издание Журнала. От Идеи До Воплощения', 'Джон Морриш', image='https://libs.ru/book/731/cover_731092.jpg', language='rus'))
books.append(Book('9785982120182', 'Любовныи Многоуголник', 'Анатолий Некрасов', image='https://images-na.ssl-images-amazon.com/images/I/31E+8MqNSLL._BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9789665215622', 'Третье Открытие Силы', 'Андрей Сидерский', image='https://images-na.ssl-images-amazon.com/images/I/41nNk9j8A6L._BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9789851522350', 'Супермышление', 'Тони Бьюзен, Барри Бьюзен', image='https://images-na.ssl-images-amazon.com/images/I/515QIA5P7mL._SX335_BO1,204,203,200_.jpg', language='rus'))
books.append(Book('9789851531659', '7 Навыков Высокоэффективных Семей', 'Стивен Р Кови ', image='https://www.troykaonline.com/files/product/large/246789_9789851531659.jpg', language='rus'))
books.append(Book('9795367002415', 'Русские Летописи Xi-Xvi Веков', 'А. Боброва', image='https://images-na.ssl-images-amazon.com/images/I/61ynENagZXL._SX339_BO1,204,203,200_.jpg', language='rus'))

add_books(books)

#book = get_book('9781897510247')
#if book is not None:
#    print(book.title, book.authors)

# %%
# Admin script to add all books from Firestore to MySQL

db = firestore.client()

#books = db.collection('bookrecords').limit(30).stream()
books = db.collection('books').stream()
books = [b for b in books]

print('Number of records:', len(books))

books_to_add = []

for b in books:
    data = b.to_dict()
    
    if 'migrated' in data and data['migrated']:
        continue
     
    if 'isbn' in data and ('title' in data or 'authors' in data):
        #print('Authors:', data['authors'])
        if 'authors' in data and data['authors'] is not None:
            authors = ','.join([a for a in data['authors'] if a is not None])
        else:
            authors = ''
        books_to_add.append(Book(data['isbn'], data['title'], authors, data['image']))

        if 'authors' in data and len(data['authors']) > 1:
            print('Multi-authors: %s' % data['isbn'], data['authors'])
    elif 'book' in data:
        data = data['book']
        if 'isbn' in data and ('title' in data or 'authors' in data):
            if 'authors' in data and data['authors'] is not None:
                authors = ','.join([a for a in data['authors'] if a is not None])
            else:
                authors = ''
            books_to_add.append(Book(data['isbn'], data['title'], authors, data['image']))

            if 'authors' in data and len(data['authors']) > 1:
                print('Multi-authors: %s' % data['isbn'], data['authors'])
    else:
        print('DATA MISSING:', data)
    
    if len(books_to_add) >= 10:
        add_books(books_to_add)
        for isbn in [b.isbn for b in books_to_add]:
            db.collection('books').document(isbn).update({'migrated': True})

        books_to_add = []

if len(books_to_add) > 0:        
    add_books(books_to_add)
    for isbn in [b.isbn for b in books_to_add]:
        db.collection('books').document(isbn).update({'migrated': True})

# %%
# Admin script to run shelf recognition for old shelves

db = firestore.client()


shelves = db.collection('shelves').where('user', '>', '').where('status', '==', 5).stream()
#shelves = db.collection('shelves').where('user', '>', '').stream()
shelves = [s for s in shelves]

print('Number of book shelves:', len(shelves))

for s in shelves:
    data = s.to_dict()
    
    # Skip shelves already requested for processing
    #if 'status' in data:
    #    continue

    # Run recognition via API
    print('Run recognition for user [%s], image [%s], shelf [%s], at coordinates [%.5f, %.5f]' % (data['user'], data['file'], s.id, data['position'].latitude, data['position'].longitude))
    res = recognize_image(data['user'], data['file'], s.id, data['position'])

# %%
# Run recognition for one book shelf
#recognize_image('NW3sjiR8NQT6OwZyRFwCEmgbZ8j1', '1589726917860.jpg', '1589726917860', firestore.GeoPoint(43.7113831, 20.6709329))
recognize_image('0000000000000000000000000000', '0000000000034.jpg', '0000000000000000000000000000:0000000000034', firestore.GeoPoint(90.0, 135.0))

# Add books
#books = [Book('9785946230469', 'Энциклопедия для детей. Т. 23: Универсальный иллюстрированный энциклопедический словарь', '', image='https://images-na.ssl-images-amazon.com/images/I/21HqXNQA5FL._BO1,204,203,200_.jpg')]
#add_books(books)

# Get book by ISBN
#book = get_book('9785946230469')
#print(book.isbn, book.title)

# %%
# Script to check results of the recognition

db = firestore.client()

shelves = db.collection('shelves').where('user', '>', '').stream()
shelves = [s for s in shelves]

print('Number of book shelves:', len(shelves))

recognized, total, completed, failed, lookup = 0, 0, 0, 0, 0
for s in shelves:
    data = s.to_dict()
    
    if data['status'] == 6:
        completed += 1
        recognized += data['recognized']
        total += data['total']
    elif data['status'] == 7:
        failed += 1
    else:
        print('Other status:', data['status'])

print('Completed: %d, Failed: %d, Lookup: %d' % (completed, failed, lookup))
print('Recognized: %d (%d%%), Total: %d'  % (recognized, 100 * recognized / total, total))

# %%
# Admin script to visualize recognition
# Get the image and recognition json from GCS and visualize
import cv2
import numpy as np
from firebase_admin import storage

bucket = storage.bucket('biblosphere-210106.appspot.com')

#user = '0000000000000000000000000000'
#shelf = '0000000000034'

user = 'AWsv5n9QiJYIUcDQmxWlBKRoBzZ2'
shelf = '1590618924998' # '1590619142574', '1590619327951'
#shelf = '1590619142574' # '1590619327951'
#shelf = '1590619327951'

image_blob = bucket.blob('images/%s/%s.jpg' % (user, shelf))
result_blob = bucket.blob('images/%s/%s.json' % (user, shelf))

img = imread_blob(image_blob)
results = json.loads(result_blob.download_as_string())

for b in results['recognized']:
    cv2.drawContours(img, np.array([b['outline']]), 0, (0, 255, 0), 7)

for b in results['unrecognized']:
    cv2.drawContours(img, np.array([b['outline']]), 0, (0, 0, 255), 7)

cv2.imwrite('results/'+user+'-'+shelf+'.jpg', img)

# %%
for b in results['recognized']:
    print(b['book']['isbn'], '"%s"' % b['book']['title'])

# %% [markdown]
# **FIRST RUN (Error in web-search)**
# * Number of book shelves: 171
# * Completed: 117, Failed: 51
# * Recognized: 560 (40%), Total: 1384
#
# **SECOND RUN (only processed schelves have been taken)**
# * Number of book shelves: 170
# * Completed: 170, Failed: 0, Lookup: 0
# * Recognized: 1010 (50%), Total: 2017

# %%
# TODO actions:

# 1. Corrupted symbols (abebooks):
# 9789874024770, 9785733103037
